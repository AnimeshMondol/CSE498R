# %% [markdown]
# <a href="https://colab.research.google.com/github/AnimeshMondol/CSE498R/blob/main/Epo220.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Jul 26 10:38:57 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.5.30)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-63057acd-519f-4228-9ebf-7b2ef9e2fca0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63057acd-519f-4228-9ebf-7b2ef9e2fca0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"animeshmondol","key":"c4507c33debf7afb770d35a343bfcbcc"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle

#Change permission
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d plameneduardo/sarscov2-ctscan-dataset
# Out:
# Downloading sarscov2-ctscan-dataset.zip to /content
#  95% 218M/230M [00:01<00:00, 153MB/s]
# 100% 230M/230M [00:01<00:00, 146MB/s]

# %%
from zipfile import ZipFile
file_name = "sarscov2-ctscan-dataset.zip"

with ZipFile(file_name,"r") as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
        #print(os.path.join(dirname, filename))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.densenet import DenseNet121

# %%
disease_types=['COVID', 'non-COVID']
data_dir = '/content'
train_dir = os.path.join(data_dir)

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.head()
# Out:
#                     File  DiseaseID Disease Type
# 0  COVID/Covid (277).png          0        COVID
# 1  COVID/Covid (278).png          0        COVID
# 2  COVID/Covid (528).png          0        COVID
# 3  COVID/Covid (349).png          0        COVID
# 4  COVID/Covid (736).png          0        COVID

# %%
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#                             File  DiseaseID Disease Type
# 0          COVID/Covid (231).png          0        COVID
# 1          COVID/Covid (428).png          0        COVID
# 2  non-COVID/Non-Covid (209).png          1    non-COVID
# 3  non-COVID/Non-Covid (545).png          1    non-COVID
# 4          COVID/Covid (390).png          0        COVID

# %%
plt.hist(train['DiseaseID'])
plt.title('Frequency Histogram of Species')
plt.figure(figsize=(12, 12))
plt.show()

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('COVID', 5, 5)

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('non-COVID', 5, 5)

# %%
IMAGE_SIZE = 64
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 2481it [00:07, 317.43it/s]
# Train Shape: (2481, 64, 64, 3)

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=2)

# %%
BATCH_SIZE = 64

# Split the train and validation sets 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 15))
for i in range(3):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(disease_types[np.argmax(Y_train[i])])

# %%
EPOCHS = 220
SIZE=64
N_ch=3

# %%
def build_densenet():
    densenet = DenseNet121(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = densenet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    optimizer = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
model = build_densenet()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        zoom_range=0.2, # Range for random zoom
                        horizontal_flip=True, # Randomly flip inputs horizontally
                        vertical_flip=True) # Randomly flip inputs vertically

datagen.fit(X_train)
# Fits the model on batches with real-time data augmentation
hist = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 3)         84
# _________________________________________________________________
# densenet121 (Functional)     (None, None, None, 1024)  7037504
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1024)              0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               262400
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# root (Dense)                 (None, 2)                 514
# =================================================================
# Total params: 7,305,622
# Trainable params: 7,219,414
# Non-trainable params: 86,208
# _________________________________________________________________
# Epoch 1/220
# 31/31 - 40s - loss: 1.1536 - accuracy: 0.5494 - val_loss: 1.5799 - val_accuracy: 0.5513
#
# Epoch 00001: val_loss improved from inf to 1.57986, saving model to model.h5
# Epoch 2/220
# 31/31 - 4s - loss: 0.9831 - accuracy: 0.6079 - val_loss: 0.7850 - val_accuracy: 0.5533
#
# Epoch 00002: val_loss improved from 1.57986 to 0.78501, saving model to model.h5
# Epoch 3/220
# 31/31 - 4s - loss: 0.9035 - accuracy: 0.6371 - val_loss: 0.6908 - val_accuracy: 0.5553
#
# Epoch 00003: val_loss improved from 0.78501 to 0.69083, saving model to model.h5
# Epoch 4/220
# 31/31 - 4s - loss: 0.7597 - accuracy: 0.6830 - val_loss: 0.7328 - val_accuracy: 0.5493
#
# Epoch 00004: val_loss did not improve from 0.69083
# Epoch 5/220
# 31/31 - 4s - loss: 0.7650 - accuracy: 0.6804 - val_loss: 0.7048 - val_accuracy: 0.5795
#
# Epoch 00005: val_loss did not improve from 0.69083
# Epoch 6/220
# 31/31 - 4s - loss: 0.6930 - accuracy: 0.7157 - val_loss: 1.0109 - val_accuracy: 0.5835
#
# Epoch 00006: val_loss did not improve from 0.69083
# Epoch 7/220
# 31/31 - 4s - loss: 0.6301 - accuracy: 0.7440 - val_loss: 0.9627 - val_accuracy: 0.5976
#
# Epoch 00007: val_loss did not improve from 0.69083
# Epoch 8/220
# 31/31 - 4s - loss: 0.5509 - accuracy: 0.7530 - val_loss: 1.0366 - val_accuracy: 0.5915
#
# Epoch 00008: val_loss did not improve from 0.69083
# Epoch 9/220
# 31/31 - 4s - loss: 0.5392 - accuracy: 0.7823 - val_loss: 0.7341 - val_accuracy: 0.6439
#
# Epoch 00009: val_loss did not improve from 0.69083
# Epoch 10/220
# 31/31 - 4s - loss: 0.5056 - accuracy: 0.7812 - val_loss: 0.6145 - val_accuracy: 0.6942
#
# Epoch 00010: val_loss improved from 0.69083 to 0.61448, saving model to model.h5
# Epoch 11/220
# 31/31 - 4s - loss: 0.5115 - accuracy: 0.7727 - val_loss: 0.5241 - val_accuracy: 0.7404
#
# Epoch 00011: val_loss improved from 0.61448 to 0.52413, saving model to model.h5
# Epoch 12/220
# 31/31 - 4s - loss: 0.4671 - accuracy: 0.7964 - val_loss: 0.4590 - val_accuracy: 0.7746
#
# Epoch 00012: val_loss improved from 0.52413 to 0.45901, saving model to model.h5
# Epoch 13/220
# 31/31 - 4s - loss: 0.4410 - accuracy: 0.8059 - val_loss: 0.4084 - val_accuracy: 0.8089
#
# Epoch 00013: val_loss improved from 0.45901 to 0.40841, saving model to model.h5
# Epoch 14/220
# 31/31 - 4s - loss: 0.4483 - accuracy: 0.8095 - val_loss: 0.5804 - val_accuracy: 0.7586
#
# Epoch 00014: val_loss did not improve from 0.40841
# Epoch 15/220
# 31/31 - 4s - loss: 0.4095 - accuracy: 0.8191 - val_loss: 1.2941 - val_accuracy: 0.5734
#
# Epoch 00015: val_loss did not improve from 0.40841
# Epoch 16/220
# 31/31 - 4s - loss: 0.4054 - accuracy: 0.8261 - val_loss: 0.6552 - val_accuracy: 0.6821
#
# Epoch 00016: val_loss did not improve from 0.40841
# Epoch 17/220
# 31/31 - 4s - loss: 0.3911 - accuracy: 0.8317 - val_loss: 0.9359 - val_accuracy: 0.5936
#
# Epoch 00017: val_loss did not improve from 0.40841
# Epoch 18/220
# 31/31 - 4s - loss: 0.4044 - accuracy: 0.8281 - val_loss: 1.1151 - val_accuracy: 0.6036
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 00018: val_loss did not improve from 0.40841
# Epoch 19/220
# 31/31 - 4s - loss: 0.3683 - accuracy: 0.8518 - val_loss: 0.6288 - val_accuracy: 0.7002
#
# Epoch 00019: val_loss did not improve from 0.40841
# Epoch 20/220
# 31/31 - 4s - loss: 0.3649 - accuracy: 0.8443 - val_loss: 0.3351 - val_accuracy: 0.8632
#
# Epoch 00020: val_loss improved from 0.40841 to 0.33506, saving model to model.h5
# Epoch 21/220
# 31/31 - 4s - loss: 0.3473 - accuracy: 0.8528 - val_loss: 0.6371 - val_accuracy: 0.7143
#
# Epoch 00021: val_loss did not improve from 0.33506
# Epoch 22/220
# 31/31 - 4s - loss: 0.3581 - accuracy: 0.8453 - val_loss: 0.3218 - val_accuracy: 0.8753
#
# Epoch 00022: val_loss improved from 0.33506 to 0.32183, saving model to model.h5
# Epoch 23/220
# 31/31 - 4s - loss: 0.3611 - accuracy: 0.8448 - val_loss: 0.5807 - val_accuracy: 0.7264
#
# Epoch 00023: val_loss did not improve from 0.32183
# Epoch 24/220
# 31/31 - 4s - loss: 0.3489 - accuracy: 0.8523 - val_loss: 0.5042 - val_accuracy: 0.7606
#
# Epoch 00024: val_loss did not improve from 0.32183
# Epoch 25/220
# 31/31 - 4s - loss: 0.3549 - accuracy: 0.8443 - val_loss: 0.6315 - val_accuracy: 0.7143
#
# Epoch 00025: val_loss did not improve from 0.32183
# Epoch 26/220
# 31/31 - 4s - loss: 0.3444 - accuracy: 0.8564 - val_loss: 0.3530 - val_accuracy: 0.8451
#
# Epoch 00026: val_loss did not improve from 0.32183
# Epoch 27/220
# 31/31 - 4s - loss: 0.3428 - accuracy: 0.8523 - val_loss: 0.4723 - val_accuracy: 0.7746
#
# Epoch 00027: val_loss did not improve from 0.32183
# Epoch 28/220
# 31/31 - 4s - loss: 0.3383 - accuracy: 0.8614 - val_loss: 0.3382 - val_accuracy: 0.8310
#
# Epoch 00028: val_loss did not improve from 0.32183
# Epoch 29/220
# 31/31 - 4s - loss: 0.3311 - accuracy: 0.8634 - val_loss: 0.3193 - val_accuracy: 0.8773
#
# Epoch 00029: val_loss improved from 0.32183 to 0.31933, saving model to model.h5
# Epoch 30/220
# 31/31 - 4s - loss: 0.3257 - accuracy: 0.8619 - val_loss: 0.3027 - val_accuracy: 0.8632
#
# Epoch 00030: val_loss improved from 0.31933 to 0.30270, saving model to model.h5
# Epoch 31/220
# 31/31 - 4s - loss: 0.3226 - accuracy: 0.8740 - val_loss: 0.3786 - val_accuracy: 0.8068
#
# Epoch 00031: val_loss did not improve from 0.30270
# Epoch 32/220
# 31/31 - 4s - loss: 0.3436 - accuracy: 0.8548 - val_loss: 0.4226 - val_accuracy: 0.8249
#
# Epoch 00032: val_loss did not improve from 0.30270
# Epoch 33/220
# 31/31 - 4s - loss: 0.3367 - accuracy: 0.8553 - val_loss: 0.2834 - val_accuracy: 0.9034
#
# Epoch 00033: val_loss improved from 0.30270 to 0.28341, saving model to model.h5
# Epoch 34/220
# 31/31 - 4s - loss: 0.3187 - accuracy: 0.8538 - val_loss: 0.3380 - val_accuracy: 0.8370
#
# Epoch 00034: val_loss did not improve from 0.28341
# Epoch 35/220
# 31/31 - 4s - loss: 0.3121 - accuracy: 0.8750 - val_loss: 0.3200 - val_accuracy: 0.8793
#
# Epoch 00035: val_loss did not improve from 0.28341
# Epoch 36/220
# 31/31 - 4s - loss: 0.3155 - accuracy: 0.8679 - val_loss: 0.2722 - val_accuracy: 0.8994
#
# Epoch 00036: val_loss improved from 0.28341 to 0.27216, saving model to model.h5
# Epoch 37/220
# 31/31 - 4s - loss: 0.2963 - accuracy: 0.8861 - val_loss: 0.3037 - val_accuracy: 0.8712
#
# Epoch 00037: val_loss did not improve from 0.27216
# Epoch 38/220
# 31/31 - 4s - loss: 0.3065 - accuracy: 0.8745 - val_loss: 0.2675 - val_accuracy: 0.8974
#
# Epoch 00038: val_loss improved from 0.27216 to 0.26754, saving model to model.h5
# Epoch 39/220
# 31/31 - 4s - loss: 0.3038 - accuracy: 0.8765 - val_loss: 0.2723 - val_accuracy: 0.9014
#
# Epoch 00039: val_loss did not improve from 0.26754
# Epoch 40/220
# 31/31 - 4s - loss: 0.2995 - accuracy: 0.8775 - val_loss: 0.2752 - val_accuracy: 0.9014
#
# Epoch 00040: val_loss did not improve from 0.26754
# Epoch 41/220
# 31/31 - 4s - loss: 0.3122 - accuracy: 0.8659 - val_loss: 0.2670 - val_accuracy: 0.8974
#
# Epoch 00041: val_loss improved from 0.26754 to 0.26695, saving model to model.h5
# Epoch 42/220
# 31/31 - 4s - loss: 0.3070 - accuracy: 0.8770 - val_loss: 0.2617 - val_accuracy: 0.9115
#
# Epoch 00042: val_loss improved from 0.26695 to 0.26174, saving model to model.h5
# Epoch 43/220
# 31/31 - 4s - loss: 0.2988 - accuracy: 0.8690 - val_loss: 0.2821 - val_accuracy: 0.8853
#
# Epoch 00043: val_loss did not improve from 0.26174
# Epoch 44/220
# 31/31 - 4s - loss: 0.3002 - accuracy: 0.8770 - val_loss: 0.2668 - val_accuracy: 0.9054
#
# Epoch 00044: val_loss did not improve from 0.26174
# Epoch 45/220
# 31/31 - 4s - loss: 0.2883 - accuracy: 0.8775 - val_loss: 0.2881 - val_accuracy: 0.8974
#
# Epoch 00045: val_loss did not improve from 0.26174
# Epoch 46/220
# 31/31 - 4s - loss: 0.2787 - accuracy: 0.8881 - val_loss: 0.4238 - val_accuracy: 0.7928
#
# Epoch 00046: val_loss did not improve from 0.26174
# Epoch 47/220
# 31/31 - 4s - loss: 0.2933 - accuracy: 0.8785 - val_loss: 0.5070 - val_accuracy: 0.7485
#
# Epoch 00047: val_loss did not improve from 0.26174
# Epoch 48/220
# 31/31 - 4s - loss: 0.2930 - accuracy: 0.8715 - val_loss: 0.8834 - val_accuracy: 0.6499
#
# Epoch 00048: val_loss did not improve from 0.26174
# Epoch 49/220
# 31/31 - 4s - loss: 0.2942 - accuracy: 0.8725 - val_loss: 0.4400 - val_accuracy: 0.7666
#
# Epoch 00049: val_loss did not improve from 0.26174
# Epoch 50/220
# 31/31 - 4s - loss: 0.2808 - accuracy: 0.8826 - val_loss: 0.3078 - val_accuracy: 0.8531
#
# Epoch 00050: val_loss did not improve from 0.26174
# Epoch 51/220
# 31/31 - 4s - loss: 0.2968 - accuracy: 0.8800 - val_loss: 0.3445 - val_accuracy: 0.8310
#
# Epoch 00051: val_loss did not improve from 0.26174
# Epoch 52/220
# 31/31 - 4s - loss: 0.2807 - accuracy: 0.8826 - val_loss: 0.6632 - val_accuracy: 0.6861
#
# Epoch 00052: val_loss did not improve from 0.26174
# Epoch 53/220
# 31/31 - 4s - loss: 0.2823 - accuracy: 0.8866 - val_loss: 0.3131 - val_accuracy: 0.8551
#
# Epoch 00053: val_loss did not improve from 0.26174
# Epoch 54/220
# 31/31 - 4s - loss: 0.2751 - accuracy: 0.8871 - val_loss: 0.3529 - val_accuracy: 0.8571
#
# Epoch 00054: val_loss did not improve from 0.26174
# Epoch 55/220
# 31/31 - 4s - loss: 0.2778 - accuracy: 0.8810 - val_loss: 0.3031 - val_accuracy: 0.8913
#
# Epoch 00055: val_loss did not improve from 0.26174
# Epoch 56/220
# 31/31 - 4s - loss: 0.2690 - accuracy: 0.8755 - val_loss: 0.3945 - val_accuracy: 0.8089
#
# Epoch 00056: val_loss did not improve from 0.26174
# Epoch 57/220
# 31/31 - 4s - loss: 0.2763 - accuracy: 0.8780 - val_loss: 0.2930 - val_accuracy: 0.8994
#
# Epoch 00057: val_loss did not improve from 0.26174
# Epoch 58/220
# 31/31 - 4s - loss: 0.2717 - accuracy: 0.8881 - val_loss: 0.3004 - val_accuracy: 0.8833
#
# Epoch 00058: val_loss did not improve from 0.26174
# Epoch 59/220
# 31/31 - 4s - loss: 0.2748 - accuracy: 0.8911 - val_loss: 0.3357 - val_accuracy: 0.8511
#
# Epoch 00059: val_loss did not improve from 0.26174
# Epoch 60/220
# 31/31 - 4s - loss: 0.2764 - accuracy: 0.8770 - val_loss: 0.7298 - val_accuracy: 0.6841
#
# Epoch 00060: val_loss did not improve from 0.26174
# Epoch 61/220
# 31/31 - 4s - loss: 0.2816 - accuracy: 0.8775 - val_loss: 0.2877 - val_accuracy: 0.8893
#
# Epoch 00061: val_loss did not improve from 0.26174
# Epoch 62/220
# 31/31 - 4s - loss: 0.2581 - accuracy: 0.8886 - val_loss: 0.3618 - val_accuracy: 0.8229
#
# Epoch 00062: val_loss did not improve from 0.26174
# Epoch 63/220
# 31/31 - 4s - loss: 0.2598 - accuracy: 0.8931 - val_loss: 0.3329 - val_accuracy: 0.8390
#
# Epoch 00063: val_loss did not improve from 0.26174
# Epoch 64/220
# 31/31 - 4s - loss: 0.2546 - accuracy: 0.8911 - val_loss: 0.4624 - val_accuracy: 0.8310
#
# Epoch 00064: val_loss did not improve from 0.26174
# Epoch 65/220
# 31/31 - 4s - loss: 0.2674 - accuracy: 0.8901 - val_loss: 0.5155 - val_accuracy: 0.7565
#
# Epoch 00065: val_loss did not improve from 0.26174
# Epoch 66/220
# 31/31 - 4s - loss: 0.2774 - accuracy: 0.8816 - val_loss: 0.2294 - val_accuracy: 0.9175
#
# Epoch 00066: val_loss improved from 0.26174 to 0.22938, saving model to model.h5
# Epoch 67/220
# 31/31 - 4s - loss: 0.2671 - accuracy: 0.8921 - val_loss: 0.4302 - val_accuracy: 0.7787
#
# Epoch 00067: val_loss did not improve from 0.22938
# Epoch 68/220
# 31/31 - 4s - loss: 0.2651 - accuracy: 0.8891 - val_loss: 0.3134 - val_accuracy: 0.8753
#
# Epoch 00068: val_loss did not improve from 0.22938
# Epoch 69/220
# 31/31 - 4s - loss: 0.2664 - accuracy: 0.8911 - val_loss: 0.2650 - val_accuracy: 0.8853
#
# Epoch 00069: val_loss did not improve from 0.22938
# Epoch 70/220
# 31/31 - 4s - loss: 0.2515 - accuracy: 0.8891 - val_loss: 0.3095 - val_accuracy: 0.8793
#
# Epoch 00070: val_loss did not improve from 0.22938
# Epoch 71/220
# 31/31 - 4s - loss: 0.2602 - accuracy: 0.8891 - val_loss: 0.2496 - val_accuracy: 0.8954
#
# Epoch 00071: val_loss did not improve from 0.22938
# Epoch 72/220
# 31/31 - 4s - loss: 0.2690 - accuracy: 0.8846 - val_loss: 0.4054 - val_accuracy: 0.8290
#
# Epoch 00072: val_loss did not improve from 0.22938
# Epoch 73/220
# 31/31 - 4s - loss: 0.2308 - accuracy: 0.8972 - val_loss: 0.2966 - val_accuracy: 0.8833
#
# Epoch 00073: val_loss did not improve from 0.22938
# Epoch 74/220
# 31/31 - 4s - loss: 0.2507 - accuracy: 0.8942 - val_loss: 0.2348 - val_accuracy: 0.9135
#
# Epoch 00074: val_loss did not improve from 0.22938
# Epoch 75/220
# 31/31 - 4s - loss: 0.2439 - accuracy: 0.8977 - val_loss: 0.2980 - val_accuracy: 0.8592
#
# Epoch 00075: val_loss did not improve from 0.22938
# Epoch 76/220
# 31/31 - 4s - loss: 0.2374 - accuracy: 0.9012 - val_loss: 0.2505 - val_accuracy: 0.8994
#
# Epoch 00076: val_loss did not improve from 0.22938
# Epoch 77/220
# 31/31 - 4s - loss: 0.2447 - accuracy: 0.8967 - val_loss: 0.4930 - val_accuracy: 0.8310
#
# Epoch 00077: val_loss did not improve from 0.22938
# Epoch 78/220
# 31/31 - 4s - loss: 0.2239 - accuracy: 0.9047 - val_loss: 0.2585 - val_accuracy: 0.8913
#
# Epoch 00078: val_loss did not improve from 0.22938
# Epoch 79/220
# 31/31 - 4s - loss: 0.2367 - accuracy: 0.8957 - val_loss: 0.7557 - val_accuracy: 0.7002
#
# Epoch 00079: val_loss did not improve from 0.22938
# Epoch 80/220
# 31/31 - 4s - loss: 0.2406 - accuracy: 0.8952 - val_loss: 0.5257 - val_accuracy: 0.7545
#
# Epoch 00080: val_loss did not improve from 0.22938
# Epoch 81/220
# 31/31 - 4s - loss: 0.2335 - accuracy: 0.8977 - val_loss: 0.2403 - val_accuracy: 0.9054
#
# Epoch 00081: val_loss did not improve from 0.22938
# Epoch 82/220
# 31/31 - 4s - loss: 0.2304 - accuracy: 0.9037 - val_loss: 0.2797 - val_accuracy: 0.8934
#
# Epoch 00082: val_loss did not improve from 0.22938
# Epoch 83/220
# 31/31 - 4s - loss: 0.2374 - accuracy: 0.9012 - val_loss: 0.2862 - val_accuracy: 0.8853
#
# Epoch 00083: val_loss did not improve from 0.22938
# Epoch 84/220
# 31/31 - 4s - loss: 0.2132 - accuracy: 0.9148 - val_loss: 0.4240 - val_accuracy: 0.8089
#
# Epoch 00084: val_loss did not improve from 0.22938
# Epoch 85/220
# 31/31 - 4s - loss: 0.2345 - accuracy: 0.9037 - val_loss: 0.3117 - val_accuracy: 0.8672
#
# Epoch 00085: val_loss did not improve from 0.22938
# Epoch 86/220
# 31/31 - 4s - loss: 0.2116 - accuracy: 0.9138 - val_loss: 0.3035 - val_accuracy: 0.8773
#
# Epoch 00086: val_loss did not improve from 0.22938
# Epoch 87/220
# 31/31 - 4s - loss: 0.2238 - accuracy: 0.9118 - val_loss: 0.2646 - val_accuracy: 0.8873
#
# Epoch 00087: val_loss did not improve from 0.22938
# Epoch 88/220
# 31/31 - 4s - loss: 0.2237 - accuracy: 0.9052 - val_loss: 0.3983 - val_accuracy: 0.8451
#
# Epoch 00088: val_loss did not improve from 0.22938
# Epoch 89/220
# 31/31 - 4s - loss: 0.2335 - accuracy: 0.8992 - val_loss: 0.2657 - val_accuracy: 0.9034
#
# Epoch 00089: val_loss did not improve from 0.22938
# Epoch 90/220
# 31/31 - 4s - loss: 0.2105 - accuracy: 0.9103 - val_loss: 0.2841 - val_accuracy: 0.8913
#
# Epoch 00090: val_loss did not improve from 0.22938
# Epoch 91/220
# 31/31 - 4s - loss: 0.2327 - accuracy: 0.9007 - val_loss: 0.7163 - val_accuracy: 0.7425
#
# Epoch 00091: val_loss did not improve from 0.22938
# Epoch 92/220
# 31/31 - 4s - loss: 0.2265 - accuracy: 0.9037 - val_loss: 0.2698 - val_accuracy: 0.8793
#
# Epoch 00092: val_loss did not improve from 0.22938
# Epoch 93/220
# 31/31 - 4s - loss: 0.2139 - accuracy: 0.9118 - val_loss: 0.2644 - val_accuracy: 0.8913
#
# Epoch 00093: val_loss did not improve from 0.22938
# Epoch 94/220
# 31/31 - 4s - loss: 0.2130 - accuracy: 0.9138 - val_loss: 0.2873 - val_accuracy: 0.8873
#
# Epoch 00094: val_loss did not improve from 0.22938
# Epoch 95/220
# 31/31 - 4s - loss: 0.2031 - accuracy: 0.9209 - val_loss: 0.3946 - val_accuracy: 0.8330
#
# Epoch 00095: val_loss did not improve from 0.22938
# Epoch 96/220
# 31/31 - 4s - loss: 0.2068 - accuracy: 0.9128 - val_loss: 0.2394 - val_accuracy: 0.8974
#
# Epoch 00096: val_loss did not improve from 0.22938
# Epoch 97/220
# 31/31 - 4s - loss: 0.1969 - accuracy: 0.9229 - val_loss: 0.3192 - val_accuracy: 0.8531
#
# Epoch 00097: val_loss did not improve from 0.22938
# Epoch 98/220
# 31/31 - 4s - loss: 0.1949 - accuracy: 0.9138 - val_loss: 0.2983 - val_accuracy: 0.8813
#
# Epoch 00098: val_loss did not improve from 0.22938
# Epoch 99/220
# 31/31 - 4s - loss: 0.2164 - accuracy: 0.9022 - val_loss: 0.4513 - val_accuracy: 0.8229
#
# Epoch 00099: val_loss did not improve from 0.22938
# Epoch 100/220
# 31/31 - 4s - loss: 0.2188 - accuracy: 0.9098 - val_loss: 0.4712 - val_accuracy: 0.7988
#
# Epoch 00100: val_loss did not improve from 0.22938
# Epoch 101/220
# 31/31 - 4s - loss: 0.1996 - accuracy: 0.9153 - val_loss: 0.2877 - val_accuracy: 0.8672
#
# Epoch 00101: val_loss did not improve from 0.22938
# Epoch 102/220
# 31/31 - 4s - loss: 0.1867 - accuracy: 0.9244 - val_loss: 0.9964 - val_accuracy: 0.6640
#
# Epoch 00102: val_loss did not improve from 0.22938
# Epoch 103/220
# 31/31 - 4s - loss: 0.1907 - accuracy: 0.9234 - val_loss: 0.6079 - val_accuracy: 0.7867
#
# Epoch 00103: val_loss did not improve from 0.22938
# Epoch 104/220
# 31/31 - 4s - loss: 0.2141 - accuracy: 0.9148 - val_loss: 0.3193 - val_accuracy: 0.8672
#
# Epoch 00104: val_loss did not improve from 0.22938
# Epoch 105/220
# 31/31 - 4s - loss: 0.1848 - accuracy: 0.9224 - val_loss: 0.2260 - val_accuracy: 0.9175
#
# Epoch 00105: val_loss improved from 0.22938 to 0.22603, saving model to model.h5
# Epoch 106/220
# 31/31 - 4s - loss: 0.1994 - accuracy: 0.9178 - val_loss: 0.2286 - val_accuracy: 0.9054
#
# Epoch 00106: val_loss did not improve from 0.22603
# Epoch 107/220
# 31/31 - 4s - loss: 0.2046 - accuracy: 0.9123 - val_loss: 0.3005 - val_accuracy: 0.8692
#
# Epoch 00107: val_loss did not improve from 0.22603
# Epoch 108/220
# 31/31 - 4s - loss: 0.1954 - accuracy: 0.9153 - val_loss: 0.2097 - val_accuracy: 0.9296
#
# Epoch 00108: val_loss improved from 0.22603 to 0.20975, saving model to model.h5
# Epoch 109/220
# 31/31 - 4s - loss: 0.1894 - accuracy: 0.9194 - val_loss: 0.4637 - val_accuracy: 0.8048
#
# Epoch 00109: val_loss did not improve from 0.20975
# Epoch 110/220
# 31/31 - 4s - loss: 0.1888 - accuracy: 0.9274 - val_loss: 0.4488 - val_accuracy: 0.8068
#
# Epoch 00110: val_loss did not improve from 0.20975
# Epoch 111/220
# 31/31 - 4s - loss: 0.1918 - accuracy: 0.9183 - val_loss: 0.5397 - val_accuracy: 0.7887
#
# Epoch 00111: val_loss did not improve from 0.20975
# Epoch 112/220
# 31/31 - 4s - loss: 0.2000 - accuracy: 0.9199 - val_loss: 0.2200 - val_accuracy: 0.8974
#
# Epoch 00112: val_loss did not improve from 0.20975
# Epoch 113/220
# 31/31 - 4s - loss: 0.1836 - accuracy: 0.9309 - val_loss: 0.3324 - val_accuracy: 0.8511
#
# Epoch 00113: val_loss did not improve from 0.20975
# Epoch 114/220
# 31/31 - 4s - loss: 0.1922 - accuracy: 0.9199 - val_loss: 0.3499 - val_accuracy: 0.8652
#
# Epoch 00114: val_loss did not improve from 0.20975
# Epoch 115/220
# 31/31 - 4s - loss: 0.1795 - accuracy: 0.9299 - val_loss: 0.2599 - val_accuracy: 0.9014
#
# Epoch 00115: val_loss did not improve from 0.20975
# Epoch 116/220
# 31/31 - 4s - loss: 0.1625 - accuracy: 0.9360 - val_loss: 0.2621 - val_accuracy: 0.8954
#
# Epoch 00116: val_loss did not improve from 0.20975
# Epoch 117/220
# 31/31 - 4s - loss: 0.1661 - accuracy: 0.9304 - val_loss: 0.7385 - val_accuracy: 0.7565
#
# Epoch 00117: val_loss did not improve from 0.20975
# Epoch 118/220
# 31/31 - 4s - loss: 0.1786 - accuracy: 0.9294 - val_loss: 0.2399 - val_accuracy: 0.9034
#
# Epoch 00118: val_loss did not improve from 0.20975
# Epoch 119/220
# 31/31 - 4s - loss: 0.1798 - accuracy: 0.9264 - val_loss: 0.2731 - val_accuracy: 0.9074
#
# Epoch 00119: val_loss did not improve from 0.20975
# Epoch 120/220
# 31/31 - 4s - loss: 0.1761 - accuracy: 0.9204 - val_loss: 0.2633 - val_accuracy: 0.8994
#
# Epoch 00120: val_loss did not improve from 0.20975
# Epoch 121/220
# 31/31 - 4s - loss: 0.1867 - accuracy: 0.9194 - val_loss: 0.3721 - val_accuracy: 0.8451
#
# Epoch 00121: val_loss did not improve from 0.20975
# Epoch 122/220
# 31/31 - 4s - loss: 0.1735 - accuracy: 0.9289 - val_loss: 0.2478 - val_accuracy: 0.9195
#
# Epoch 00122: val_loss did not improve from 0.20975
# Epoch 123/220
# 31/31 - 4s - loss: 0.1897 - accuracy: 0.9214 - val_loss: 0.6046 - val_accuracy: 0.7726
#
# Epoch 00123: val_loss did not improve from 0.20975
# Epoch 124/220
# 31/31 - 4s - loss: 0.1661 - accuracy: 0.9325 - val_loss: 0.1747 - val_accuracy: 0.9296
#
# Epoch 00124: val_loss improved from 0.20975 to 0.17465, saving model to model.h5
# Epoch 125/220
# 31/31 - 4s - loss: 0.1750 - accuracy: 0.9299 - val_loss: 0.4068 - val_accuracy: 0.8270
#
# Epoch 00125: val_loss did not improve from 0.17465
# Epoch 126/220
# 31/31 - 4s - loss: 0.1562 - accuracy: 0.9350 - val_loss: 0.2460 - val_accuracy: 0.8893
#
# Epoch 00126: val_loss did not improve from 0.17465
# Epoch 127/220
# 31/31 - 4s - loss: 0.1636 - accuracy: 0.9340 - val_loss: 0.1972 - val_accuracy: 0.9356
#
# Epoch 00127: val_loss did not improve from 0.17465
# Epoch 128/220
# 31/31 - 4s - loss: 0.1679 - accuracy: 0.9325 - val_loss: 0.3987 - val_accuracy: 0.8652
#
# Epoch 00128: val_loss did not improve from 0.17465
# Epoch 129/220
# 31/31 - 4s - loss: 0.1697 - accuracy: 0.9320 - val_loss: 0.2804 - val_accuracy: 0.8712
#
# Epoch 00129: val_loss did not improve from 0.17465
# Epoch 130/220
# 31/31 - 4s - loss: 0.1692 - accuracy: 0.9284 - val_loss: 0.1802 - val_accuracy: 0.9356
#
# Epoch 00130: val_loss did not improve from 0.17465
# Epoch 131/220
# 31/31 - 4s - loss: 0.1437 - accuracy: 0.9370 - val_loss: 0.4238 - val_accuracy: 0.8511
#
# Epoch 00131: val_loss did not improve from 0.17465
# Epoch 132/220
# 31/31 - 4s - loss: 0.1487 - accuracy: 0.9380 - val_loss: 0.2143 - val_accuracy: 0.9175
#
# Epoch 00132: val_loss did not improve from 0.17465
# Epoch 133/220
# 31/31 - 4s - loss: 0.1616 - accuracy: 0.9380 - val_loss: 0.2175 - val_accuracy: 0.9135
#
# Epoch 00133: val_loss did not improve from 0.17465
# Epoch 134/220
# 31/31 - 4s - loss: 0.1583 - accuracy: 0.9320 - val_loss: 0.1563 - val_accuracy: 0.9316
#
# Epoch 00134: val_loss improved from 0.17465 to 0.15632, saving model to model.h5
# Epoch 135/220
# 31/31 - 4s - loss: 0.1463 - accuracy: 0.9420 - val_loss: 0.1933 - val_accuracy: 0.9215
#
# Epoch 00135: val_loss did not improve from 0.15632
# Epoch 136/220
# 31/31 - 4s - loss: 0.1387 - accuracy: 0.9385 - val_loss: 0.2095 - val_accuracy: 0.9195
#
# Epoch 00136: val_loss did not improve from 0.15632
# Epoch 137/220
# 31/31 - 4s - loss: 0.1652 - accuracy: 0.9304 - val_loss: 0.5087 - val_accuracy: 0.8129
#
# Epoch 00137: val_loss did not improve from 0.15632
# Epoch 138/220
# 31/31 - 4s - loss: 0.1438 - accuracy: 0.9385 - val_loss: 0.2809 - val_accuracy: 0.8672
#
# Epoch 00138: val_loss did not improve from 0.15632
# Epoch 139/220
# 31/31 - 4s - loss: 0.1287 - accuracy: 0.9516 - val_loss: 0.4078 - val_accuracy: 0.8330
#
# Epoch 00139: val_loss did not improve from 0.15632
# Epoch 140/220
# 31/31 - 4s - loss: 0.1681 - accuracy: 0.9335 - val_loss: 0.4361 - val_accuracy: 0.8330
#
# Epoch 00140: val_loss did not improve from 0.15632
# Epoch 141/220
# 31/31 - 4s - loss: 0.1377 - accuracy: 0.9461 - val_loss: 0.3917 - val_accuracy: 0.8330
#
# Epoch 00141: val_loss did not improve from 0.15632
# Epoch 142/220
# 31/31 - 4s - loss: 0.1453 - accuracy: 0.9410 - val_loss: 0.2721 - val_accuracy: 0.8994
#
# Epoch 00142: val_loss did not improve from 0.15632
# Epoch 143/220
# 31/31 - 4s - loss: 0.1418 - accuracy: 0.9471 - val_loss: 0.2840 - val_accuracy: 0.9175
#
# Epoch 00143: val_loss did not improve from 0.15632
# Epoch 144/220
# 31/31 - 4s - loss: 0.1441 - accuracy: 0.9446 - val_loss: 0.2177 - val_accuracy: 0.9256
#
# Epoch 00144: val_loss did not improve from 0.15632
# Epoch 145/220
# 31/31 - 4s - loss: 0.1331 - accuracy: 0.9496 - val_loss: 0.3187 - val_accuracy: 0.9135
#
# Epoch 00145: val_loss did not improve from 0.15632
# Epoch 146/220
# 31/31 - 4s - loss: 0.1401 - accuracy: 0.9435 - val_loss: 0.2012 - val_accuracy: 0.9155
#
# Epoch 00146: val_loss did not improve from 0.15632
# Epoch 147/220
# 31/31 - 4s - loss: 0.1398 - accuracy: 0.9420 - val_loss: 0.1317 - val_accuracy: 0.9457
#
# Epoch 00147: val_loss improved from 0.15632 to 0.13170, saving model to model.h5
# Epoch 148/220
# 31/31 - 4s - loss: 0.1401 - accuracy: 0.9435 - val_loss: 0.1329 - val_accuracy: 0.9517
#
# Epoch 00148: val_loss did not improve from 0.13170
# Epoch 149/220
# 31/31 - 4s - loss: 0.1344 - accuracy: 0.9461 - val_loss: 0.1751 - val_accuracy: 0.9396
#
# Epoch 00149: val_loss did not improve from 0.13170
# Epoch 150/220
# 31/31 - 4s - loss: 0.1529 - accuracy: 0.9420 - val_loss: 0.2251 - val_accuracy: 0.9175
#
# Epoch 00150: val_loss did not improve from 0.13170
# Epoch 151/220
# 31/31 - 4s - loss: 0.1329 - accuracy: 0.9476 - val_loss: 0.3902 - val_accuracy: 0.8793
#
# Epoch 00151: val_loss did not improve from 0.13170
# Epoch 152/220
# 31/31 - 4s - loss: 0.1306 - accuracy: 0.9461 - val_loss: 0.4443 - val_accuracy: 0.8632
#
# Epoch 00152: val_loss did not improve from 0.13170
# Epoch 153/220
# 31/31 - 4s - loss: 0.1354 - accuracy: 0.9511 - val_loss: 0.3245 - val_accuracy: 0.9074
#
# Epoch 00153: val_loss did not improve from 0.13170
# Epoch 154/220
# 31/31 - 4s - loss: 0.1295 - accuracy: 0.9481 - val_loss: 0.2104 - val_accuracy: 0.9296
#
# Epoch 00154: val_loss did not improve from 0.13170
# Epoch 155/220
# 31/31 - 4s - loss: 0.1269 - accuracy: 0.9476 - val_loss: 0.1279 - val_accuracy: 0.9517
#
# Epoch 00155: val_loss improved from 0.13170 to 0.12788, saving model to model.h5
# Epoch 156/220
# 31/31 - 4s - loss: 0.1301 - accuracy: 0.9466 - val_loss: 0.2942 - val_accuracy: 0.8773
#
# Epoch 00156: val_loss did not improve from 0.12788
# Epoch 157/220
# 31/31 - 4s - loss: 0.1415 - accuracy: 0.9370 - val_loss: 0.3619 - val_accuracy: 0.8672
#
# Epoch 00157: val_loss did not improve from 0.12788
# Epoch 158/220
# 31/31 - 4s - loss: 0.1303 - accuracy: 0.9466 - val_loss: 0.4137 - val_accuracy: 0.8471
#
# Epoch 00158: val_loss did not improve from 0.12788
# Epoch 159/220
# 31/31 - 4s - loss: 0.1138 - accuracy: 0.9572 - val_loss: 0.1462 - val_accuracy: 0.9416
#
# Epoch 00159: val_loss did not improve from 0.12788
# Epoch 160/220
# 31/31 - 4s - loss: 0.1166 - accuracy: 0.9551 - val_loss: 0.1300 - val_accuracy: 0.9437
#
# Epoch 00160: val_loss did not improve from 0.12788
# Epoch 161/220
# 31/31 - 4s - loss: 0.1192 - accuracy: 0.9496 - val_loss: 0.1493 - val_accuracy: 0.9376
#
# Epoch 00161: val_loss did not improve from 0.12788
# Epoch 162/220
# 31/31 - 4s - loss: 0.1142 - accuracy: 0.9536 - val_loss: 0.1617 - val_accuracy: 0.9477
#
# Epoch 00162: val_loss did not improve from 0.12788
# Epoch 163/220
# 31/31 - 4s - loss: 0.1202 - accuracy: 0.9556 - val_loss: 0.2196 - val_accuracy: 0.9235
#
# Epoch 00163: val_loss did not improve from 0.12788
# Epoch 164/220
# 31/31 - 4s - loss: 0.1038 - accuracy: 0.9587 - val_loss: 0.1745 - val_accuracy: 0.9416
#
# Epoch 00164: val_loss did not improve from 0.12788
# Epoch 165/220
# 31/31 - 4s - loss: 0.1163 - accuracy: 0.9506 - val_loss: 0.5699 - val_accuracy: 0.8068
#
# Epoch 00165: val_loss did not improve from 0.12788
# Epoch 166/220
# 31/31 - 4s - loss: 0.1196 - accuracy: 0.9496 - val_loss: 0.1641 - val_accuracy: 0.9396
#
# Epoch 00166: val_loss did not improve from 0.12788
# Epoch 167/220
# 31/31 - 4s - loss: 0.1108 - accuracy: 0.9587 - val_loss: 0.1385 - val_accuracy: 0.9557
#
# Epoch 00167: val_loss did not improve from 0.12788
# Epoch 168/220
# 31/31 - 4s - loss: 0.1097 - accuracy: 0.9506 - val_loss: 0.2682 - val_accuracy: 0.9014
#
# Epoch 00168: val_loss did not improve from 0.12788
# Epoch 169/220
# 31/31 - 4s - loss: 0.1255 - accuracy: 0.9486 - val_loss: 0.1301 - val_accuracy: 0.9618
#
# Epoch 00169: val_loss did not improve from 0.12788
# Epoch 170/220
# 31/31 - 4s - loss: 0.1027 - accuracy: 0.9647 - val_loss: 0.1477 - val_accuracy: 0.9577
#
# Epoch 00170: val_loss did not improve from 0.12788
# Epoch 171/220
# 31/31 - 4s - loss: 0.1191 - accuracy: 0.9521 - val_loss: 0.1718 - val_accuracy: 0.9296
#
# Epoch 00171: val_loss did not improve from 0.12788
# Epoch 172/220
# 31/31 - 4s - loss: 0.1116 - accuracy: 0.9526 - val_loss: 0.1282 - val_accuracy: 0.9598
#
# Epoch 00172: val_loss did not improve from 0.12788
# Epoch 173/220
# 31/31 - 4s - loss: 0.1086 - accuracy: 0.9556 - val_loss: 0.1225 - val_accuracy: 0.9618
#
# Epoch 00173: val_loss improved from 0.12788 to 0.12247, saving model to model.h5
# Epoch 174/220
# 31/31 - 4s - loss: 0.1027 - accuracy: 0.9607 - val_loss: 0.1483 - val_accuracy: 0.9517
#
# Epoch 00174: val_loss did not improve from 0.12247
# Epoch 175/220
# 31/31 - 4s - loss: 0.1029 - accuracy: 0.9577 - val_loss: 0.2754 - val_accuracy: 0.9115
#
# Epoch 00175: val_loss did not improve from 0.12247
# Epoch 176/220
# 31/31 - 4s - loss: 0.0892 - accuracy: 0.9632 - val_loss: 0.3444 - val_accuracy: 0.8773
#
# Epoch 00176: val_loss did not improve from 0.12247
# Epoch 177/220
# 31/31 - 4s - loss: 0.1014 - accuracy: 0.9597 - val_loss: 0.1330 - val_accuracy: 0.9457
#
# Epoch 00177: val_loss did not improve from 0.12247
# Epoch 178/220
# 31/31 - 4s - loss: 0.1062 - accuracy: 0.9567 - val_loss: 0.2066 - val_accuracy: 0.9437
#
# Epoch 00178: val_loss did not improve from 0.12247
# Epoch 179/220
# 31/31 - 4s - loss: 0.1277 - accuracy: 0.9506 - val_loss: 0.1348 - val_accuracy: 0.9537
#
# Epoch 00179: val_loss did not improve from 0.12247
# Epoch 180/220
# 31/31 - 4s - loss: 0.1083 - accuracy: 0.9577 - val_loss: 0.1093 - val_accuracy: 0.9618
#
# Epoch 00180: val_loss improved from 0.12247 to 0.10926, saving model to model.h5
# Epoch 181/220
# 31/31 - 4s - loss: 0.1061 - accuracy: 0.9577 - val_loss: 0.5082 - val_accuracy: 0.8209
#
# Epoch 00181: val_loss did not improve from 0.10926
# Epoch 182/220
# 31/31 - 4s - loss: 0.1054 - accuracy: 0.9592 - val_loss: 0.2390 - val_accuracy: 0.9235
#
# Epoch 00182: val_loss did not improve from 0.10926
# Epoch 183/220
# 31/31 - 4s - loss: 0.1079 - accuracy: 0.9577 - val_loss: 0.2080 - val_accuracy: 0.9115
#
# Epoch 00183: val_loss did not improve from 0.10926
# Epoch 184/220
# 31/31 - 4s - loss: 0.1270 - accuracy: 0.9506 - val_loss: 0.3555 - val_accuracy: 0.8813
#
# Epoch 00184: val_loss did not improve from 0.10926
# Epoch 185/220
# 31/31 - 4s - loss: 0.1013 - accuracy: 0.9662 - val_loss: 0.2556 - val_accuracy: 0.9014
#
# Epoch 00185: val_loss did not improve from 0.10926
# Epoch 186/220
# 31/31 - 4s - loss: 0.1006 - accuracy: 0.9642 - val_loss: 0.1921 - val_accuracy: 0.9215
#
# Epoch 00186: val_loss did not improve from 0.10926
# Epoch 187/220
# 31/31 - 4s - loss: 0.0960 - accuracy: 0.9627 - val_loss: 0.1755 - val_accuracy: 0.9195
#
# Epoch 00187: val_loss did not improve from 0.10926
# Epoch 188/220
# 31/31 - 4s - loss: 0.1094 - accuracy: 0.9577 - val_loss: 0.1377 - val_accuracy: 0.9537
#
# Epoch 00188: val_loss did not improve from 0.10926
# Epoch 189/220
# 31/31 - 4s - loss: 0.1012 - accuracy: 0.9597 - val_loss: 0.1426 - val_accuracy: 0.9577
#
# Epoch 00189: val_loss did not improve from 0.10926
# Epoch 190/220
# 31/31 - 4s - loss: 0.1075 - accuracy: 0.9592 - val_loss: 0.1471 - val_accuracy: 0.9376
#
# Epoch 00190: val_loss did not improve from 0.10926
# Epoch 191/220
# 31/31 - 4s - loss: 0.0915 - accuracy: 0.9652 - val_loss: 0.1311 - val_accuracy: 0.9437
#
# Epoch 00191: val_loss did not improve from 0.10926
# Epoch 192/220
# 31/31 - 4s - loss: 0.0922 - accuracy: 0.9672 - val_loss: 0.1620 - val_accuracy: 0.9376
#
# Epoch 00192: val_loss did not improve from 0.10926
# Epoch 193/220
# 31/31 - 4s - loss: 0.0956 - accuracy: 0.9647 - val_loss: 0.1433 - val_accuracy: 0.9477
#
# Epoch 00193: val_loss did not improve from 0.10926
# Epoch 194/220
# 31/31 - 4s - loss: 0.0908 - accuracy: 0.9662 - val_loss: 0.1470 - val_accuracy: 0.9296
#
# Epoch 00194: val_loss did not improve from 0.10926
# Epoch 195/220
# 31/31 - 4s - loss: 0.1070 - accuracy: 0.9602 - val_loss: 0.6117 - val_accuracy: 0.8008
#
# Epoch 00195: val_loss did not improve from 0.10926
# Epoch 196/220
# 31/31 - 4s - loss: 0.1002 - accuracy: 0.9657 - val_loss: 0.2142 - val_accuracy: 0.9175
#
# Epoch 00196: val_loss did not improve from 0.10926
# Epoch 197/220
# 31/31 - 4s - loss: 0.0900 - accuracy: 0.9647 - val_loss: 0.1700 - val_accuracy: 0.9416
#
# Epoch 00197: val_loss did not improve from 0.10926
# Epoch 198/220
# 31/31 - 4s - loss: 0.0890 - accuracy: 0.9677 - val_loss: 0.2413 - val_accuracy: 0.9155
#
# Epoch 00198: val_loss did not improve from 0.10926
# Epoch 199/220
# 31/31 - 4s - loss: 0.0962 - accuracy: 0.9592 - val_loss: 0.2735 - val_accuracy: 0.9014
#
# Epoch 00199: val_loss did not improve from 0.10926
# Epoch 200/220
# 31/31 - 4s - loss: 0.1031 - accuracy: 0.9567 - val_loss: 0.5903 - val_accuracy: 0.8189
#
# Epoch 00200: val_loss did not improve from 0.10926
# Epoch 201/220
# 31/31 - 4s - loss: 0.0864 - accuracy: 0.9662 - val_loss: 0.3348 - val_accuracy: 0.8893
#
# Epoch 00201: val_loss did not improve from 0.10926
# Epoch 202/220
# 31/31 - 4s - loss: 0.0885 - accuracy: 0.9632 - val_loss: 0.2589 - val_accuracy: 0.9155
#
# Epoch 00202: val_loss did not improve from 0.10926
# Epoch 203/220
# 31/31 - 4s - loss: 0.0928 - accuracy: 0.9597 - val_loss: 0.1552 - val_accuracy: 0.9416
#
# Epoch 00203: val_loss did not improve from 0.10926
# Epoch 204/220
# 31/31 - 4s - loss: 0.0897 - accuracy: 0.9667 - val_loss: 0.1964 - val_accuracy: 0.9195
#
# Epoch 00204: val_loss did not improve from 0.10926
# Epoch 205/220
# 31/31 - 4s - loss: 0.0926 - accuracy: 0.9607 - val_loss: 0.2294 - val_accuracy: 0.9074
#
# Epoch 00205: val_loss did not improve from 0.10926
# Epoch 206/220
# 31/31 - 4s - loss: 0.0979 - accuracy: 0.9657 - val_loss: 0.2490 - val_accuracy: 0.9095
#
# Epoch 00206: val_loss did not improve from 0.10926
# Epoch 207/220
# 31/31 - 4s - loss: 0.0838 - accuracy: 0.9723 - val_loss: 0.1178 - val_accuracy: 0.9557
#
# Epoch 00207: val_loss did not improve from 0.10926
# Epoch 208/220
# 31/31 - 4s - loss: 0.0859 - accuracy: 0.9708 - val_loss: 0.2130 - val_accuracy: 0.9135
#
# Epoch 00208: val_loss did not improve from 0.10926
# Epoch 209/220
# 31/31 - 4s - loss: 0.0845 - accuracy: 0.9698 - val_loss: 0.2309 - val_accuracy: 0.9054
#
# Epoch 00209: val_loss did not improve from 0.10926
# Epoch 210/220
# 31/31 - 4s - loss: 0.0871 - accuracy: 0.9677 - val_loss: 0.1181 - val_accuracy: 0.9577
#
# Epoch 00210: val_loss did not improve from 0.10926
# Epoch 211/220
# 31/31 - 4s - loss: 0.0947 - accuracy: 0.9632 - val_loss: 0.0998 - val_accuracy: 0.9678
#
# Epoch 00211: val_loss improved from 0.10926 to 0.09977, saving model to model.h5
# Epoch 212/220
# 31/31 - 4s - loss: 0.0842 - accuracy: 0.9642 - val_loss: 0.1896 - val_accuracy: 0.9215
#
# Epoch 00212: val_loss did not improve from 0.09977
# Epoch 213/220
# 31/31 - 4s - loss: 0.0855 - accuracy: 0.9698 - val_loss: 0.0934 - val_accuracy: 0.9658
#
# Epoch 00213: val_loss improved from 0.09977 to 0.09336, saving model to model.h5
# Epoch 214/220
# 31/31 - 4s - loss: 0.0992 - accuracy: 0.9617 - val_loss: 0.3002 - val_accuracy: 0.8934
#
# Epoch 00214: val_loss did not improve from 0.09336
# Epoch 215/220
# 31/31 - 4s - loss: 0.0838 - accuracy: 0.9667 - val_loss: 0.0994 - val_accuracy: 0.9618
#
# Epoch 00215: val_loss did not improve from 0.09336
# Epoch 216/220
# 31/31 - 4s - loss: 0.0704 - accuracy: 0.9693 - val_loss: 0.1235 - val_accuracy: 0.9457
#
# Epoch 00216: val_loss did not improve from 0.09336
# Epoch 217/220
# 31/31 - 4s - loss: 0.0831 - accuracy: 0.9652 - val_loss: 0.1161 - val_accuracy: 0.9537
#
# Epoch 00217: val_loss did not improve from 0.09336
# Epoch 218/220
# 31/31 - 4s - loss: 0.0829 - accuracy: 0.9708 - val_loss: 0.1336 - val_accuracy: 0.9457
#
# Epoch 00218: val_loss did not improve from 0.09336
# Epoch 219/220
# 31/31 - 4s - loss: 0.0812 - accuracy: 0.9662 - val_loss: 0.0999 - val_accuracy: 0.9598
#
# Epoch 00219: val_loss did not improve from 0.09336
# Epoch 220/220
# 31/31 - 4s - loss: 0.0846 - accuracy: 0.9662 - val_loss: 0.0776 - val_accuracy: 0.9678
#
# Epoch 00220: val_loss improved from 0.09336 to 0.07756, saving model to model.h5

# %%
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0776 - accuracy: 0.9678
# Final Loss: 0.07755715399980545, Final Accuracy: 0.9678068161010742

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 145.31999999999996, 'Predicted')

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

print('Precision: %f' % precision_score(Y_true, Y_pred))
print('Recall: %f' % recall_score(Y_true, Y_pred))
print('F1 Score: %f' % f1_score(Y_true, Y_pred))
print('Accuracy: %f' % accuracy_score(Y_true, Y_pred))
# Out:
# Precision: 0.960000
# Recall: 0.968610
# F1 Score: 0.964286
# Accuracy: 0.967807

# %%
from sklearn.metrics import classification_report, confusion_matrix

Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

print( classification_report(Y_true, Y_pred))
print(confusion_matrix(Y_true, Y_pred))
sns.heatmap(confusion_matrix(Y_true, Y_pred), annot = True)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       274
#            1       0.96      0.97      0.96       223
#
#     accuracy                           0.97       497
#    macro avg       0.97      0.97      0.97       497
# weighted avg       0.97      0.97      0.97       497
#
# [[265   9]
#  [  7 216]]

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from skimage import io
from keras.preprocessing import image
#path='imbalanced/Scratch/Scratch_400.jpg'
img = image.load_img('/content/COVID/Covid (1010).png', grayscale=False, target_size=(64, 64))
show_img=image.load_img('/content/COVID/Covid (1010).png', grayscale=False, target_size=(200, 200))
disease_class=['Covid-19','Non Covid-19']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255

custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [9.9995804e-01 4.2007574e-05]
# Prediction: Covid-19

# %%
from skimage import io
from keras.preprocessing import image
#path='imbalanced/Scratch/Scratch_400.jpg'
img = image.load_img('/content/non-COVID/Non-Covid (1007).png', grayscale=False, target_size=(64, 64))
show_img=image.load_img('/content/non-COVID/Non-Covid (1007).png', grayscale=False, target_size=(200, 200))
disease_class=['Covid-19','Non Covid-19']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255

custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [0.7630779  0.23692206]
# Prediction: Covid-19
