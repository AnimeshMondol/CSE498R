# %% [markdown]
# <a href="https://colab.research.google.com/github/AnimeshMondol/CSE498R/blob/main/epo700(new)2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sat Jun 19 13:52:38 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.5.30)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2ffd194c-8adc-452a-9d5b-db6c79e93506" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2ffd194c-8adc-452a-9d5b-db6c79e93506">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"animeshmondol","key":"c4507c33debf7afb770d35a343bfcbcc"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle

#Change permission
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d plameneduardo/sarscov2-ctscan-dataset
# Out:
# Downloading sarscov2-ctscan-dataset.zip to /content
#  99% 228M/230M [00:02<00:00, 110MB/s]
# 100% 230M/230M [00:02<00:00, 88.7MB/s]

# %%
from zipfile import ZipFile
file_name = "sarscov2-ctscan-dataset.zip"

with ZipFile(file_name,"r") as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
        #print(os.path.join(dirname, filename))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.densenet import DenseNet121

# %%
disease_types=['COVID', 'non-COVID']
data_dir = '/content'
train_dir = os.path.join(data_dir)

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.head()
# Out:
#                     File  DiseaseID Disease Type
# 0   COVID/Covid (78).png          0        COVID
# 1  COVID/Covid (388).png          0        COVID
# 2   COVID/Covid (72).png          0        COVID
# 3  COVID/Covid (318).png          0        COVID
# 4  COVID/Covid (118).png          0        COVID

# %%
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#                             File  DiseaseID Disease Type
# 0          COVID/Covid (237).png          0        COVID
# 1          COVID/Covid (772).png          0        COVID
# 2  non-COVID/Non-Covid (386).png          1    non-COVID
# 3   non-COVID/Non-Covid (94).png          1    non-COVID
# 4          COVID/Covid (147).png          0        COVID

# %%
plt.hist(train['DiseaseID'])
plt.title('Frequency Histogram of Species')
plt.figure(figsize=(12, 12))
plt.show()

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('COVID', 5, 5)

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('non-COVID', 5, 5)

# %%
IMAGE_SIZE = 64
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 2481it [00:07, 322.69it/s]
# Train Shape: (2481, 64, 64, 3)

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=2)

# %%
BATCH_SIZE = 64

# Split the train and validation sets 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 15))
for i in range(3):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(disease_types[np.argmax(Y_train[i])])

# %%
EPOCHS = 700
SIZE=64
N_ch=3

# %%
def build_densenet():
    densenet = DenseNet121(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = densenet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    optimizer = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
model = build_densenet()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        zoom_range=0.2, # Range for random zoom
                        horizontal_flip=True, # Randomly flip inputs horizontally
                        vertical_flip=True) # Randomly flip inputs vertically

datagen.fit(X_train)
# Fits the model on batches with real-time data augmentation
hist = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 3)         84
# _________________________________________________________________
# densenet121 (Functional)     (None, None, None, 1024)  7037504
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               262400
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# root (Dense)                 (None, 2)                 514
# =================================================================
# Total params: 7,305,622
# Trainable params: 7,219,414
# Non-trainable params: 86,208
# _________________________________________________________________
# Epoch 1/700
# 31/31 - 38s - loss: 1.1491 - accuracy: 0.5343 - val_loss: 0.8845 - val_accuracy: 0.4427
#
# Epoch 00001: val_loss improved from inf to 0.88451, saving model to model.h5
# Epoch 2/700
# 31/31 - 4s - loss: 0.9687 - accuracy: 0.5978 - val_loss: 0.7374 - val_accuracy: 0.5372
#
# Epoch 00002: val_loss improved from 0.88451 to 0.73736, saving model to model.h5
# Epoch 3/700
# 31/31 - 4s - loss: 0.8067 - accuracy: 0.6699 - val_loss: 0.7314 - val_accuracy: 0.5614
#
# Epoch 00003: val_loss improved from 0.73736 to 0.73136, saving model to model.h5
# Epoch 4/700
# 31/31 - 4s - loss: 0.7844 - accuracy: 0.6799 - val_loss: 0.7787 - val_accuracy: 0.5976
#
# Epoch 00004: val_loss did not improve from 0.73136
# Epoch 5/700
# 31/31 - 4s - loss: 0.6792 - accuracy: 0.7001 - val_loss: 0.7407 - val_accuracy: 0.5956
#
# Epoch 00005: val_loss did not improve from 0.73136
# Epoch 6/700
# 31/31 - 4s - loss: 0.5968 - accuracy: 0.7384 - val_loss: 0.8149 - val_accuracy: 0.5594
#
# Epoch 00006: val_loss did not improve from 0.73136
# Epoch 7/700
# 31/31 - 4s - loss: 0.6320 - accuracy: 0.7379 - val_loss: 0.9149 - val_accuracy: 0.5453
#
# Epoch 00007: val_loss did not improve from 0.73136
# Epoch 8/700
# 31/31 - 4s - loss: 0.5546 - accuracy: 0.7606 - val_loss: 0.9246 - val_accuracy: 0.5674
#
# Epoch 00008: val_loss did not improve from 0.73136
# Epoch 9/700
# 31/31 - 4s - loss: 0.5151 - accuracy: 0.7767 - val_loss: 0.6979 - val_accuracy: 0.6439
#
# Epoch 00009: val_loss improved from 0.73136 to 0.69791, saving model to model.h5
# Epoch 10/700
# 31/31 - 4s - loss: 0.4798 - accuracy: 0.7999 - val_loss: 1.0145 - val_accuracy: 0.5674
#
# Epoch 00010: val_loss did not improve from 0.69791
# Epoch 11/700
# 31/31 - 4s - loss: 0.4577 - accuracy: 0.8100 - val_loss: 0.4739 - val_accuracy: 0.7545
#
# Epoch 00011: val_loss improved from 0.69791 to 0.47391, saving model to model.h5
# Epoch 12/700
# 31/31 - 4s - loss: 0.4217 - accuracy: 0.8185 - val_loss: 0.3797 - val_accuracy: 0.8431
#
# Epoch 00012: val_loss improved from 0.47391 to 0.37973, saving model to model.h5
# Epoch 13/700
# 31/31 - 4s - loss: 0.4150 - accuracy: 0.8196 - val_loss: 0.6135 - val_accuracy: 0.6881
#
# Epoch 00013: val_loss did not improve from 0.37973
# Epoch 14/700
# 31/31 - 4s - loss: 0.4014 - accuracy: 0.8362 - val_loss: 0.7054 - val_accuracy: 0.6781
#
# Epoch 00014: val_loss did not improve from 0.37973
# Epoch 15/700
# 31/31 - 4s - loss: 0.3758 - accuracy: 0.8392 - val_loss: 0.3757 - val_accuracy: 0.8310
#
# Epoch 00015: val_loss improved from 0.37973 to 0.37568, saving model to model.h5
# Epoch 16/700
# 31/31 - 4s - loss: 0.3342 - accuracy: 0.8614 - val_loss: 0.4283 - val_accuracy: 0.7827
#
# Epoch 00016: val_loss did not improve from 0.37568
# Epoch 17/700
# 31/31 - 4s - loss: 0.3424 - accuracy: 0.8649 - val_loss: 0.3873 - val_accuracy: 0.8048
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 00017: val_loss did not improve from 0.37568
# Epoch 18/700
# 31/31 - 4s - loss: 0.3337 - accuracy: 0.8579 - val_loss: 0.3131 - val_accuracy: 0.8773
#
# Epoch 00018: val_loss improved from 0.37568 to 0.31309, saving model to model.h5
# Epoch 19/700
# 31/31 - 4s - loss: 0.3215 - accuracy: 0.8690 - val_loss: 0.3106 - val_accuracy: 0.8793
#
# Epoch 00019: val_loss improved from 0.31309 to 0.31063, saving model to model.h5
# Epoch 20/700
# 31/31 - 4s - loss: 0.2986 - accuracy: 0.8816 - val_loss: 0.3150 - val_accuracy: 0.8813
#
# Epoch 00020: val_loss did not improve from 0.31063
# Epoch 21/700
# 31/31 - 4s - loss: 0.3125 - accuracy: 0.8750 - val_loss: 0.2957 - val_accuracy: 0.8813
#
# Epoch 00021: val_loss improved from 0.31063 to 0.29568, saving model to model.h5
# Epoch 22/700
# 31/31 - 4s - loss: 0.3142 - accuracy: 0.8720 - val_loss: 0.3068 - val_accuracy: 0.8672
#
# Epoch 00022: val_loss did not improve from 0.29568
# Epoch 23/700
# 31/31 - 4s - loss: 0.2978 - accuracy: 0.8695 - val_loss: 0.3038 - val_accuracy: 0.8712
#
# Epoch 00023: val_loss did not improve from 0.29568
# Epoch 24/700
# 31/31 - 4s - loss: 0.3034 - accuracy: 0.8800 - val_loss: 0.2980 - val_accuracy: 0.8773
#
# Epoch 00024: val_loss did not improve from 0.29568
# Epoch 25/700
# 31/31 - 4s - loss: 0.2927 - accuracy: 0.8851 - val_loss: 0.3058 - val_accuracy: 0.8753
#
# Epoch 00025: val_loss did not improve from 0.29568
# Epoch 26/700
# 31/31 - 4s - loss: 0.2847 - accuracy: 0.8790 - val_loss: 0.3168 - val_accuracy: 0.8793
#
# Epoch 00026: val_loss did not improve from 0.29568
# Epoch 27/700
# 31/31 - 4s - loss: 0.2867 - accuracy: 0.8780 - val_loss: 0.3402 - val_accuracy: 0.8793
#
# Epoch 00027: val_loss did not improve from 0.29568
# Epoch 28/700
# 31/31 - 4s - loss: 0.2943 - accuracy: 0.8760 - val_loss: 0.3103 - val_accuracy: 0.8833
#
# Epoch 00028: val_loss did not improve from 0.29568
# Epoch 29/700
# 31/31 - 4s - loss: 0.2911 - accuracy: 0.8800 - val_loss: 0.2918 - val_accuracy: 0.8913
#
# Epoch 00029: val_loss improved from 0.29568 to 0.29177, saving model to model.h5
# Epoch 30/700
# 31/31 - 4s - loss: 0.2794 - accuracy: 0.8795 - val_loss: 0.4168 - val_accuracy: 0.7907
#
# Epoch 00030: val_loss did not improve from 0.29177
# Epoch 31/700
# 31/31 - 4s - loss: 0.2657 - accuracy: 0.8947 - val_loss: 0.3096 - val_accuracy: 0.8873
#
# Epoch 00031: val_loss did not improve from 0.29177
# Epoch 32/700
# 31/31 - 4s - loss: 0.2775 - accuracy: 0.8901 - val_loss: 0.3505 - val_accuracy: 0.8471
#
# Epoch 00032: val_loss did not improve from 0.29177
# Epoch 33/700
# 31/31 - 4s - loss: 0.2721 - accuracy: 0.8906 - val_loss: 0.2903 - val_accuracy: 0.8934
#
# Epoch 00033: val_loss improved from 0.29177 to 0.29030, saving model to model.h5
# Epoch 34/700
# 31/31 - 4s - loss: 0.2530 - accuracy: 0.8936 - val_loss: 0.2955 - val_accuracy: 0.8893
#
# Epoch 00034: val_loss did not improve from 0.29030
# Epoch 35/700
# 31/31 - 4s - loss: 0.2592 - accuracy: 0.8936 - val_loss: 0.4479 - val_accuracy: 0.7968
#
# Epoch 00035: val_loss did not improve from 0.29030
# Epoch 36/700
# 31/31 - 4s - loss: 0.2605 - accuracy: 0.8881 - val_loss: 0.3336 - val_accuracy: 0.8712
#
# Epoch 00036: val_loss did not improve from 0.29030
# Epoch 37/700
# 31/31 - 4s - loss: 0.2585 - accuracy: 0.8962 - val_loss: 0.3134 - val_accuracy: 0.8773
#
# Epoch 00037: val_loss did not improve from 0.29030
# Epoch 38/700
# 31/31 - 4s - loss: 0.2508 - accuracy: 0.8952 - val_loss: 0.4635 - val_accuracy: 0.7928
#
# Epoch 00038: val_loss did not improve from 0.29030
# Epoch 39/700
# 31/31 - 4s - loss: 0.2620 - accuracy: 0.8921 - val_loss: 0.2921 - val_accuracy: 0.8934
#
# Epoch 00039: val_loss did not improve from 0.29030
# Epoch 40/700
# 31/31 - 4s - loss: 0.2566 - accuracy: 0.8982 - val_loss: 0.3143 - val_accuracy: 0.8632
#
# Epoch 00040: val_loss did not improve from 0.29030
# Epoch 41/700
# 31/31 - 4s - loss: 0.2550 - accuracy: 0.8876 - val_loss: 0.2637 - val_accuracy: 0.9054
#
# Epoch 00041: val_loss improved from 0.29030 to 0.26365, saving model to model.h5
# Epoch 42/700
# 31/31 - 4s - loss: 0.2519 - accuracy: 0.8947 - val_loss: 0.3528 - val_accuracy: 0.8270
#
# Epoch 00042: val_loss did not improve from 0.26365
# Epoch 43/700
# 31/31 - 4s - loss: 0.2485 - accuracy: 0.8982 - val_loss: 0.3401 - val_accuracy: 0.8833
#
# Epoch 00043: val_loss did not improve from 0.26365
# Epoch 44/700
# 31/31 - 4s - loss: 0.2424 - accuracy: 0.8992 - val_loss: 0.2858 - val_accuracy: 0.8773
#
# Epoch 00044: val_loss did not improve from 0.26365
# Epoch 45/700
# 31/31 - 4s - loss: 0.2309 - accuracy: 0.9047 - val_loss: 0.3670 - val_accuracy: 0.8270
#
# Epoch 00045: val_loss did not improve from 0.26365
# Epoch 46/700
# 31/31 - 4s - loss: 0.2232 - accuracy: 0.9032 - val_loss: 0.2985 - val_accuracy: 0.8712
#
# Epoch 00046: val_loss did not improve from 0.26365
# Epoch 47/700
# 31/31 - 4s - loss: 0.2237 - accuracy: 0.9093 - val_loss: 0.3379 - val_accuracy: 0.8431
#
# Epoch 00047: val_loss did not improve from 0.26365
# Epoch 48/700
# 31/31 - 4s - loss: 0.2283 - accuracy: 0.8997 - val_loss: 0.2658 - val_accuracy: 0.9054
#
# Epoch 00048: val_loss did not improve from 0.26365
# Epoch 49/700
# 31/31 - 4s - loss: 0.2347 - accuracy: 0.8987 - val_loss: 0.2460 - val_accuracy: 0.9115
#
# Epoch 00049: val_loss improved from 0.26365 to 0.24601, saving model to model.h5
# Epoch 50/700
# 31/31 - 4s - loss: 0.2334 - accuracy: 0.9052 - val_loss: 0.2572 - val_accuracy: 0.8913
#
# Epoch 00050: val_loss did not improve from 0.24601
# Epoch 51/700
# 31/31 - 4s - loss: 0.2314 - accuracy: 0.9098 - val_loss: 0.2539 - val_accuracy: 0.9014
#
# Epoch 00051: val_loss did not improve from 0.24601
# Epoch 52/700
# 31/31 - 4s - loss: 0.2331 - accuracy: 0.9012 - val_loss: 0.2663 - val_accuracy: 0.9034
#
# Epoch 00052: val_loss did not improve from 0.24601
# Epoch 53/700
# 31/31 - 4s - loss: 0.2058 - accuracy: 0.9143 - val_loss: 0.2621 - val_accuracy: 0.8934
#
# Epoch 00053: val_loss did not improve from 0.24601
# Epoch 54/700
# 31/31 - 4s - loss: 0.2110 - accuracy: 0.9138 - val_loss: 0.2741 - val_accuracy: 0.8793
#
# Epoch 00054: val_loss did not improve from 0.24601
# Epoch 55/700
# 31/31 - 4s - loss: 0.2094 - accuracy: 0.9123 - val_loss: 0.2612 - val_accuracy: 0.8833
#
# Epoch 00055: val_loss did not improve from 0.24601
# Epoch 56/700
# 31/31 - 4s - loss: 0.2120 - accuracy: 0.9123 - val_loss: 0.2932 - val_accuracy: 0.8913
#
# Epoch 00056: val_loss did not improve from 0.24601
# Epoch 57/700
# 31/31 - 4s - loss: 0.2184 - accuracy: 0.9083 - val_loss: 0.2696 - val_accuracy: 0.8893
#
# Epoch 00057: val_loss did not improve from 0.24601
# Epoch 58/700
# 31/31 - 4s - loss: 0.2077 - accuracy: 0.9098 - val_loss: 0.2505 - val_accuracy: 0.9115
#
# Epoch 00058: val_loss did not improve from 0.24601
# Epoch 59/700
# 31/31 - 4s - loss: 0.1981 - accuracy: 0.9178 - val_loss: 0.2262 - val_accuracy: 0.9095
#
# Epoch 00059: val_loss improved from 0.24601 to 0.22620, saving model to model.h5
# Epoch 60/700
# 31/31 - 4s - loss: 0.2066 - accuracy: 0.9153 - val_loss: 0.2140 - val_accuracy: 0.9215
#
# Epoch 00060: val_loss improved from 0.22620 to 0.21397, saving model to model.h5
# Epoch 61/700
# 31/31 - 4s - loss: 0.2154 - accuracy: 0.9093 - val_loss: 0.2736 - val_accuracy: 0.8974
#
# Epoch 00061: val_loss did not improve from 0.21397
# Epoch 62/700
# 31/31 - 4s - loss: 0.2082 - accuracy: 0.9204 - val_loss: 0.2430 - val_accuracy: 0.8954
#
# Epoch 00062: val_loss did not improve from 0.21397
# Epoch 63/700
# 31/31 - 4s - loss: 0.2070 - accuracy: 0.9178 - val_loss: 0.2330 - val_accuracy: 0.9034
#
# Epoch 00063: val_loss did not improve from 0.21397
# Epoch 64/700
# 31/31 - 4s - loss: 0.2013 - accuracy: 0.9163 - val_loss: 0.2243 - val_accuracy: 0.9155
#
# Epoch 00064: val_loss did not improve from 0.21397
# Epoch 65/700
# 31/31 - 4s - loss: 0.2049 - accuracy: 0.9153 - val_loss: 0.2233 - val_accuracy: 0.9095
#
# Epoch 00065: val_loss did not improve from 0.21397
# Epoch 66/700
# 31/31 - 4s - loss: 0.1918 - accuracy: 0.9219 - val_loss: 0.2389 - val_accuracy: 0.8974
#
# Epoch 00066: val_loss did not improve from 0.21397
# Epoch 67/700
# 31/31 - 4s - loss: 0.1898 - accuracy: 0.9229 - val_loss: 0.4979 - val_accuracy: 0.7847
#
# Epoch 00067: val_loss did not improve from 0.21397
# Epoch 68/700
# 31/31 - 4s - loss: 0.2005 - accuracy: 0.9163 - val_loss: 0.8078 - val_accuracy: 0.7082
#
# Epoch 00068: val_loss did not improve from 0.21397
# Epoch 69/700
# 31/31 - 4s - loss: 0.1904 - accuracy: 0.9189 - val_loss: 0.3311 - val_accuracy: 0.8773
#
# Epoch 00069: val_loss did not improve from 0.21397
# Epoch 70/700
# 31/31 - 4s - loss: 0.1807 - accuracy: 0.9269 - val_loss: 0.3077 - val_accuracy: 0.8652
#
# Epoch 00070: val_loss did not improve from 0.21397
# Epoch 71/700
# 31/31 - 4s - loss: 0.1906 - accuracy: 0.9249 - val_loss: 0.2601 - val_accuracy: 0.8893
#
# Epoch 00071: val_loss did not improve from 0.21397
# Epoch 72/700
# 31/31 - 4s - loss: 0.1839 - accuracy: 0.9209 - val_loss: 0.4343 - val_accuracy: 0.8632
#
# Epoch 00072: val_loss did not improve from 0.21397
# Epoch 73/700
# 31/31 - 4s - loss: 0.1884 - accuracy: 0.9133 - val_loss: 0.5263 - val_accuracy: 0.8370
#
# Epoch 00073: val_loss did not improve from 0.21397
# Epoch 74/700
# 31/31 - 4s - loss: 0.1889 - accuracy: 0.9264 - val_loss: 0.3011 - val_accuracy: 0.8913
#
# Epoch 00074: val_loss did not improve from 0.21397
# Epoch 75/700
# 31/31 - 4s - loss: 0.1967 - accuracy: 0.9189 - val_loss: 0.2635 - val_accuracy: 0.9014
#
# Epoch 00075: val_loss did not improve from 0.21397
# Epoch 76/700
# 31/31 - 4s - loss: 0.1706 - accuracy: 0.9289 - val_loss: 0.2396 - val_accuracy: 0.9155
#
# Epoch 00076: val_loss did not improve from 0.21397
# Epoch 77/700
# 31/31 - 4s - loss: 0.1756 - accuracy: 0.9289 - val_loss: 0.2328 - val_accuracy: 0.9195
#
# Epoch 00077: val_loss did not improve from 0.21397
# Epoch 78/700
# 31/31 - 4s - loss: 0.1711 - accuracy: 0.9304 - val_loss: 0.2324 - val_accuracy: 0.9095
#
# Epoch 00078: val_loss did not improve from 0.21397
# Epoch 79/700
# 31/31 - 4s - loss: 0.1826 - accuracy: 0.9229 - val_loss: 0.1997 - val_accuracy: 0.9155
#
# Epoch 00079: val_loss improved from 0.21397 to 0.19968, saving model to model.h5
# Epoch 80/700
# 31/31 - 4s - loss: 0.1648 - accuracy: 0.9365 - val_loss: 0.2879 - val_accuracy: 0.8672
#
# Epoch 00080: val_loss did not improve from 0.19968
# Epoch 81/700
# 31/31 - 4s - loss: 0.1673 - accuracy: 0.9279 - val_loss: 0.7908 - val_accuracy: 0.7324
#
# Epoch 00081: val_loss did not improve from 0.19968
# Epoch 82/700
# 31/31 - 4s - loss: 0.1483 - accuracy: 0.9420 - val_loss: 0.4269 - val_accuracy: 0.8149
#
# Epoch 00082: val_loss did not improve from 0.19968
# Epoch 83/700
# 31/31 - 4s - loss: 0.1504 - accuracy: 0.9350 - val_loss: 0.2428 - val_accuracy: 0.8974
#
# Epoch 00083: val_loss did not improve from 0.19968
# Epoch 84/700
# 31/31 - 4s - loss: 0.1681 - accuracy: 0.9284 - val_loss: 0.9167 - val_accuracy: 0.7123
#
# Epoch 00084: val_loss did not improve from 0.19968
# Epoch 85/700
# 31/31 - 4s - loss: 0.1433 - accuracy: 0.9425 - val_loss: 0.5221 - val_accuracy: 0.7847
#
# Epoch 00085: val_loss did not improve from 0.19968
# Epoch 86/700
# 31/31 - 4s - loss: 0.1671 - accuracy: 0.9355 - val_loss: 0.3057 - val_accuracy: 0.8632
#
# Epoch 00086: val_loss did not improve from 0.19968
# Epoch 87/700
# 31/31 - 4s - loss: 0.1681 - accuracy: 0.9350 - val_loss: 0.2486 - val_accuracy: 0.9135
#
# Epoch 00087: val_loss did not improve from 0.19968
# Epoch 88/700
# 31/31 - 4s - loss: 0.1726 - accuracy: 0.9299 - val_loss: 0.3851 - val_accuracy: 0.8732
#
# Epoch 00088: val_loss did not improve from 0.19968
# Epoch 89/700
# 31/31 - 4s - loss: 0.1534 - accuracy: 0.9365 - val_loss: 0.4865 - val_accuracy: 0.8048
#
# Epoch 00089: val_loss did not improve from 0.19968
# Epoch 90/700
# 31/31 - 4s - loss: 0.1524 - accuracy: 0.9405 - val_loss: 0.7368 - val_accuracy: 0.7465
#
# Epoch 00090: val_loss did not improve from 0.19968
# Epoch 91/700
# 31/31 - 4s - loss: 0.1719 - accuracy: 0.9315 - val_loss: 0.2830 - val_accuracy: 0.9034
#
# Epoch 00091: val_loss did not improve from 0.19968
# Epoch 92/700
# 31/31 - 4s - loss: 0.1424 - accuracy: 0.9430 - val_loss: 0.2420 - val_accuracy: 0.9276
#
# Epoch 00092: val_loss did not improve from 0.19968
# Epoch 93/700
# 31/31 - 4s - loss: 0.1395 - accuracy: 0.9471 - val_loss: 0.2397 - val_accuracy: 0.9115
#
# Epoch 00093: val_loss did not improve from 0.19968
# Epoch 94/700
# 31/31 - 4s - loss: 0.1791 - accuracy: 0.9279 - val_loss: 0.3754 - val_accuracy: 0.8551
#
# Epoch 00094: val_loss did not improve from 0.19968
# Epoch 95/700
# 31/31 - 4s - loss: 0.1625 - accuracy: 0.9330 - val_loss: 0.1940 - val_accuracy: 0.9336
#
# Epoch 00095: val_loss improved from 0.19968 to 0.19400, saving model to model.h5
# Epoch 96/700
# 31/31 - 4s - loss: 0.1611 - accuracy: 0.9355 - val_loss: 0.1939 - val_accuracy: 0.9376
#
# Epoch 00096: val_loss improved from 0.19400 to 0.19389, saving model to model.h5
# Epoch 97/700
# 31/31 - 4s - loss: 0.1399 - accuracy: 0.9441 - val_loss: 0.1746 - val_accuracy: 0.9457
#
# Epoch 00097: val_loss improved from 0.19389 to 0.17457, saving model to model.h5
# Epoch 98/700
# 31/31 - 4s - loss: 0.1538 - accuracy: 0.9375 - val_loss: 0.1652 - val_accuracy: 0.9376
#
# Epoch 00098: val_loss improved from 0.17457 to 0.16516, saving model to model.h5
# Epoch 99/700
# 31/31 - 4s - loss: 0.1497 - accuracy: 0.9395 - val_loss: 0.2561 - val_accuracy: 0.8934
#
# Epoch 00099: val_loss did not improve from 0.16516
# Epoch 100/700
# 31/31 - 4s - loss: 0.1273 - accuracy: 0.9491 - val_loss: 0.2435 - val_accuracy: 0.9095
#
# Epoch 00100: val_loss did not improve from 0.16516
# Epoch 101/700
# 31/31 - 4s - loss: 0.1354 - accuracy: 0.9420 - val_loss: 0.3009 - val_accuracy: 0.8732
#
# Epoch 00101: val_loss did not improve from 0.16516
# Epoch 102/700
# 31/31 - 4s - loss: 0.1449 - accuracy: 0.9395 - val_loss: 0.1849 - val_accuracy: 0.9235
#
# Epoch 00102: val_loss did not improve from 0.16516
# Epoch 103/700
# 31/31 - 4s - loss: 0.1340 - accuracy: 0.9451 - val_loss: 0.2036 - val_accuracy: 0.9155
#
# Epoch 00103: val_loss did not improve from 0.16516
# Epoch 104/700
# 31/31 - 4s - loss: 0.1489 - accuracy: 0.9375 - val_loss: 0.2992 - val_accuracy: 0.8773
#
# Epoch 00104: val_loss did not improve from 0.16516
# Epoch 105/700
# 31/31 - 4s - loss: 0.1269 - accuracy: 0.9496 - val_loss: 0.2533 - val_accuracy: 0.9014
#
# Epoch 00105: val_loss did not improve from 0.16516
# Epoch 106/700
# 31/31 - 4s - loss: 0.1425 - accuracy: 0.9461 - val_loss: 0.5506 - val_accuracy: 0.7988
#
# Epoch 00106: val_loss did not improve from 0.16516
# Epoch 107/700
# 31/31 - 4s - loss: 0.1433 - accuracy: 0.9425 - val_loss: 0.2090 - val_accuracy: 0.9336
#
# Epoch 00107: val_loss did not improve from 0.16516
# Epoch 108/700
# 31/31 - 4s - loss: 0.1368 - accuracy: 0.9430 - val_loss: 0.2084 - val_accuracy: 0.9336
#
# Epoch 00108: val_loss did not improve from 0.16516
# Epoch 109/700
# 31/31 - 4s - loss: 0.1263 - accuracy: 0.9471 - val_loss: 0.4607 - val_accuracy: 0.8632
#
# Epoch 00109: val_loss did not improve from 0.16516
# Epoch 110/700
# 31/31 - 4s - loss: 0.1354 - accuracy: 0.9466 - val_loss: 0.2892 - val_accuracy: 0.9054
#
# Epoch 00110: val_loss did not improve from 0.16516
# Epoch 111/700
# 31/31 - 4s - loss: 0.1277 - accuracy: 0.9491 - val_loss: 0.2493 - val_accuracy: 0.9074
#
# Epoch 00111: val_loss did not improve from 0.16516
# Epoch 112/700
# 31/31 - 4s - loss: 0.1169 - accuracy: 0.9521 - val_loss: 0.2372 - val_accuracy: 0.9175
#
# Epoch 00112: val_loss did not improve from 0.16516
# Epoch 113/700
# 31/31 - 4s - loss: 0.1235 - accuracy: 0.9506 - val_loss: 0.3136 - val_accuracy: 0.9074
#
# Epoch 00113: val_loss did not improve from 0.16516
# Epoch 114/700
# 31/31 - 4s - loss: 0.1302 - accuracy: 0.9486 - val_loss: 0.3619 - val_accuracy: 0.8672
#
# Epoch 00114: val_loss did not improve from 0.16516
# Epoch 115/700
# 31/31 - 4s - loss: 0.1281 - accuracy: 0.9456 - val_loss: 0.2444 - val_accuracy: 0.9115
#
# Epoch 00115: val_loss did not improve from 0.16516
# Epoch 116/700
# 31/31 - 4s - loss: 0.1180 - accuracy: 0.9587 - val_loss: 0.2718 - val_accuracy: 0.9135
#
# Epoch 00116: val_loss did not improve from 0.16516
# Epoch 117/700
# 31/31 - 4s - loss: 0.1223 - accuracy: 0.9486 - val_loss: 0.5090 - val_accuracy: 0.8370
#
# Epoch 00117: val_loss did not improve from 0.16516
# Epoch 118/700
# 31/31 - 4s - loss: 0.1166 - accuracy: 0.9506 - val_loss: 0.1801 - val_accuracy: 0.9396
#
# Epoch 00118: val_loss did not improve from 0.16516
# Epoch 119/700
# 31/31 - 4s - loss: 0.1518 - accuracy: 0.9430 - val_loss: 0.1690 - val_accuracy: 0.9296
#
# Epoch 00119: val_loss did not improve from 0.16516
# Epoch 120/700
# 31/31 - 4s - loss: 0.1322 - accuracy: 0.9461 - val_loss: 0.3529 - val_accuracy: 0.8672
#
# Epoch 00120: val_loss did not improve from 0.16516
# Epoch 121/700
# 31/31 - 4s - loss: 0.1144 - accuracy: 0.9481 - val_loss: 0.1578 - val_accuracy: 0.9437
#
# Epoch 00121: val_loss improved from 0.16516 to 0.15776, saving model to model.h5
# Epoch 122/700
# 31/31 - 4s - loss: 0.1290 - accuracy: 0.9506 - val_loss: 0.2639 - val_accuracy: 0.9034
#
# Epoch 00122: val_loss did not improve from 0.15776
# Epoch 123/700
# 31/31 - 4s - loss: 0.1263 - accuracy: 0.9506 - val_loss: 0.1887 - val_accuracy: 0.9195
#
# Epoch 00123: val_loss did not improve from 0.15776
# Epoch 124/700
# 31/31 - 4s - loss: 0.1195 - accuracy: 0.9531 - val_loss: 0.2387 - val_accuracy: 0.9155
#
# Epoch 00124: val_loss did not improve from 0.15776
# Epoch 125/700
# 31/31 - 4s - loss: 0.1130 - accuracy: 0.9551 - val_loss: 0.3410 - val_accuracy: 0.8954
#
# Epoch 00125: val_loss did not improve from 0.15776
# Epoch 126/700
# 31/31 - 4s - loss: 0.1078 - accuracy: 0.9526 - val_loss: 0.2390 - val_accuracy: 0.9235
#
# Epoch 00126: val_loss did not improve from 0.15776
# Epoch 127/700
# 31/31 - 4s - loss: 0.1117 - accuracy: 0.9536 - val_loss: 0.2843 - val_accuracy: 0.9034
#
# Epoch 00127: val_loss did not improve from 0.15776
# Epoch 128/700
# 31/31 - 4s - loss: 0.1223 - accuracy: 0.9476 - val_loss: 0.4932 - val_accuracy: 0.8571
#
# Epoch 00128: val_loss did not improve from 0.15776
# Epoch 129/700
# 31/31 - 4s - loss: 0.1199 - accuracy: 0.9536 - val_loss: 0.3440 - val_accuracy: 0.8793
#
# Epoch 00129: val_loss did not improve from 0.15776
# Epoch 130/700
# 31/31 - 4s - loss: 0.1078 - accuracy: 0.9567 - val_loss: 0.8025 - val_accuracy: 0.7686
#
# Epoch 00130: val_loss did not improve from 0.15776
# Epoch 131/700
# 31/31 - 4s - loss: 0.1080 - accuracy: 0.9561 - val_loss: 0.2736 - val_accuracy: 0.8913
#
# Epoch 00131: val_loss did not improve from 0.15776
# Epoch 132/700
# 31/31 - 4s - loss: 0.1151 - accuracy: 0.9546 - val_loss: 0.7768 - val_accuracy: 0.7505
#
# Epoch 00132: val_loss did not improve from 0.15776
# Epoch 133/700
# 31/31 - 4s - loss: 0.1051 - accuracy: 0.9546 - val_loss: 1.2341 - val_accuracy: 0.6740
#
# Epoch 00133: val_loss did not improve from 0.15776
# Epoch 134/700
# 31/31 - 4s - loss: 0.1090 - accuracy: 0.9561 - val_loss: 0.4592 - val_accuracy: 0.8431
#
# Epoch 00134: val_loss did not improve from 0.15776
# Epoch 135/700
# 31/31 - 4s - loss: 0.1027 - accuracy: 0.9612 - val_loss: 0.3261 - val_accuracy: 0.8672
#
# Epoch 00135: val_loss did not improve from 0.15776
# Epoch 136/700
# 31/31 - 4s - loss: 0.1115 - accuracy: 0.9612 - val_loss: 0.5495 - val_accuracy: 0.8028
#
# Epoch 00136: val_loss did not improve from 0.15776
# Epoch 137/700
# 31/31 - 4s - loss: 0.1122 - accuracy: 0.9541 - val_loss: 0.2286 - val_accuracy: 0.9175
#
# Epoch 00137: val_loss did not improve from 0.15776
# Epoch 138/700
# 31/31 - 4s - loss: 0.1025 - accuracy: 0.9622 - val_loss: 0.2225 - val_accuracy: 0.9135
#
# Epoch 00138: val_loss did not improve from 0.15776
# Epoch 139/700
# 31/31 - 4s - loss: 0.1120 - accuracy: 0.9572 - val_loss: 0.1886 - val_accuracy: 0.9376
#
# Epoch 00139: val_loss did not improve from 0.15776
# Epoch 140/700
# 31/31 - 4s - loss: 0.1143 - accuracy: 0.9556 - val_loss: 0.1702 - val_accuracy: 0.9457
#
# Epoch 00140: val_loss did not improve from 0.15776
# Epoch 141/700
# 31/31 - 4s - loss: 0.1032 - accuracy: 0.9556 - val_loss: 0.1624 - val_accuracy: 0.9416
#
# Epoch 00141: val_loss did not improve from 0.15776
# Epoch 142/700
# 31/31 - 4s - loss: 0.1099 - accuracy: 0.9577 - val_loss: 0.1950 - val_accuracy: 0.9316
#
# Epoch 00142: val_loss did not improve from 0.15776
# Epoch 143/700
# 31/31 - 4s - loss: 0.1168 - accuracy: 0.9521 - val_loss: 0.1974 - val_accuracy: 0.9416
#
# Epoch 00143: val_loss did not improve from 0.15776
# Epoch 144/700
# 31/31 - 4s - loss: 0.1185 - accuracy: 0.9546 - val_loss: 0.1971 - val_accuracy: 0.9477
#
# Epoch 00144: val_loss did not improve from 0.15776
# Epoch 145/700
# 31/31 - 4s - loss: 0.1062 - accuracy: 0.9531 - val_loss: 0.1733 - val_accuracy: 0.9477
#
# Epoch 00145: val_loss did not improve from 0.15776
# Epoch 146/700
# 31/31 - 4s - loss: 0.1062 - accuracy: 0.9556 - val_loss: 0.1881 - val_accuracy: 0.9477
#
# Epoch 00146: val_loss did not improve from 0.15776
# Epoch 147/700
# 31/31 - 4s - loss: 0.1006 - accuracy: 0.9612 - val_loss: 0.2092 - val_accuracy: 0.9477
#
# Epoch 00147: val_loss did not improve from 0.15776
# Epoch 148/700
# 31/31 - 4s - loss: 0.1090 - accuracy: 0.9531 - val_loss: 0.2404 - val_accuracy: 0.9276
#
# Epoch 00148: val_loss did not improve from 0.15776
# Epoch 149/700
# 31/31 - 4s - loss: 0.1020 - accuracy: 0.9602 - val_loss: 1.2335 - val_accuracy: 0.7525
#
# Epoch 00149: val_loss did not improve from 0.15776
# Epoch 150/700
# 31/31 - 4s - loss: 0.1167 - accuracy: 0.9551 - val_loss: 0.2704 - val_accuracy: 0.9155
#
# Epoch 00150: val_loss did not improve from 0.15776
# Epoch 151/700
# 31/31 - 4s - loss: 0.0922 - accuracy: 0.9647 - val_loss: 0.1800 - val_accuracy: 0.9296
#
# Epoch 00151: val_loss did not improve from 0.15776
# Epoch 152/700
# 31/31 - 4s - loss: 0.0904 - accuracy: 0.9688 - val_loss: 0.1757 - val_accuracy: 0.9296
#
# Epoch 00152: val_loss did not improve from 0.15776
# Epoch 153/700
# 31/31 - 4s - loss: 0.1034 - accuracy: 0.9572 - val_loss: 0.2702 - val_accuracy: 0.8974
#
# Epoch 00153: val_loss did not improve from 0.15776
# Epoch 154/700
# 31/31 - 4s - loss: 0.0877 - accuracy: 0.9723 - val_loss: 0.2712 - val_accuracy: 0.8913
#
# Epoch 00154: val_loss did not improve from 0.15776
# Epoch 155/700
# 31/31 - 4s - loss: 0.0828 - accuracy: 0.9708 - val_loss: 0.2971 - val_accuracy: 0.8954
#
# Epoch 00155: val_loss did not improve from 0.15776
# Epoch 156/700
# 31/31 - 4s - loss: 0.1057 - accuracy: 0.9587 - val_loss: 0.2154 - val_accuracy: 0.9235
#
# Epoch 00156: val_loss did not improve from 0.15776
# Epoch 157/700
# 31/31 - 4s - loss: 0.0993 - accuracy: 0.9637 - val_loss: 0.1676 - val_accuracy: 0.9356
#
# Epoch 00157: val_loss did not improve from 0.15776
# Epoch 158/700
# 31/31 - 4s - loss: 0.0798 - accuracy: 0.9733 - val_loss: 0.1468 - val_accuracy: 0.9517
#
# Epoch 00158: val_loss improved from 0.15776 to 0.14683, saving model to model.h5
# Epoch 159/700
# 31/31 - 4s - loss: 0.0923 - accuracy: 0.9672 - val_loss: 0.1625 - val_accuracy: 0.9497
#
# Epoch 00159: val_loss did not improve from 0.14683
# Epoch 160/700
# 31/31 - 4s - loss: 0.1016 - accuracy: 0.9627 - val_loss: 0.2071 - val_accuracy: 0.9296
#
# Epoch 00160: val_loss did not improve from 0.14683
# Epoch 161/700
# 31/31 - 4s - loss: 0.0805 - accuracy: 0.9688 - val_loss: 0.3637 - val_accuracy: 0.8612
#
# Epoch 00161: val_loss did not improve from 0.14683
# Epoch 162/700
# 31/31 - 4s - loss: 0.0817 - accuracy: 0.9693 - val_loss: 0.3146 - val_accuracy: 0.9014
#
# Epoch 00162: val_loss did not improve from 0.14683
# Epoch 163/700
# 31/31 - 4s - loss: 0.0862 - accuracy: 0.9667 - val_loss: 0.4778 - val_accuracy: 0.8451
#
# Epoch 00163: val_loss did not improve from 0.14683
# Epoch 164/700
# 31/31 - 4s - loss: 0.0823 - accuracy: 0.9713 - val_loss: 0.8307 - val_accuracy: 0.7746
#
# Epoch 00164: val_loss did not improve from 0.14683
# Epoch 165/700
# 31/31 - 4s - loss: 0.0901 - accuracy: 0.9612 - val_loss: 1.3252 - val_accuracy: 0.6962
#
# Epoch 00165: val_loss did not improve from 0.14683
# Epoch 166/700
# 31/31 - 4s - loss: 0.0790 - accuracy: 0.9708 - val_loss: 0.2007 - val_accuracy: 0.9296
#
# Epoch 00166: val_loss did not improve from 0.14683
# Epoch 167/700
# 31/31 - 4s - loss: 0.0835 - accuracy: 0.9682 - val_loss: 0.1958 - val_accuracy: 0.9457
#
# Epoch 00167: val_loss did not improve from 0.14683
# Epoch 168/700
# 31/31 - 4s - loss: 0.0899 - accuracy: 0.9672 - val_loss: 0.1896 - val_accuracy: 0.9416
#
# Epoch 00168: val_loss did not improve from 0.14683
# Epoch 169/700
# 31/31 - 4s - loss: 0.0809 - accuracy: 0.9677 - val_loss: 0.1881 - val_accuracy: 0.9537
#
# Epoch 00169: val_loss did not improve from 0.14683
# Epoch 170/700
# 31/31 - 4s - loss: 0.0887 - accuracy: 0.9632 - val_loss: 0.2130 - val_accuracy: 0.9457
#
# Epoch 00170: val_loss did not improve from 0.14683
# Epoch 171/700
# 31/31 - 4s - loss: 0.0813 - accuracy: 0.9708 - val_loss: 0.1931 - val_accuracy: 0.9396
#
# Epoch 00171: val_loss did not improve from 0.14683
# Epoch 172/700
# 31/31 - 4s - loss: 0.0791 - accuracy: 0.9672 - val_loss: 0.2218 - val_accuracy: 0.9316
#
# Epoch 00172: val_loss did not improve from 0.14683
# Epoch 173/700
# 31/31 - 4s - loss: 0.0750 - accuracy: 0.9703 - val_loss: 0.1888 - val_accuracy: 0.9437
#
# Epoch 00173: val_loss did not improve from 0.14683
# Epoch 174/700
# 31/31 - 4s - loss: 0.0800 - accuracy: 0.9703 - val_loss: 0.1377 - val_accuracy: 0.9577
#
# Epoch 00174: val_loss improved from 0.14683 to 0.13772, saving model to model.h5
# Epoch 175/700
# 31/31 - 4s - loss: 0.0770 - accuracy: 0.9703 - val_loss: 0.1256 - val_accuracy: 0.9517
#
# Epoch 00175: val_loss improved from 0.13772 to 0.12561, saving model to model.h5
# Epoch 176/700
# 31/31 - 4s - loss: 0.0760 - accuracy: 0.9718 - val_loss: 0.1096 - val_accuracy: 0.9618
#
# Epoch 00176: val_loss improved from 0.12561 to 0.10961, saving model to model.h5
# Epoch 177/700
# 31/31 - 4s - loss: 0.0801 - accuracy: 0.9718 - val_loss: 0.2130 - val_accuracy: 0.9256
#
# Epoch 00177: val_loss did not improve from 0.10961
# Epoch 178/700
# 31/31 - 4s - loss: 0.0819 - accuracy: 0.9698 - val_loss: 0.4218 - val_accuracy: 0.8672
#
# Epoch 00178: val_loss did not improve from 0.10961
# Epoch 179/700
# 31/31 - 4s - loss: 0.0728 - accuracy: 0.9713 - val_loss: 0.6266 - val_accuracy: 0.8129
#
# Epoch 00179: val_loss did not improve from 0.10961
# Epoch 180/700
# 31/31 - 4s - loss: 0.0636 - accuracy: 0.9748 - val_loss: 0.3477 - val_accuracy: 0.8833
#
# Epoch 00180: val_loss did not improve from 0.10961
# Epoch 181/700
# 31/31 - 4s - loss: 0.0763 - accuracy: 0.9713 - val_loss: 0.2098 - val_accuracy: 0.9477
#
# Epoch 00181: val_loss did not improve from 0.10961
# Epoch 182/700
# 31/31 - 4s - loss: 0.0840 - accuracy: 0.9677 - val_loss: 0.1644 - val_accuracy: 0.9557
#
# Epoch 00182: val_loss did not improve from 0.10961
# Epoch 183/700
# 31/31 - 4s - loss: 0.0827 - accuracy: 0.9672 - val_loss: 0.1248 - val_accuracy: 0.9557
#
# Epoch 00183: val_loss did not improve from 0.10961
# Epoch 184/700
# 31/31 - 4s - loss: 0.0772 - accuracy: 0.9713 - val_loss: 0.2505 - val_accuracy: 0.9336
#
# Epoch 00184: val_loss did not improve from 0.10961
# Epoch 185/700
# 31/31 - 4s - loss: 0.0697 - accuracy: 0.9743 - val_loss: 0.1974 - val_accuracy: 0.9437
#
# Epoch 00185: val_loss did not improve from 0.10961
# Epoch 186/700
# 31/31 - 4s - loss: 0.0756 - accuracy: 0.9728 - val_loss: 0.1597 - val_accuracy: 0.9437
#
# Epoch 00186: val_loss did not improve from 0.10961
# Epoch 187/700
# 31/31 - 4s - loss: 0.0691 - accuracy: 0.9758 - val_loss: 0.2180 - val_accuracy: 0.9416
#
# Epoch 00187: val_loss did not improve from 0.10961
# Epoch 188/700
# 31/31 - 4s - loss: 0.0690 - accuracy: 0.9748 - val_loss: 0.1770 - val_accuracy: 0.9437
#
# Epoch 00188: val_loss did not improve from 0.10961
# Epoch 189/700
# 31/31 - 4s - loss: 0.0817 - accuracy: 0.9682 - val_loss: 0.1727 - val_accuracy: 0.9477
#
# Epoch 00189: val_loss did not improve from 0.10961
# Epoch 190/700
# 31/31 - 4s - loss: 0.0760 - accuracy: 0.9703 - val_loss: 0.1892 - val_accuracy: 0.9276
#
# Epoch 00190: val_loss did not improve from 0.10961
# Epoch 191/700
# 31/31 - 4s - loss: 0.0717 - accuracy: 0.9718 - val_loss: 0.2036 - val_accuracy: 0.9316
#
# Epoch 00191: val_loss did not improve from 0.10961
# Epoch 192/700
# 31/31 - 4s - loss: 0.0723 - accuracy: 0.9708 - val_loss: 0.6193 - val_accuracy: 0.8169
#
# Epoch 00192: val_loss did not improve from 0.10961
# Epoch 193/700
# 31/31 - 4s - loss: 0.0683 - accuracy: 0.9773 - val_loss: 0.1910 - val_accuracy: 0.9356
#
# Epoch 00193: val_loss did not improve from 0.10961
# Epoch 194/700
# 31/31 - 4s - loss: 0.0651 - accuracy: 0.9778 - val_loss: 0.2175 - val_accuracy: 0.9336
#
# Epoch 00194: val_loss did not improve from 0.10961
# Epoch 195/700
# 31/31 - 4s - loss: 0.0852 - accuracy: 0.9693 - val_loss: 0.1409 - val_accuracy: 0.9638
#
# Epoch 00195: val_loss did not improve from 0.10961
# Epoch 196/700
# 31/31 - 4s - loss: 0.0708 - accuracy: 0.9733 - val_loss: 0.1562 - val_accuracy: 0.9577
#
# Epoch 00196: val_loss did not improve from 0.10961
# Epoch 197/700
# 31/31 - 4s - loss: 0.0746 - accuracy: 0.9698 - val_loss: 0.1919 - val_accuracy: 0.9416
#
# Epoch 00197: val_loss did not improve from 0.10961
# Epoch 198/700
# 31/31 - 4s - loss: 0.0598 - accuracy: 0.9768 - val_loss: 0.1197 - val_accuracy: 0.9618
#
# Epoch 00198: val_loss did not improve from 0.10961
# Epoch 199/700
# 31/31 - 4s - loss: 0.0673 - accuracy: 0.9738 - val_loss: 0.2519 - val_accuracy: 0.9316
#
# Epoch 00199: val_loss did not improve from 0.10961
# Epoch 200/700
# 31/31 - 4s - loss: 0.0791 - accuracy: 0.9748 - val_loss: 0.2463 - val_accuracy: 0.9296
#
# Epoch 00200: val_loss did not improve from 0.10961
# Epoch 201/700
# 31/31 - 4s - loss: 0.0657 - accuracy: 0.9733 - val_loss: 0.2111 - val_accuracy: 0.9296
#
# Epoch 00201: val_loss did not improve from 0.10961
# Epoch 202/700
# 31/31 - 4s - loss: 0.0639 - accuracy: 0.9743 - val_loss: 0.1575 - val_accuracy: 0.9517
#
# Epoch 00202: val_loss did not improve from 0.10961
# Epoch 203/700
# 31/31 - 4s - loss: 0.0570 - accuracy: 0.9803 - val_loss: 0.2327 - val_accuracy: 0.9195
#
# Epoch 00203: val_loss did not improve from 0.10961
# Epoch 204/700
# 31/31 - 4s - loss: 0.0613 - accuracy: 0.9773 - val_loss: 0.2506 - val_accuracy: 0.9155
#
# Epoch 00204: val_loss did not improve from 0.10961
# Epoch 205/700
# 31/31 - 4s - loss: 0.0691 - accuracy: 0.9708 - val_loss: 0.1019 - val_accuracy: 0.9618
#
# Epoch 00205: val_loss improved from 0.10961 to 0.10189, saving model to model.h5
# Epoch 206/700
# 31/31 - 4s - loss: 0.0625 - accuracy: 0.9753 - val_loss: 0.1332 - val_accuracy: 0.9658
#
# Epoch 00206: val_loss did not improve from 0.10189
# Epoch 207/700
# 31/31 - 4s - loss: 0.0648 - accuracy: 0.9788 - val_loss: 0.1998 - val_accuracy: 0.9356
#
# Epoch 00207: val_loss did not improve from 0.10189
# Epoch 208/700
# 31/31 - 4s - loss: 0.0636 - accuracy: 0.9758 - val_loss: 0.1137 - val_accuracy: 0.9557
#
# Epoch 00208: val_loss did not improve from 0.10189
# Epoch 209/700
# 31/31 - 4s - loss: 0.0765 - accuracy: 0.9713 - val_loss: 0.2112 - val_accuracy: 0.9235
#
# Epoch 00209: val_loss did not improve from 0.10189
# Epoch 210/700
# 31/31 - 4s - loss: 0.0709 - accuracy: 0.9738 - val_loss: 0.1124 - val_accuracy: 0.9618
#
# Epoch 00210: val_loss did not improve from 0.10189
# Epoch 211/700
# 31/31 - 4s - loss: 0.0722 - accuracy: 0.9738 - val_loss: 0.1907 - val_accuracy: 0.9356
#
# Epoch 00211: val_loss did not improve from 0.10189
# Epoch 212/700
# 31/31 - 4s - loss: 0.0796 - accuracy: 0.9708 - val_loss: 0.1691 - val_accuracy: 0.9356
#
# Epoch 00212: val_loss did not improve from 0.10189
# Epoch 213/700
# 31/31 - 4s - loss: 0.0567 - accuracy: 0.9798 - val_loss: 0.3741 - val_accuracy: 0.8652
#
# Epoch 00213: val_loss did not improve from 0.10189
# Epoch 214/700
# 31/31 - 4s - loss: 0.0587 - accuracy: 0.9748 - val_loss: 0.1416 - val_accuracy: 0.9537
#
# Epoch 00214: val_loss did not improve from 0.10189
# Epoch 215/700
# 31/31 - 4s - loss: 0.0591 - accuracy: 0.9793 - val_loss: 0.2424 - val_accuracy: 0.9215
#
# Epoch 00215: val_loss did not improve from 0.10189
# Epoch 216/700
# 31/31 - 4s - loss: 0.0607 - accuracy: 0.9803 - val_loss: 0.1086 - val_accuracy: 0.9698
#
# Epoch 00216: val_loss did not improve from 0.10189
# Epoch 217/700
# 31/31 - 4s - loss: 0.0492 - accuracy: 0.9834 - val_loss: 0.1969 - val_accuracy: 0.9256
#
# Epoch 00217: val_loss did not improve from 0.10189
# Epoch 218/700
# 31/31 - 4s - loss: 0.0588 - accuracy: 0.9793 - val_loss: 0.5826 - val_accuracy: 0.7968
#
# Epoch 00218: val_loss did not improve from 0.10189
# Epoch 219/700
# 31/31 - 4s - loss: 0.0680 - accuracy: 0.9733 - val_loss: 0.2918 - val_accuracy: 0.8873
#
# Epoch 00219: val_loss did not improve from 0.10189
# Epoch 220/700
# 31/31 - 4s - loss: 0.0595 - accuracy: 0.9793 - val_loss: 0.0937 - val_accuracy: 0.9678
#
# Epoch 00220: val_loss improved from 0.10189 to 0.09369, saving model to model.h5
# Epoch 221/700
# 31/31 - 4s - loss: 0.0624 - accuracy: 0.9758 - val_loss: 0.1373 - val_accuracy: 0.9477
#
# Epoch 00221: val_loss did not improve from 0.09369
# Epoch 222/700
# 31/31 - 4s - loss: 0.0523 - accuracy: 0.9788 - val_loss: 0.1422 - val_accuracy: 0.9457
#
# Epoch 00222: val_loss did not improve from 0.09369
# Epoch 223/700
# 31/31 - 4s - loss: 0.0603 - accuracy: 0.9793 - val_loss: 0.2440 - val_accuracy: 0.9517
#
# Epoch 00223: val_loss did not improve from 0.09369
# Epoch 224/700
# 31/31 - 4s - loss: 0.0674 - accuracy: 0.9693 - val_loss: 0.1541 - val_accuracy: 0.9577
#
# Epoch 00224: val_loss did not improve from 0.09369
# Epoch 225/700
# 31/31 - 4s - loss: 0.0650 - accuracy: 0.9718 - val_loss: 0.1902 - val_accuracy: 0.9477
#
# Epoch 00225: val_loss did not improve from 0.09369
# Epoch 226/700
# 31/31 - 4s - loss: 0.0534 - accuracy: 0.9773 - val_loss: 0.2411 - val_accuracy: 0.9135
#
# Epoch 00226: val_loss did not improve from 0.09369
# Epoch 227/700
# 31/31 - 4s - loss: 0.0761 - accuracy: 0.9743 - val_loss: 0.2214 - val_accuracy: 0.9256
#
# Epoch 00227: val_loss did not improve from 0.09369
# Epoch 228/700
# 31/31 - 4s - loss: 0.0547 - accuracy: 0.9803 - val_loss: 0.1301 - val_accuracy: 0.9638
#
# Epoch 00228: val_loss did not improve from 0.09369
# Epoch 229/700
# 31/31 - 4s - loss: 0.0768 - accuracy: 0.9718 - val_loss: 0.1504 - val_accuracy: 0.9638
#
# Epoch 00229: val_loss did not improve from 0.09369
# Epoch 230/700
# 31/31 - 4s - loss: 0.0504 - accuracy: 0.9849 - val_loss: 0.1490 - val_accuracy: 0.9638
#
# Epoch 00230: val_loss did not improve from 0.09369
# Epoch 231/700
# 31/31 - 4s - loss: 0.0507 - accuracy: 0.9793 - val_loss: 0.1380 - val_accuracy: 0.9658
#
# Epoch 00231: val_loss did not improve from 0.09369
# Epoch 232/700
# 31/31 - 4s - loss: 0.0538 - accuracy: 0.9808 - val_loss: 0.2654 - val_accuracy: 0.9175
#
# Epoch 00232: val_loss did not improve from 0.09369
# Epoch 233/700
# 31/31 - 4s - loss: 0.0450 - accuracy: 0.9824 - val_loss: 0.5271 - val_accuracy: 0.8390
#
# Epoch 00233: val_loss did not improve from 0.09369
# Epoch 234/700
# 31/31 - 4s - loss: 0.0446 - accuracy: 0.9869 - val_loss: 0.1880 - val_accuracy: 0.9517
#
# Epoch 00234: val_loss did not improve from 0.09369
# Epoch 235/700
# 31/31 - 4s - loss: 0.0520 - accuracy: 0.9778 - val_loss: 0.4391 - val_accuracy: 0.8551
#
# Epoch 00235: val_loss did not improve from 0.09369
# Epoch 236/700
# 31/31 - 4s - loss: 0.0454 - accuracy: 0.9829 - val_loss: 0.9746 - val_accuracy: 0.7264
#
# Epoch 00236: val_loss did not improve from 0.09369
# Epoch 237/700
# 31/31 - 4s - loss: 0.0514 - accuracy: 0.9793 - val_loss: 0.1641 - val_accuracy: 0.9477
#
# Epoch 00237: val_loss did not improve from 0.09369
# Epoch 238/700
# 31/31 - 4s - loss: 0.0481 - accuracy: 0.9844 - val_loss: 0.1961 - val_accuracy: 0.9396
#
# Epoch 00238: val_loss did not improve from 0.09369
# Epoch 239/700
# 31/31 - 4s - loss: 0.0671 - accuracy: 0.9748 - val_loss: 0.1637 - val_accuracy: 0.9537
#
# Epoch 00239: val_loss did not improve from 0.09369
# Epoch 240/700
# 31/31 - 4s - loss: 0.0544 - accuracy: 0.9778 - val_loss: 0.4749 - val_accuracy: 0.8571
#
# Epoch 00240: val_loss did not improve from 0.09369
# Epoch 241/700
# 31/31 - 4s - loss: 0.0485 - accuracy: 0.9819 - val_loss: 0.1740 - val_accuracy: 0.9376
#
# Epoch 00241: val_loss did not improve from 0.09369
# Epoch 242/700
# 31/31 - 4s - loss: 0.0390 - accuracy: 0.9844 - val_loss: 0.3020 - val_accuracy: 0.9014
#
# Epoch 00242: val_loss did not improve from 0.09369
# Epoch 243/700
# 31/31 - 4s - loss: 0.0502 - accuracy: 0.9824 - val_loss: 0.1233 - val_accuracy: 0.9698
#
# Epoch 00243: val_loss did not improve from 0.09369
# Epoch 244/700
# 31/31 - 4s - loss: 0.0404 - accuracy: 0.9849 - val_loss: 0.1272 - val_accuracy: 0.9517
#
# Epoch 00244: val_loss did not improve from 0.09369
# Epoch 245/700
# 31/31 - 4s - loss: 0.0471 - accuracy: 0.9814 - val_loss: 0.1110 - val_accuracy: 0.9598
#
# Epoch 00245: val_loss did not improve from 0.09369
# Epoch 246/700
# 31/31 - 4s - loss: 0.0503 - accuracy: 0.9814 - val_loss: 0.1984 - val_accuracy: 0.9376
#
# Epoch 00246: val_loss did not improve from 0.09369
# Epoch 247/700
# 31/31 - 4s - loss: 0.0665 - accuracy: 0.9758 - val_loss: 0.1164 - val_accuracy: 0.9718
#
# Epoch 00247: val_loss did not improve from 0.09369
# Epoch 248/700
# 31/31 - 4s - loss: 0.0582 - accuracy: 0.9788 - val_loss: 0.1575 - val_accuracy: 0.9497
#
# Epoch 00248: val_loss did not improve from 0.09369
# Epoch 249/700
# 31/31 - 4s - loss: 0.0503 - accuracy: 0.9788 - val_loss: 0.1500 - val_accuracy: 0.9537
#
# Epoch 00249: val_loss did not improve from 0.09369
# Epoch 250/700
# 31/31 - 4s - loss: 0.0571 - accuracy: 0.9773 - val_loss: 0.1922 - val_accuracy: 0.9437
#
# Epoch 00250: val_loss did not improve from 0.09369
# Epoch 251/700
# 31/31 - 4s - loss: 0.0439 - accuracy: 0.9798 - val_loss: 0.1441 - val_accuracy: 0.9577
#
# Epoch 00251: val_loss did not improve from 0.09369
# Epoch 252/700
# 31/31 - 4s - loss: 0.0444 - accuracy: 0.9859 - val_loss: 0.1799 - val_accuracy: 0.9477
#
# Epoch 00252: val_loss did not improve from 0.09369
# Epoch 253/700
# 31/31 - 4s - loss: 0.0418 - accuracy: 0.9839 - val_loss: 0.0998 - val_accuracy: 0.9698
#
# Epoch 00253: val_loss did not improve from 0.09369
# Epoch 254/700
# 31/31 - 4s - loss: 0.0551 - accuracy: 0.9753 - val_loss: 0.1607 - val_accuracy: 0.9577
#
# Epoch 00254: val_loss did not improve from 0.09369
# Epoch 255/700
# 31/31 - 4s - loss: 0.0471 - accuracy: 0.9798 - val_loss: 0.1484 - val_accuracy: 0.9557
#
# Epoch 00255: val_loss did not improve from 0.09369
# Epoch 256/700
# 31/31 - 4s - loss: 0.0353 - accuracy: 0.9879 - val_loss: 0.1221 - val_accuracy: 0.9638
#
# Epoch 00256: val_loss did not improve from 0.09369
# Epoch 257/700
# 31/31 - 4s - loss: 0.0478 - accuracy: 0.9808 - val_loss: 0.1583 - val_accuracy: 0.9557
#
# Epoch 00257: val_loss did not improve from 0.09369
# Epoch 258/700
# 31/31 - 4s - loss: 0.0476 - accuracy: 0.9803 - val_loss: 0.1573 - val_accuracy: 0.9557
#
# Epoch 00258: val_loss did not improve from 0.09369
# Epoch 259/700
# 31/31 - 4s - loss: 0.0448 - accuracy: 0.9844 - val_loss: 0.1508 - val_accuracy: 0.9557
#
# Epoch 00259: val_loss did not improve from 0.09369
# Epoch 260/700
# 31/31 - 4s - loss: 0.0481 - accuracy: 0.9814 - val_loss: 0.2526 - val_accuracy: 0.9175
#
# Epoch 00260: val_loss did not improve from 0.09369
# Epoch 261/700
# 31/31 - 4s - loss: 0.0462 - accuracy: 0.9819 - val_loss: 0.1588 - val_accuracy: 0.9437
#
# Epoch 00261: val_loss did not improve from 0.09369
# Epoch 262/700
# 31/31 - 4s - loss: 0.0323 - accuracy: 0.9864 - val_loss: 0.1208 - val_accuracy: 0.9618
#
# Epoch 00262: val_loss did not improve from 0.09369
# Epoch 263/700
# 31/31 - 4s - loss: 0.0448 - accuracy: 0.9834 - val_loss: 0.1430 - val_accuracy: 0.9598
#
# Epoch 00263: val_loss did not improve from 0.09369
# Epoch 264/700
# 31/31 - 4s - loss: 0.0305 - accuracy: 0.9914 - val_loss: 0.1443 - val_accuracy: 0.9577
#
# Epoch 00264: val_loss did not improve from 0.09369
# Epoch 265/700
# 31/31 - 4s - loss: 0.0383 - accuracy: 0.9849 - val_loss: 0.1895 - val_accuracy: 0.9376
#
# Epoch 00265: val_loss did not improve from 0.09369
# Epoch 266/700
# 31/31 - 4s - loss: 0.0501 - accuracy: 0.9824 - val_loss: 0.1011 - val_accuracy: 0.9698
#
# Epoch 00266: val_loss did not improve from 0.09369
# Epoch 267/700
# 31/31 - 4s - loss: 0.0373 - accuracy: 0.9874 - val_loss: 0.2114 - val_accuracy: 0.9276
#
# Epoch 00267: val_loss did not improve from 0.09369
# Epoch 268/700
# 31/31 - 4s - loss: 0.0382 - accuracy: 0.9849 - val_loss: 0.1134 - val_accuracy: 0.9638
#
# Epoch 00268: val_loss did not improve from 0.09369
# Epoch 269/700
# 31/31 - 4s - loss: 0.0272 - accuracy: 0.9914 - val_loss: 0.0820 - val_accuracy: 0.9718
#
# Epoch 00269: val_loss improved from 0.09369 to 0.08198, saving model to model.h5
# Epoch 270/700
# 31/31 - 4s - loss: 0.0407 - accuracy: 0.9839 - val_loss: 0.1491 - val_accuracy: 0.9517
#
# Epoch 00270: val_loss did not improve from 0.08198
# Epoch 271/700
# 31/31 - 4s - loss: 0.0569 - accuracy: 0.9819 - val_loss: 0.1096 - val_accuracy: 0.9678
#
# Epoch 00271: val_loss did not improve from 0.08198
# Epoch 272/700
# 31/31 - 4s - loss: 0.0351 - accuracy: 0.9874 - val_loss: 0.1741 - val_accuracy: 0.9517
#
# Epoch 00272: val_loss did not improve from 0.08198
# Epoch 273/700
# 31/31 - 4s - loss: 0.0442 - accuracy: 0.9834 - val_loss: 0.1306 - val_accuracy: 0.9638
#
# Epoch 00273: val_loss did not improve from 0.08198
# Epoch 274/700
# 31/31 - 4s - loss: 0.0487 - accuracy: 0.9824 - val_loss: 0.1150 - val_accuracy: 0.9618
#
# Epoch 00274: val_loss did not improve from 0.08198
# Epoch 275/700
# 31/31 - 4s - loss: 0.0391 - accuracy: 0.9874 - val_loss: 0.1601 - val_accuracy: 0.9557
#
# Epoch 00275: val_loss did not improve from 0.08198
# Epoch 276/700
# 31/31 - 4s - loss: 0.0419 - accuracy: 0.9859 - val_loss: 0.1424 - val_accuracy: 0.9557
#
# Epoch 00276: val_loss did not improve from 0.08198
# Epoch 277/700
# 31/31 - 4s - loss: 0.0447 - accuracy: 0.9834 - val_loss: 0.2084 - val_accuracy: 0.9376
#
# Epoch 00277: val_loss did not improve from 0.08198
# Epoch 278/700
# 31/31 - 4s - loss: 0.0614 - accuracy: 0.9778 - val_loss: 0.1443 - val_accuracy: 0.9457
#
# Epoch 00278: val_loss did not improve from 0.08198
# Epoch 279/700
# 31/31 - 4s - loss: 0.0294 - accuracy: 0.9909 - val_loss: 0.1549 - val_accuracy: 0.9457
#
# Epoch 00279: val_loss did not improve from 0.08198
# Epoch 280/700
# 31/31 - 4s - loss: 0.0336 - accuracy: 0.9884 - val_loss: 0.0839 - val_accuracy: 0.9738
#
# Epoch 00280: val_loss did not improve from 0.08198
# Epoch 281/700
# 31/31 - 4s - loss: 0.0320 - accuracy: 0.9889 - val_loss: 0.1021 - val_accuracy: 0.9759
#
# Epoch 00281: val_loss did not improve from 0.08198
# Epoch 282/700
# 31/31 - 4s - loss: 0.0335 - accuracy: 0.9859 - val_loss: 0.1105 - val_accuracy: 0.9618
#
# Epoch 00282: val_loss did not improve from 0.08198
# Epoch 283/700
# 31/31 - 4s - loss: 0.0360 - accuracy: 0.9859 - val_loss: 0.4500 - val_accuracy: 0.8491
#
# Epoch 00283: val_loss did not improve from 0.08198
# Epoch 284/700
# 31/31 - 4s - loss: 0.0389 - accuracy: 0.9839 - val_loss: 0.2502 - val_accuracy: 0.9235
#
# Epoch 00284: val_loss did not improve from 0.08198
# Epoch 285/700
# 31/31 - 4s - loss: 0.0298 - accuracy: 0.9899 - val_loss: 0.1293 - val_accuracy: 0.9557
#
# Epoch 00285: val_loss did not improve from 0.08198
# Epoch 286/700
# 31/31 - 4s - loss: 0.0362 - accuracy: 0.9849 - val_loss: 0.1478 - val_accuracy: 0.9537
#
# Epoch 00286: val_loss did not improve from 0.08198
# Epoch 287/700
# 31/31 - 4s - loss: 0.0431 - accuracy: 0.9839 - val_loss: 0.1385 - val_accuracy: 0.9537
#
# Epoch 00287: val_loss did not improve from 0.08198
# Epoch 288/700
# 31/31 - 4s - loss: 0.0368 - accuracy: 0.9874 - val_loss: 0.1506 - val_accuracy: 0.9618
#
# Epoch 00288: val_loss did not improve from 0.08198
# Epoch 289/700
# 31/31 - 4s - loss: 0.0344 - accuracy: 0.9884 - val_loss: 0.1606 - val_accuracy: 0.9416
#
# Epoch 00289: val_loss did not improve from 0.08198
# Epoch 290/700
# 31/31 - 4s - loss: 0.0397 - accuracy: 0.9849 - val_loss: 0.1315 - val_accuracy: 0.9598
#
# Epoch 00290: val_loss did not improve from 0.08198
# Epoch 291/700
# 31/31 - 4s - loss: 0.0340 - accuracy: 0.9874 - val_loss: 0.3796 - val_accuracy: 0.8893
#
# Epoch 00291: val_loss did not improve from 0.08198
# Epoch 292/700
# 31/31 - 4s - loss: 0.0523 - accuracy: 0.9803 - val_loss: 0.4096 - val_accuracy: 0.8913
#
# Epoch 00292: val_loss did not improve from 0.08198
# Epoch 293/700
# 31/31 - 4s - loss: 0.0419 - accuracy: 0.9844 - val_loss: 0.1579 - val_accuracy: 0.9537
#
# Epoch 00293: val_loss did not improve from 0.08198
# Epoch 294/700
# 31/31 - 4s - loss: 0.0470 - accuracy: 0.9839 - val_loss: 0.2147 - val_accuracy: 0.9396
#
# ...
#
# Epoch 00596: val_loss did not improve from 0.06461
# Epoch 597/700
# 31/31 - 4s - loss: 0.0155 - accuracy: 0.9950 - val_loss: 0.1201 - val_accuracy: 0.9759
#
# Epoch 00597: val_loss did not improve from 0.06461
# Epoch 598/700
# 31/31 - 4s - loss: 0.0121 - accuracy: 0.9975 - val_loss: 0.1711 - val_accuracy: 0.9396
#
# Epoch 00598: val_loss did not improve from 0.06461
# Epoch 599/700
# 31/31 - 4s - loss: 0.0096 - accuracy: 0.9980 - val_loss: 0.2275 - val_accuracy: 0.9316
#
# Epoch 00599: val_loss did not improve from 0.06461
# Epoch 600/700
# 31/31 - 4s - loss: 0.0083 - accuracy: 0.9975 - val_loss: 0.1368 - val_accuracy: 0.9598
#
# Epoch 00600: val_loss did not improve from 0.06461
# Epoch 601/700
# 31/31 - 4s - loss: 0.0131 - accuracy: 0.9965 - val_loss: 0.1198 - val_accuracy: 0.9658
#
# Epoch 00601: val_loss did not improve from 0.06461
# Epoch 602/700
# 31/31 - 4s - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.1295 - val_accuracy: 0.9598
#
# Epoch 00602: val_loss did not improve from 0.06461
# Epoch 603/700
# 31/31 - 4s - loss: 0.0199 - accuracy: 0.9934 - val_loss: 0.1468 - val_accuracy: 0.9577
#
# Epoch 00603: val_loss did not improve from 0.06461
# Epoch 604/700
# 31/31 - 4s - loss: 0.0120 - accuracy: 0.9960 - val_loss: 0.0923 - val_accuracy: 0.9799
#
# Epoch 00604: val_loss did not improve from 0.06461
# Epoch 605/700
# 31/31 - 4s - loss: 0.0130 - accuracy: 0.9960 - val_loss: 0.1021 - val_accuracy: 0.9819
#
# Epoch 00605: val_loss did not improve from 0.06461
# Epoch 606/700
# 31/31 - 4s - loss: 0.0070 - accuracy: 0.9980 - val_loss: 0.1123 - val_accuracy: 0.9738
#
# Epoch 00606: val_loss did not improve from 0.06461
# Epoch 607/700
# 31/31 - 4s - loss: 0.0125 - accuracy: 0.9965 - val_loss: 0.1232 - val_accuracy: 0.9658
#
# Epoch 00607: val_loss did not improve from 0.06461
# Epoch 608/700
# 31/31 - 4s - loss: 0.0134 - accuracy: 0.9955 - val_loss: 0.1493 - val_accuracy: 0.9638
#
# Epoch 00608: val_loss did not improve from 0.06461
# Epoch 609/700
# 31/31 - 4s - loss: 0.0169 - accuracy: 0.9940 - val_loss: 0.2575 - val_accuracy: 0.9356
#
# Epoch 00609: val_loss did not improve from 0.06461
# Epoch 610/700
# 31/31 - 4s - loss: 0.0088 - accuracy: 0.9975 - val_loss: 0.1644 - val_accuracy: 0.9618
#
# Epoch 00610: val_loss did not improve from 0.06461
# Epoch 611/700
# 31/31 - 4s - loss: 0.0120 - accuracy: 0.9955 - val_loss: 0.1255 - val_accuracy: 0.9799
#
# Epoch 00611: val_loss did not improve from 0.06461
# Epoch 612/700
# 31/31 - 4s - loss: 0.0144 - accuracy: 0.9950 - val_loss: 0.5495 - val_accuracy: 0.8551
#
# Epoch 00612: val_loss did not improve from 0.06461
# Epoch 613/700
# 31/31 - 4s - loss: 0.0069 - accuracy: 0.9975 - val_loss: 0.2633 - val_accuracy: 0.9215
#
# Epoch 00613: val_loss did not improve from 0.06461
# Epoch 614/700
# 31/31 - 4s - loss: 0.0123 - accuracy: 0.9960 - val_loss: 0.1057 - val_accuracy: 0.9698
#
# Epoch 00614: val_loss did not improve from 0.06461
# Epoch 615/700
# 31/31 - 4s - loss: 0.0174 - accuracy: 0.9929 - val_loss: 0.1000 - val_accuracy: 0.9638
#
# Epoch 00615: val_loss did not improve from 0.06461
# Epoch 616/700
# 31/31 - 4s - loss: 0.0157 - accuracy: 0.9945 - val_loss: 0.0699 - val_accuracy: 0.9779
#
# Epoch 00616: val_loss did not improve from 0.06461
# Epoch 617/700
# 31/31 - 4s - loss: 0.0134 - accuracy: 0.9960 - val_loss: 0.1403 - val_accuracy: 0.9738
#
# Epoch 00617: val_loss did not improve from 0.06461
# Epoch 618/700
# 31/31 - 4s - loss: 0.0093 - accuracy: 0.9965 - val_loss: 0.1327 - val_accuracy: 0.9779
#
# Epoch 00618: val_loss did not improve from 0.06461
# Epoch 619/700
# 31/31 - 4s - loss: 0.0089 - accuracy: 0.9970 - val_loss: 0.2140 - val_accuracy: 0.9557
#
# Epoch 00619: val_loss did not improve from 0.06461
# Epoch 620/700
# 31/31 - 4s - loss: 0.0091 - accuracy: 0.9970 - val_loss: 0.1250 - val_accuracy: 0.9759
#
# Epoch 00620: val_loss did not improve from 0.06461
# Epoch 621/700
# 31/31 - 4s - loss: 0.0146 - accuracy: 0.9965 - val_loss: 0.1054 - val_accuracy: 0.9738
#
# Epoch 00621: val_loss did not improve from 0.06461
# Epoch 622/700
# 31/31 - 4s - loss: 0.0085 - accuracy: 0.9970 - val_loss: 0.1154 - val_accuracy: 0.9779
#
# Epoch 00622: val_loss did not improve from 0.06461
# Epoch 623/700
# 31/31 - 4s - loss: 0.0147 - accuracy: 0.9955 - val_loss: 0.1744 - val_accuracy: 0.9477
#
# Epoch 00623: val_loss did not improve from 0.06461
# Epoch 624/700
# 31/31 - 4s - loss: 0.0106 - accuracy: 0.9960 - val_loss: 0.1609 - val_accuracy: 0.9698
#
# Epoch 00624: val_loss did not improve from 0.06461
# Epoch 625/700
# 31/31 - 4s - loss: 0.0090 - accuracy: 0.9980 - val_loss: 0.1758 - val_accuracy: 0.9618
#
# Epoch 00625: val_loss did not improve from 0.06461
# Epoch 626/700
# 31/31 - 4s - loss: 0.0068 - accuracy: 0.9975 - val_loss: 0.1425 - val_accuracy: 0.9638
#
# Epoch 00626: val_loss did not improve from 0.06461
# Epoch 627/700
# 31/31 - 4s - loss: 0.0092 - accuracy: 0.9975 - val_loss: 0.1045 - val_accuracy: 0.9839
#
# Epoch 00627: val_loss did not improve from 0.06461
# Epoch 628/700
# 31/31 - 4s - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.1217 - val_accuracy: 0.9738
#
# Epoch 00628: val_loss did not improve from 0.06461
# Epoch 629/700
# 31/31 - 4s - loss: 0.0085 - accuracy: 0.9955 - val_loss: 0.1122 - val_accuracy: 0.9799
#
# Epoch 00629: val_loss did not improve from 0.06461
# Epoch 630/700
# 31/31 - 4s - loss: 0.0101 - accuracy: 0.9965 - val_loss: 0.1195 - val_accuracy: 0.9799
#
# Epoch 00630: val_loss did not improve from 0.06461
# Epoch 631/700
# 31/31 - 4s - loss: 0.0119 - accuracy: 0.9965 - val_loss: 0.1616 - val_accuracy: 0.9598
#
# Epoch 00631: val_loss did not improve from 0.06461
# Epoch 632/700
# 31/31 - 4s - loss: 0.0124 - accuracy: 0.9965 - val_loss: 0.1888 - val_accuracy: 0.9638
#
# Epoch 00632: val_loss did not improve from 0.06461
# Epoch 633/700
# 31/31 - 4s - loss: 0.0140 - accuracy: 0.9960 - val_loss: 0.2988 - val_accuracy: 0.9376
#
# Epoch 00633: val_loss did not improve from 0.06461
# Epoch 634/700
# 31/31 - 4s - loss: 0.0046 - accuracy: 0.9990 - val_loss: 0.2919 - val_accuracy: 0.9396
#
# Epoch 00634: val_loss did not improve from 0.06461
# Epoch 635/700
# 31/31 - 4s - loss: 0.0111 - accuracy: 0.9970 - val_loss: 0.2532 - val_accuracy: 0.9457
#
# Epoch 00635: val_loss did not improve from 0.06461
# Epoch 636/700
# 31/31 - 4s - loss: 0.0095 - accuracy: 0.9975 - val_loss: 0.1587 - val_accuracy: 0.9698
#
# Epoch 00636: val_loss did not improve from 0.06461
# Epoch 637/700
# 31/31 - 4s - loss: 0.0123 - accuracy: 0.9965 - val_loss: 0.1187 - val_accuracy: 0.9779
#
# Epoch 00637: val_loss did not improve from 0.06461
# Epoch 638/700
# 31/31 - 4s - loss: 0.0127 - accuracy: 0.9940 - val_loss: 0.0951 - val_accuracy: 0.9839
#
# Epoch 00638: val_loss did not improve from 0.06461
# Epoch 639/700
# 31/31 - 4s - loss: 0.0069 - accuracy: 0.9970 - val_loss: 0.1106 - val_accuracy: 0.9799
#
# Epoch 00639: val_loss did not improve from 0.06461
# Epoch 640/700
# 31/31 - 4s - loss: 0.0106 - accuracy: 0.9965 - val_loss: 0.1556 - val_accuracy: 0.9678
#
# Epoch 00640: val_loss did not improve from 0.06461
# Epoch 641/700
# 31/31 - 4s - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.1604 - val_accuracy: 0.9598
#
# Epoch 00641: val_loss did not improve from 0.06461
# Epoch 642/700
# 31/31 - 4s - loss: 0.0056 - accuracy: 0.9985 - val_loss: 0.1494 - val_accuracy: 0.9638
#
# Epoch 00642: val_loss did not improve from 0.06461
# Epoch 643/700
# 31/31 - 4s - loss: 0.0101 - accuracy: 0.9960 - val_loss: 0.1026 - val_accuracy: 0.9738
#
# Epoch 00643: val_loss did not improve from 0.06461
# Epoch 644/700
# 31/31 - 4s - loss: 0.0124 - accuracy: 0.9955 - val_loss: 0.1818 - val_accuracy: 0.9497
#
# Epoch 00644: val_loss did not improve from 0.06461
# Epoch 645/700
# 31/31 - 4s - loss: 0.0092 - accuracy: 0.9955 - val_loss: 0.1555 - val_accuracy: 0.9658
#
# Epoch 00645: val_loss did not improve from 0.06461
# Epoch 646/700
# 31/31 - 4s - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.3001 - val_accuracy: 0.9296
#
# Epoch 00646: val_loss did not improve from 0.06461
# Epoch 647/700
# 31/31 - 4s - loss: 0.0081 - accuracy: 0.9965 - val_loss: 0.1941 - val_accuracy: 0.9598
#
# Epoch 00647: val_loss did not improve from 0.06461
# Epoch 648/700
# 31/31 - 4s - loss: 0.0068 - accuracy: 0.9970 - val_loss: 0.1876 - val_accuracy: 0.9678
#
# Epoch 00648: val_loss did not improve from 0.06461
# Epoch 649/700
# 31/31 - 4s - loss: 0.0066 - accuracy: 0.9980 - val_loss: 0.1491 - val_accuracy: 0.9759
#
# Epoch 00649: val_loss did not improve from 0.06461
# Epoch 650/700
# 31/31 - 4s - loss: 0.0178 - accuracy: 0.9945 - val_loss: 0.1209 - val_accuracy: 0.9698
#
# Epoch 00650: val_loss did not improve from 0.06461
# Epoch 651/700
# 31/31 - 4s - loss: 0.0109 - accuracy: 0.9950 - val_loss: 0.1151 - val_accuracy: 0.9577
#
# Epoch 00651: val_loss did not improve from 0.06461
# Epoch 652/700
# 31/31 - 4s - loss: 0.0097 - accuracy: 0.9960 - val_loss: 0.1644 - val_accuracy: 0.9577
#
# Epoch 00652: val_loss did not improve from 0.06461
# Epoch 653/700
# 31/31 - 4s - loss: 0.0077 - accuracy: 0.9965 - val_loss: 0.2572 - val_accuracy: 0.9276
#
# Epoch 00653: val_loss did not improve from 0.06461
# Epoch 654/700
# 31/31 - 4s - loss: 0.0117 - accuracy: 0.9960 - val_loss: 0.2080 - val_accuracy: 0.9396
#
# Epoch 00654: val_loss did not improve from 0.06461
# Epoch 655/700
# 31/31 - 4s - loss: 0.0059 - accuracy: 0.9985 - val_loss: 0.1069 - val_accuracy: 0.9678
#
# Epoch 00655: val_loss did not improve from 0.06461
# Epoch 656/700
# 31/31 - 4s - loss: 0.0097 - accuracy: 0.9965 - val_loss: 0.1658 - val_accuracy: 0.9678
#
# Epoch 00656: val_loss did not improve from 0.06461
# Epoch 657/700
# 31/31 - 4s - loss: 0.0110 - accuracy: 0.9960 - val_loss: 0.1761 - val_accuracy: 0.9537
#
# Epoch 00657: val_loss did not improve from 0.06461
# Epoch 658/700
# 31/31 - 4s - loss: 0.0119 - accuracy: 0.9960 - val_loss: 0.1053 - val_accuracy: 0.9698
#
# Epoch 00658: val_loss did not improve from 0.06461
# Epoch 659/700
# 31/31 - 4s - loss: 0.0127 - accuracy: 0.9940 - val_loss: 0.0850 - val_accuracy: 0.9819
#
# Epoch 00659: val_loss did not improve from 0.06461
# Epoch 660/700
# 31/31 - 4s - loss: 0.0073 - accuracy: 0.9975 - val_loss: 0.1459 - val_accuracy: 0.9638
#
# Epoch 00660: val_loss did not improve from 0.06461
# Epoch 661/700
# 31/31 - 4s - loss: 0.0107 - accuracy: 0.9965 - val_loss: 0.1288 - val_accuracy: 0.9698
#
# Epoch 00661: val_loss did not improve from 0.06461
# Epoch 662/700
# 31/31 - 4s - loss: 0.0095 - accuracy: 0.9955 - val_loss: 0.2421 - val_accuracy: 0.9276
#
# Epoch 00662: val_loss did not improve from 0.06461
# Epoch 663/700
# 31/31 - 4s - loss: 0.0123 - accuracy: 0.9960 - val_loss: 0.0863 - val_accuracy: 0.9759
#
# Epoch 00663: val_loss did not improve from 0.06461
# Epoch 664/700
# 31/31 - 4s - loss: 0.0130 - accuracy: 0.9955 - val_loss: 0.0680 - val_accuracy: 0.9819
#
# Epoch 00664: val_loss did not improve from 0.06461
# Epoch 665/700
# 31/31 - 4s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0701 - val_accuracy: 0.9839
#
# Epoch 00665: val_loss did not improve from 0.06461
# Epoch 666/700
# 31/31 - 4s - loss: 0.0088 - accuracy: 0.9965 - val_loss: 0.1123 - val_accuracy: 0.9819
#
# Epoch 00666: val_loss did not improve from 0.06461
# Epoch 667/700
# 31/31 - 4s - loss: 0.0109 - accuracy: 0.9965 - val_loss: 0.1052 - val_accuracy: 0.9738
#
# Epoch 00667: val_loss did not improve from 0.06461
# Epoch 668/700
# 31/31 - 4s - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.1100 - val_accuracy: 0.9698
#
# Epoch 00668: val_loss did not improve from 0.06461
# Epoch 669/700
# 31/31 - 4s - loss: 0.0075 - accuracy: 0.9970 - val_loss: 0.1145 - val_accuracy: 0.9779
#
# Epoch 00669: val_loss did not improve from 0.06461
# Epoch 670/700
# 31/31 - 4s - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.1030 - val_accuracy: 0.9718
#
# Epoch 00670: val_loss did not improve from 0.06461
# Epoch 671/700
# 31/31 - 4s - loss: 0.0106 - accuracy: 0.9955 - val_loss: 0.1045 - val_accuracy: 0.9839
#
# Epoch 00671: val_loss did not improve from 0.06461
# Epoch 672/700
# 31/31 - 4s - loss: 0.0126 - accuracy: 0.9940 - val_loss: 0.1874 - val_accuracy: 0.9638
#
# Epoch 00672: val_loss did not improve from 0.06461
# Epoch 673/700
# 31/31 - 4s - loss: 0.0070 - accuracy: 0.9970 - val_loss: 0.1294 - val_accuracy: 0.9718
#
# Epoch 00673: val_loss did not improve from 0.06461
# Epoch 674/700
# 31/31 - 4s - loss: 0.0110 - accuracy: 0.9955 - val_loss: 0.1140 - val_accuracy: 0.9779
#
# Epoch 00674: val_loss did not improve from 0.06461
# Epoch 675/700
# 31/31 - 4s - loss: 0.0102 - accuracy: 0.9970 - val_loss: 0.1269 - val_accuracy: 0.9718
#
# Epoch 00675: val_loss did not improve from 0.06461
# Epoch 676/700
# 31/31 - 4s - loss: 0.0107 - accuracy: 0.9960 - val_loss: 0.1338 - val_accuracy: 0.9698
#
# Epoch 00676: val_loss did not improve from 0.06461
# Epoch 677/700
# 31/31 - 4s - loss: 0.0097 - accuracy: 0.9970 - val_loss: 0.1394 - val_accuracy: 0.9759
#
# Epoch 00677: val_loss did not improve from 0.06461
# Epoch 678/700
# 31/31 - 4s - loss: 0.0067 - accuracy: 0.9975 - val_loss: 0.1921 - val_accuracy: 0.9517
#
# Epoch 00678: val_loss did not improve from 0.06461
# Epoch 679/700
# 31/31 - 4s - loss: 0.0078 - accuracy: 0.9970 - val_loss: 0.1162 - val_accuracy: 0.9698
#
# Epoch 00679: val_loss did not improve from 0.06461
# Epoch 680/700
# 31/31 - 4s - loss: 0.0087 - accuracy: 0.9965 - val_loss: 0.1033 - val_accuracy: 0.9779
#
# Epoch 00680: val_loss did not improve from 0.06461
# Epoch 681/700
# 31/31 - 4s - loss: 0.0092 - accuracy: 0.9965 - val_loss: 0.1179 - val_accuracy: 0.9779
#
# Epoch 00681: val_loss did not improve from 0.06461
# Epoch 682/700
# 31/31 - 4s - loss: 0.0062 - accuracy: 0.9985 - val_loss: 0.1899 - val_accuracy: 0.9457
#
# Epoch 00682: val_loss did not improve from 0.06461
# Epoch 683/700
# 31/31 - 4s - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.3978 - val_accuracy: 0.8913
#
# Epoch 00683: val_loss did not improve from 0.06461
# Epoch 684/700
# 31/31 - 4s - loss: 0.0074 - accuracy: 0.9980 - val_loss: 0.1526 - val_accuracy: 0.9618
#
# Epoch 00684: val_loss did not improve from 0.06461
# Epoch 685/700
# 31/31 - 4s - loss: 0.0075 - accuracy: 0.9975 - val_loss: 0.1195 - val_accuracy: 0.9759
#
# Epoch 00685: val_loss did not improve from 0.06461
# Epoch 686/700
# 31/31 - 4s - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.0984 - val_accuracy: 0.9759
#
# Epoch 00686: val_loss did not improve from 0.06461
# Epoch 687/700
# 31/31 - 4s - loss: 0.0094 - accuracy: 0.9960 - val_loss: 0.1344 - val_accuracy: 0.9779
#
# Epoch 00687: val_loss did not improve from 0.06461
# Epoch 688/700
# 31/31 - 4s - loss: 0.0106 - accuracy: 0.9955 - val_loss: 0.1501 - val_accuracy: 0.9698
#
# Epoch 00688: val_loss did not improve from 0.06461
# Epoch 689/700
# 31/31 - 4s - loss: 0.0118 - accuracy: 0.9975 - val_loss: 0.1503 - val_accuracy: 0.9557
#
# Epoch 00689: val_loss did not improve from 0.06461
# Epoch 690/700
# 31/31 - 4s - loss: 0.0123 - accuracy: 0.9965 - val_loss: 0.0766 - val_accuracy: 0.9859
#
# Epoch 00690: val_loss did not improve from 0.06461
# Epoch 691/700
# 31/31 - 4s - loss: 0.0160 - accuracy: 0.9955 - val_loss: 0.0693 - val_accuracy: 0.9799
#
# Epoch 00691: val_loss did not improve from 0.06461
# Epoch 692/700
# 31/31 - 4s - loss: 0.0085 - accuracy: 0.9975 - val_loss: 0.0801 - val_accuracy: 0.9799
#
# Epoch 00692: val_loss did not improve from 0.06461
# Epoch 693/700
# 31/31 - 4s - loss: 0.0163 - accuracy: 0.9924 - val_loss: 0.0993 - val_accuracy: 0.9698
#
# Epoch 00693: val_loss did not improve from 0.06461
# Epoch 694/700
# 31/31 - 4s - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.1225 - val_accuracy: 0.9759
#
# Epoch 00694: val_loss did not improve from 0.06461
# Epoch 695/700
# 31/31 - 4s - loss: 0.0098 - accuracy: 0.9970 - val_loss: 0.1245 - val_accuracy: 0.9799
#
# Epoch 00695: val_loss did not improve from 0.06461
# Epoch 696/700
# 31/31 - 4s - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.1677 - val_accuracy: 0.9658
#
# Epoch 00696: val_loss did not improve from 0.06461
# Epoch 697/700
# 31/31 - 4s - loss: 0.0081 - accuracy: 0.9970 - val_loss: 0.1534 - val_accuracy: 0.9658
#
# Epoch 00697: val_loss did not improve from 0.06461
# Epoch 698/700
# 31/31 - 4s - loss: 0.0113 - accuracy: 0.9960 - val_loss: 0.1762 - val_accuracy: 0.9638
#
# Epoch 00698: val_loss did not improve from 0.06461
# Epoch 699/700
# 31/31 - 4s - loss: 0.0115 - accuracy: 0.9940 - val_loss: 0.1331 - val_accuracy: 0.9678
#
# Epoch 00699: val_loss did not improve from 0.06461
# Epoch 700/700
# 31/31 - 4s - loss: 0.0171 - accuracy: 0.9945 - val_loss: 0.1321 - val_accuracy: 0.9759
#
# Epoch 00700: val_loss did not improve from 0.06461

# %%
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 16/16 [==============================] - 0s 22ms/step - loss: 0.1321 - accuracy: 0.9759
# Final Loss: 0.13212275505065918, Final Accuracy: 0.9758551120758057

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 145.31999999999996, 'Predicted')

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

print('Precision: %f' % precision_score(Y_true, Y_pred))
print('Recall: %f' % recall_score(Y_true, Y_pred))
print('F1 Score: %f' % f1_score(Y_true, Y_pred))
print('Accuracy: %f' % accuracy_score(Y_true, Y_pred))
# Out:
# Precision: 0.964758
# Recall: 0.982063
# F1 Score: 0.973333
# Accuracy: 0.975855

# %%
from sklearn.metrics import classification_report, confusion_matrix

Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

print( classification_report(Y_true, Y_pred))
print(confusion_matrix(Y_true, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       274
#            1       0.96      0.98      0.97       223
#
#     accuracy                           0.98       497
#    macro avg       0.97      0.98      0.98       497
# weighted avg       0.98      0.98      0.98       497
#
# [[266   8]
#  [  4 219]]

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from skimage import io
from keras.preprocessing import image
#path='imbalanced/Scratch/Scratch_400.jpg'
img = image.load_img('/content/COVID/Covid (1010).png', grayscale=False, target_size=(64, 64))
show_img=image.load_img('/content/COVID/Covid (1010).png', grayscale=False, target_size=(200, 200))
disease_class=['Covid-19','Non Covid-19']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255

custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [9.999999e-01 6.602201e-08]
# Prediction: Covid-19

# %%
from skimage import io
from keras.preprocessing import image
#path='imbalanced/Scratch/Scratch_400.jpg'
img = image.load_img('/content/non-COVID/Non-Covid (1007).png', grayscale=False, target_size=(64, 64))
show_img=image.load_img('/content/non-COVID/Non-Covid (1007).png', grayscale=False, target_size=(200, 200))
disease_class=['Covid-19','Non Covid-19']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255

custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [0.00166327 0.9983367 ]
# Prediction: Non Covid-19

# %%
from skimage import io
from keras.preprocessing import image
#path='imbalanced/Scratch/Scratch_400.jpg'
img = image.load_img('/content/1.png', grayscale=False, target_size=(64, 64))
show_img=image.load_img('/content/1.png', grayscale=False, target_size=(200, 200))
disease_class=['Covid-19','Non Covid-19']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255

custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [9.999995e-01 4.993813e-07]
# Prediction: Covid-19
