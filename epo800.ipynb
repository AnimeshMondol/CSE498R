# %% [markdown]
# <a href="https://colab.research.google.com/github/AnimeshMondol/CSE498R/blob/main/epo800.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sat Jun 19 13:52:38 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.5.30)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b7d6d6b2-15a3-44e4-ac75-b3a4c94415e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b7d6d6b2-15a3-44e4-ac75-b3a4c94415e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle

#Change permission
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d plameneduardo/sarscov2-ctscan-dataset
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 146, in authenticate
#     self.config_file, self.config_dir))
# IOError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
from zipfile import ZipFile
file_name = "sarscov2-ctscan-dataset.zip"

with ZipFile(file_name,"r") as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
        #print(os.path.join(dirname, filename))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.densenet import DenseNet121

# %%
disease_types=['COVID', 'non-COVID']
data_dir = '/content'
train_dir = os.path.join(data_dir)

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.head()
# Out:
#                      File  DiseaseID Disease Type
# 0   COVID/Covid (647).png          0        COVID
# 1   COVID/Covid (697).png          0        COVID
# 2  COVID/Covid (1116).png          0        COVID
# 3   COVID/Covid (999).png          0        COVID
# 4  COVID/Covid (1245).png          0        COVID

# %%
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#                             File  DiseaseID Disease Type
# 0          COVID/Covid (681).png          0        COVID
# 1          COVID/Covid (107).png          0        COVID
# 2  non-COVID/Non-Covid (593).png          1    non-COVID
# 3   non-COVID/Non-Covid (77).png          1    non-COVID
# 4         COVID/Covid (1082).png          0        COVID

# %%
plt.hist(train['DiseaseID'])
plt.title('Frequency Histogram of Species')
plt.figure(figsize=(12, 12))
plt.show()

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('COVID', 5, 5)

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('non-COVID', 5, 5)

# %%
IMAGE_SIZE = 64
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 2481it [00:08, 301.15it/s]
# Train Shape: (2481, 64, 64, 3)

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=2)

# %%
BATCH_SIZE = 64

# Split the train and validation sets 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 15))
for i in range(3):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(disease_types[np.argmax(Y_train[i])])

# %%
EPOCHS = 800
SIZE=64
N_ch=3

# %%
def build_densenet():
    densenet = DenseNet121(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = densenet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    optimizer = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
model = build_densenet()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        zoom_range=0.2, # Range for random zoom
                        horizontal_flip=True, # Randomly flip inputs horizontally
                        vertical_flip=True) # Randomly flip inputs vertically

datagen.fit(X_train)
# Fits the model on batches with real-time data augmentation
hist = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# 29097984/29084464 [==============================] - 0s 0us/step
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 3)         84
# _________________________________________________________________
# densenet121 (Functional)     (None, None, None, 1024)  7037504
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               262400
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# root (Dense)                 (None, 2)                 514
# =================================================================
# Total params: 7,305,622
# Trainable params: 7,219,414
# Non-trainable params: 86,208
# _________________________________________________________________
# Epoch 1/800
# 31/31 - 91s - loss: 1.1395 - accuracy: 0.5494 - val_loss: 0.8878 - val_accuracy: 0.5131
#
# Epoch 00001: val_loss improved from inf to 0.88781, saving model to model.h5
# Epoch 2/800
# 31/31 - 4s - loss: 0.9406 - accuracy: 0.6169 - val_loss: 1.0613 - val_accuracy: 0.4668
#
# Epoch 00002: val_loss did not improve from 0.88781
# Epoch 3/800
# 31/31 - 4s - loss: 0.8203 - accuracy: 0.6653 - val_loss: 1.1646 - val_accuracy: 0.4507
#
# Epoch 00003: val_loss did not improve from 0.88781
# Epoch 4/800
# 31/31 - 4s - loss: 0.7320 - accuracy: 0.7021 - val_loss: 1.5753 - val_accuracy: 0.4909
#
# Epoch 00004: val_loss did not improve from 0.88781
# Epoch 5/800
# 31/31 - 4s - loss: 0.6620 - accuracy: 0.7213 - val_loss: 1.3284 - val_accuracy: 0.5352
#
# Epoch 00005: val_loss did not improve from 0.88781
# Epoch 6/800
# 31/31 - 4s - loss: 0.6085 - accuracy: 0.7434 - val_loss: 1.1421 - val_accuracy: 0.5412
#
# Epoch 00006: val_loss did not improve from 0.88781
# Epoch 7/800
# 31/31 - 4s - loss: 0.5634 - accuracy: 0.7581 - val_loss: 1.0890 - val_accuracy: 0.5835
#
# Epoch 00007: val_loss did not improve from 0.88781
# Epoch 8/800
# 31/31 - 4s - loss: 0.5579 - accuracy: 0.7666 - val_loss: 1.2980 - val_accuracy: 0.5553
#
# Epoch 00008: val_loss did not improve from 0.88781
# Epoch 9/800
# 31/31 - 4s - loss: 0.5051 - accuracy: 0.7939 - val_loss: 1.2409 - val_accuracy: 0.5614
#
# Epoch 00009: val_loss did not improve from 0.88781
# Epoch 10/800
# 31/31 - 4s - loss: 0.4364 - accuracy: 0.8075 - val_loss: 1.1502 - val_accuracy: 0.5674
#
# Epoch 00010: val_loss did not improve from 0.88781
# Epoch 11/800
# 31/31 - 4s - loss: 0.4441 - accuracy: 0.8170 - val_loss: 0.7530 - val_accuracy: 0.6620
#
# Epoch 00011: val_loss improved from 0.88781 to 0.75303, saving model to model.h5
# Epoch 12/800
# 31/31 - 4s - loss: 0.4259 - accuracy: 0.8216 - val_loss: 0.7167 - val_accuracy: 0.7062
#
# Epoch 00012: val_loss improved from 0.75303 to 0.71672, saving model to model.h5
# Epoch 13/800
# 31/31 - 4s - loss: 0.4383 - accuracy: 0.8170 - val_loss: 0.5071 - val_accuracy: 0.7505
#
# Epoch 00013: val_loss improved from 0.71672 to 0.50708, saving model to model.h5
# Epoch 14/800
# 31/31 - 4s - loss: 0.3929 - accuracy: 0.8347 - val_loss: 0.4052 - val_accuracy: 0.8109
#
# Epoch 00014: val_loss improved from 0.50708 to 0.40519, saving model to model.h5
# Epoch 15/800
# 31/31 - 4s - loss: 0.3714 - accuracy: 0.8438 - val_loss: 0.3938 - val_accuracy: 0.8229
#
# Epoch 00015: val_loss improved from 0.40519 to 0.39382, saving model to model.h5
# Epoch 16/800
# 31/31 - 4s - loss: 0.3697 - accuracy: 0.8397 - val_loss: 0.3558 - val_accuracy: 0.8431
#
# Epoch 00016: val_loss improved from 0.39382 to 0.35585, saving model to model.h5
# Epoch 17/800
# 31/31 - 4s - loss: 0.3619 - accuracy: 0.8448 - val_loss: 0.3778 - val_accuracy: 0.8189
#
# Epoch 00017: val_loss did not improve from 0.35585
# Epoch 18/800
# 31/31 - 4s - loss: 0.3625 - accuracy: 0.8574 - val_loss: 0.7997 - val_accuracy: 0.6378
#
# Epoch 00018: val_loss did not improve from 0.35585
# Epoch 19/800
# 31/31 - 4s - loss: 0.3292 - accuracy: 0.8624 - val_loss: 0.3119 - val_accuracy: 0.8732
#
# Epoch 00019: val_loss improved from 0.35585 to 0.31194, saving model to model.h5
# Epoch 20/800
# 31/31 - 4s - loss: 0.3226 - accuracy: 0.8614 - val_loss: 0.2998 - val_accuracy: 0.8753
#
# Epoch 00020: val_loss improved from 0.31194 to 0.29981, saving model to model.h5
# Epoch 21/800
# 31/31 - 4s - loss: 0.3062 - accuracy: 0.8695 - val_loss: 0.3181 - val_accuracy: 0.8632
#
# Epoch 00021: val_loss did not improve from 0.29981
# Epoch 22/800
# 31/31 - 4s - loss: 0.3086 - accuracy: 0.8755 - val_loss: 0.3071 - val_accuracy: 0.8612
#
# Epoch 00022: val_loss did not improve from 0.29981
# Epoch 23/800
# 31/31 - 4s - loss: 0.3039 - accuracy: 0.8730 - val_loss: 0.3406 - val_accuracy: 0.8571
#
# Epoch 00023: val_loss did not improve from 0.29981
# Epoch 24/800
# 31/31 - 4s - loss: 0.2971 - accuracy: 0.8795 - val_loss: 0.3280 - val_accuracy: 0.8471
#
# Epoch 00024: val_loss did not improve from 0.29981
# Epoch 25/800
# 31/31 - 4s - loss: 0.3050 - accuracy: 0.8841 - val_loss: 0.4017 - val_accuracy: 0.8129
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 00025: val_loss did not improve from 0.29981
# Epoch 26/800
# 31/31 - 4s - loss: 0.2735 - accuracy: 0.8881 - val_loss: 0.4037 - val_accuracy: 0.8169
#
# Epoch 00026: val_loss did not improve from 0.29981
# Epoch 27/800
# 31/31 - 4s - loss: 0.2711 - accuracy: 0.8926 - val_loss: 0.3282 - val_accuracy: 0.8471
#
# Epoch 00027: val_loss did not improve from 0.29981
# Epoch 28/800
# 31/31 - 4s - loss: 0.2811 - accuracy: 0.8881 - val_loss: 0.4298 - val_accuracy: 0.8008
#
# Epoch 00028: val_loss did not improve from 0.29981
# Epoch 29/800
# 31/31 - 4s - loss: 0.2808 - accuracy: 0.8861 - val_loss: 0.3256 - val_accuracy: 0.8491
#
# Epoch 00029: val_loss did not improve from 0.29981
# Epoch 30/800
# 31/31 - 4s - loss: 0.2749 - accuracy: 0.8881 - val_loss: 0.2831 - val_accuracy: 0.8813
#
# Epoch 00030: val_loss improved from 0.29981 to 0.28306, saving model to model.h5
# Epoch 31/800
# 31/31 - 4s - loss: 0.2573 - accuracy: 0.8952 - val_loss: 0.4993 - val_accuracy: 0.7545
#
# Epoch 00031: val_loss did not improve from 0.28306
# Epoch 32/800
# 31/31 - 4s - loss: 0.2695 - accuracy: 0.8916 - val_loss: 0.3246 - val_accuracy: 0.8551
#
# Epoch 00032: val_loss did not improve from 0.28306
# Epoch 33/800
# 31/31 - 4s - loss: 0.2666 - accuracy: 0.8916 - val_loss: 0.2854 - val_accuracy: 0.8712
#
# Epoch 00033: val_loss did not improve from 0.28306
# Epoch 34/800
# 31/31 - 4s - loss: 0.2621 - accuracy: 0.8962 - val_loss: 0.2522 - val_accuracy: 0.8934
#
# Epoch 00034: val_loss improved from 0.28306 to 0.25222, saving model to model.h5
# Epoch 35/800
# 31/31 - 4s - loss: 0.2610 - accuracy: 0.8947 - val_loss: 0.2756 - val_accuracy: 0.8793
#
# Epoch 00035: val_loss did not improve from 0.25222
# Epoch 36/800
# 31/31 - 4s - loss: 0.2382 - accuracy: 0.9017 - val_loss: 0.3676 - val_accuracy: 0.8270
#
# Epoch 00036: val_loss did not improve from 0.25222
# Epoch 37/800
# 31/31 - 4s - loss: 0.2595 - accuracy: 0.8962 - val_loss: 0.2644 - val_accuracy: 0.8853
#
# Epoch 00037: val_loss did not improve from 0.25222
# Epoch 38/800
# 31/31 - 4s - loss: 0.2373 - accuracy: 0.9022 - val_loss: 0.3045 - val_accuracy: 0.8672
#
# Epoch 00038: val_loss did not improve from 0.25222
# Epoch 39/800
# 31/31 - 4s - loss: 0.2490 - accuracy: 0.9022 - val_loss: 0.2351 - val_accuracy: 0.9095
#
# Epoch 00039: val_loss improved from 0.25222 to 0.23511, saving model to model.h5
# Epoch 40/800
# 31/31 - 4s - loss: 0.2437 - accuracy: 0.9007 - val_loss: 0.3809 - val_accuracy: 0.8169
#
# Epoch 00040: val_loss did not improve from 0.23511
# Epoch 41/800
# 31/31 - 4s - loss: 0.2468 - accuracy: 0.9047 - val_loss: 0.3363 - val_accuracy: 0.8431
#
# Epoch 00041: val_loss did not improve from 0.23511
# Epoch 42/800
# 31/31 - 4s - loss: 0.2312 - accuracy: 0.9052 - val_loss: 0.3021 - val_accuracy: 0.8652
#
# Epoch 00042: val_loss did not improve from 0.23511
# Epoch 43/800
# 31/31 - 4s - loss: 0.2379 - accuracy: 0.8982 - val_loss: 0.2554 - val_accuracy: 0.8994
#
# Epoch 00043: val_loss did not improve from 0.23511
# Epoch 44/800
# 31/31 - 4s - loss: 0.2507 - accuracy: 0.9027 - val_loss: 0.4185 - val_accuracy: 0.7988
#
# Epoch 00044: val_loss did not improve from 0.23511
# Epoch 45/800
# 31/31 - 4s - loss: 0.2227 - accuracy: 0.9088 - val_loss: 0.4744 - val_accuracy: 0.7968
#
# Epoch 00045: val_loss did not improve from 0.23511
# Epoch 46/800
# 31/31 - 4s - loss: 0.2203 - accuracy: 0.9178 - val_loss: 0.2268 - val_accuracy: 0.9095
#
# Epoch 00046: val_loss improved from 0.23511 to 0.22684, saving model to model.h5
# Epoch 47/800
# 31/31 - 4s - loss: 0.2251 - accuracy: 0.9083 - val_loss: 0.1962 - val_accuracy: 0.9054
#
# Epoch 00047: val_loss improved from 0.22684 to 0.19621, saving model to model.h5
# Epoch 48/800
# 31/31 - 4s - loss: 0.2318 - accuracy: 0.9062 - val_loss: 0.2933 - val_accuracy: 0.8753
#
# Epoch 00048: val_loss did not improve from 0.19621
# Epoch 49/800
# 31/31 - 4s - loss: 0.2119 - accuracy: 0.9138 - val_loss: 0.3314 - val_accuracy: 0.8712
#
# Epoch 00049: val_loss did not improve from 0.19621
# Epoch 50/800
# 31/31 - 4s - loss: 0.2122 - accuracy: 0.9128 - val_loss: 0.1916 - val_accuracy: 0.9054
#
# Epoch 00050: val_loss improved from 0.19621 to 0.19160, saving model to model.h5
# Epoch 51/800
# 31/31 - 4s - loss: 0.2158 - accuracy: 0.9098 - val_loss: 0.1954 - val_accuracy: 0.9235
#
# Epoch 00051: val_loss did not improve from 0.19160
# Epoch 52/800
# 31/31 - 4s - loss: 0.2383 - accuracy: 0.9007 - val_loss: 0.2158 - val_accuracy: 0.9074
#
# Epoch 00052: val_loss did not improve from 0.19160
# Epoch 53/800
# 31/31 - 4s - loss: 0.2303 - accuracy: 0.9108 - val_loss: 0.4083 - val_accuracy: 0.8310
#
# Epoch 00053: val_loss did not improve from 0.19160
# Epoch 54/800
# 31/31 - 4s - loss: 0.1949 - accuracy: 0.9274 - val_loss: 0.2405 - val_accuracy: 0.8934
#
# Epoch 00054: val_loss did not improve from 0.19160
# Epoch 55/800
# 31/31 - 4s - loss: 0.2231 - accuracy: 0.9052 - val_loss: 0.2078 - val_accuracy: 0.8954
#
# Epoch 00055: val_loss did not improve from 0.19160
# Epoch 56/800
# 31/31 - 4s - loss: 0.2077 - accuracy: 0.9128 - val_loss: 0.2627 - val_accuracy: 0.8934
#
# Epoch 00056: val_loss did not improve from 0.19160
# Epoch 57/800
# 31/31 - 4s - loss: 0.2011 - accuracy: 0.9113 - val_loss: 0.2424 - val_accuracy: 0.8974
#
# Epoch 00057: val_loss did not improve from 0.19160
# Epoch 58/800
# 31/31 - 4s - loss: 0.2279 - accuracy: 0.9118 - val_loss: 0.2066 - val_accuracy: 0.9014
#
# Epoch 00058: val_loss did not improve from 0.19160
# Epoch 59/800
# 31/31 - 4s - loss: 0.2159 - accuracy: 0.9163 - val_loss: 0.2059 - val_accuracy: 0.9155
#
# Epoch 00059: val_loss did not improve from 0.19160
# Epoch 60/800
# 31/31 - 4s - loss: 0.2081 - accuracy: 0.9118 - val_loss: 0.3835 - val_accuracy: 0.8229
#
# Epoch 00060: val_loss did not improve from 0.19160
# Epoch 61/800
# 31/31 - 4s - loss: 0.1900 - accuracy: 0.9244 - val_loss: 0.3438 - val_accuracy: 0.8592
#
# Epoch 00061: val_loss did not improve from 0.19160
# Epoch 62/800
# 31/31 - 4s - loss: 0.1967 - accuracy: 0.9168 - val_loss: 0.3002 - val_accuracy: 0.8793
#
# Epoch 00062: val_loss did not improve from 0.19160
# Epoch 63/800
# 31/31 - 4s - loss: 0.2065 - accuracy: 0.9234 - val_loss: 0.2078 - val_accuracy: 0.8954
#
# Epoch 00063: val_loss did not improve from 0.19160
# Epoch 64/800
# 31/31 - 4s - loss: 0.2034 - accuracy: 0.9143 - val_loss: 0.2144 - val_accuracy: 0.9074
#
# Epoch 00064: val_loss did not improve from 0.19160
# Epoch 65/800
# 31/31 - 4s - loss: 0.1957 - accuracy: 0.9199 - val_loss: 0.2292 - val_accuracy: 0.8873
#
# Epoch 00065: val_loss did not improve from 0.19160
# Epoch 66/800
# 31/31 - 4s - loss: 0.1901 - accuracy: 0.9209 - val_loss: 0.2037 - val_accuracy: 0.9135
#
# Epoch 00066: val_loss did not improve from 0.19160
# Epoch 67/800
# 31/31 - 4s - loss: 0.2016 - accuracy: 0.9269 - val_loss: 0.3284 - val_accuracy: 0.8672
#
# Epoch 00067: val_loss did not improve from 0.19160
# Epoch 68/800
# 31/31 - 4s - loss: 0.1976 - accuracy: 0.9189 - val_loss: 0.4333 - val_accuracy: 0.8149
#
# Epoch 00068: val_loss did not improve from 0.19160
# Epoch 69/800
# 31/31 - 4s - loss: 0.1925 - accuracy: 0.9199 - val_loss: 0.4507 - val_accuracy: 0.8249
#
# Epoch 00069: val_loss did not improve from 0.19160
# Epoch 70/800
# 31/31 - 4s - loss: 0.1998 - accuracy: 0.9128 - val_loss: 0.1988 - val_accuracy: 0.9115
#
# Epoch 00070: val_loss did not improve from 0.19160
# Epoch 71/800
# 31/31 - 4s - loss: 0.1976 - accuracy: 0.9254 - val_loss: 0.2745 - val_accuracy: 0.8873
#
# Epoch 00071: val_loss did not improve from 0.19160
# Epoch 72/800
# 31/31 - 4s - loss: 0.1693 - accuracy: 0.9289 - val_loss: 0.4953 - val_accuracy: 0.7968
#
# Epoch 00072: val_loss did not improve from 0.19160
# Epoch 73/800
# 31/31 - 4s - loss: 0.2004 - accuracy: 0.9158 - val_loss: 0.5112 - val_accuracy: 0.7968
#
# Epoch 00073: val_loss did not improve from 0.19160
# Epoch 74/800
# 31/31 - 4s - loss: 0.1802 - accuracy: 0.9214 - val_loss: 0.2242 - val_accuracy: 0.8913
#
# Epoch 00074: val_loss did not improve from 0.19160
# Epoch 75/800
# 31/31 - 4s - loss: 0.1943 - accuracy: 0.9234 - val_loss: 0.1956 - val_accuracy: 0.9115
#
# Epoch 00075: val_loss did not improve from 0.19160
# Epoch 76/800
# 31/31 - 4s - loss: 0.1866 - accuracy: 0.9234 - val_loss: 0.1999 - val_accuracy: 0.9155
#
# Epoch 00076: val_loss did not improve from 0.19160
# Epoch 77/800
# 31/31 - 4s - loss: 0.1762 - accuracy: 0.9244 - val_loss: 0.1752 - val_accuracy: 0.9296
#
# Epoch 00077: val_loss improved from 0.19160 to 0.17520, saving model to model.h5
# Epoch 78/800
# 31/31 - 4s - loss: 0.1814 - accuracy: 0.9284 - val_loss: 0.2012 - val_accuracy: 0.8994
#
# Epoch 00078: val_loss did not improve from 0.17520
# Epoch 79/800
# 31/31 - 4s - loss: 0.1709 - accuracy: 0.9264 - val_loss: 0.1638 - val_accuracy: 0.9276
#
# Epoch 00079: val_loss improved from 0.17520 to 0.16380, saving model to model.h5
# Epoch 80/800
# 31/31 - 4s - loss: 0.1780 - accuracy: 0.9289 - val_loss: 0.1708 - val_accuracy: 0.9235
#
# Epoch 00080: val_loss did not improve from 0.16380
# Epoch 81/800
# 31/31 - 4s - loss: 0.1612 - accuracy: 0.9299 - val_loss: 0.2118 - val_accuracy: 0.9034
#
# Epoch 00081: val_loss did not improve from 0.16380
# Epoch 82/800
# 31/31 - 4s - loss: 0.1831 - accuracy: 0.9229 - val_loss: 0.3566 - val_accuracy: 0.8773
#
# Epoch 00082: val_loss did not improve from 0.16380
# Epoch 83/800
# 31/31 - 4s - loss: 0.1860 - accuracy: 0.9264 - val_loss: 0.2606 - val_accuracy: 0.8773
#
# Epoch 00083: val_loss did not improve from 0.16380
# Epoch 84/800
# 31/31 - 4s - loss: 0.1829 - accuracy: 0.9204 - val_loss: 0.3475 - val_accuracy: 0.8692
#
# Epoch 00084: val_loss did not improve from 0.16380
# Epoch 85/800
# 31/31 - 4s - loss: 0.1579 - accuracy: 0.9350 - val_loss: 0.1772 - val_accuracy: 0.9195
#
# Epoch 00085: val_loss did not improve from 0.16380
# Epoch 86/800
# 31/31 - 4s - loss: 0.1644 - accuracy: 0.9294 - val_loss: 0.1675 - val_accuracy: 0.9296
#
# Epoch 00086: val_loss did not improve from 0.16380
# Epoch 87/800
# 31/31 - 4s - loss: 0.1671 - accuracy: 0.9370 - val_loss: 0.1881 - val_accuracy: 0.9115
#
# Epoch 00087: val_loss did not improve from 0.16380
# Epoch 88/800
# 31/31 - 4s - loss: 0.1743 - accuracy: 0.9284 - val_loss: 0.1747 - val_accuracy: 0.9195
#
# Epoch 00088: val_loss did not improve from 0.16380
# Epoch 89/800
# 31/31 - 4s - loss: 0.1679 - accuracy: 0.9309 - val_loss: 0.2151 - val_accuracy: 0.9175
#
# Epoch 00089: val_loss did not improve from 0.16380
# Epoch 90/800
# 31/31 - 4s - loss: 0.1572 - accuracy: 0.9309 - val_loss: 0.1881 - val_accuracy: 0.9155
#
# Epoch 00090: val_loss did not improve from 0.16380
# Epoch 91/800
# 31/31 - 4s - loss: 0.1365 - accuracy: 0.9456 - val_loss: 0.2441 - val_accuracy: 0.9034
#
# Epoch 00091: val_loss did not improve from 0.16380
# Epoch 92/800
# 31/31 - 4s - loss: 0.1504 - accuracy: 0.9451 - val_loss: 0.1805 - val_accuracy: 0.9195
#
# Epoch 00092: val_loss did not improve from 0.16380
# Epoch 93/800
# 31/31 - 4s - loss: 0.1714 - accuracy: 0.9284 - val_loss: 0.2525 - val_accuracy: 0.8954
#
# Epoch 00093: val_loss did not improve from 0.16380
# Epoch 94/800
# 31/31 - 4s - loss: 0.1498 - accuracy: 0.9390 - val_loss: 0.1875 - val_accuracy: 0.9135
#
# Epoch 00094: val_loss did not improve from 0.16380
# Epoch 95/800
# 31/31 - 4s - loss: 0.1512 - accuracy: 0.9395 - val_loss: 0.2292 - val_accuracy: 0.9034
#
# Epoch 00095: val_loss did not improve from 0.16380
# Epoch 96/800
# 31/31 - 4s - loss: 0.1462 - accuracy: 0.9375 - val_loss: 0.2731 - val_accuracy: 0.8994
#
# Epoch 00096: val_loss did not improve from 0.16380
# Epoch 97/800
# 31/31 - 4s - loss: 0.1467 - accuracy: 0.9400 - val_loss: 0.2617 - val_accuracy: 0.8954
#
# Epoch 00097: val_loss did not improve from 0.16380
# Epoch 98/800
# 31/31 - 4s - loss: 0.1515 - accuracy: 0.9395 - val_loss: 0.2889 - val_accuracy: 0.8813
#
# Epoch 00098: val_loss did not improve from 0.16380
# Epoch 99/800
# 31/31 - 4s - loss: 0.1689 - accuracy: 0.9385 - val_loss: 1.2916 - val_accuracy: 0.6841
#
# Epoch 00099: val_loss did not improve from 0.16380
# Epoch 100/800
# 31/31 - 4s - loss: 0.1532 - accuracy: 0.9405 - val_loss: 0.3717 - val_accuracy: 0.8551
#
# Epoch 00100: val_loss did not improve from 0.16380
# Epoch 101/800
# 31/31 - 4s - loss: 0.1339 - accuracy: 0.9466 - val_loss: 0.1853 - val_accuracy: 0.9235
#
# Epoch 00101: val_loss did not improve from 0.16380
# Epoch 102/800
# 31/31 - 4s - loss: 0.1455 - accuracy: 0.9370 - val_loss: 0.2118 - val_accuracy: 0.9235
#
# Epoch 00102: val_loss did not improve from 0.16380
# Epoch 103/800
# 31/31 - 4s - loss: 0.1420 - accuracy: 0.9456 - val_loss: 0.1739 - val_accuracy: 0.9155
#
# Epoch 00103: val_loss did not improve from 0.16380
# Epoch 104/800
# 31/31 - 4s - loss: 0.1457 - accuracy: 0.9425 - val_loss: 0.1641 - val_accuracy: 0.9235
#
# Epoch 00104: val_loss did not improve from 0.16380
# Epoch 105/800
# 31/31 - 4s - loss: 0.1458 - accuracy: 0.9425 - val_loss: 0.3035 - val_accuracy: 0.8853
#
# Epoch 00105: val_loss did not improve from 0.16380
# Epoch 106/800
# 31/31 - 4s - loss: 0.1521 - accuracy: 0.9345 - val_loss: 0.4602 - val_accuracy: 0.8209
#
# Epoch 00106: val_loss did not improve from 0.16380
# Epoch 107/800
# 31/31 - 4s - loss: 0.1431 - accuracy: 0.9441 - val_loss: 0.3939 - val_accuracy: 0.8410
#
# Epoch 00107: val_loss did not improve from 0.16380
# Epoch 108/800
# 31/31 - 4s - loss: 0.1251 - accuracy: 0.9496 - val_loss: 0.4406 - val_accuracy: 0.8511
#
# Epoch 00108: val_loss did not improve from 0.16380
# Epoch 109/800
# 31/31 - 4s - loss: 0.1417 - accuracy: 0.9435 - val_loss: 0.6078 - val_accuracy: 0.7928
#
# Epoch 00109: val_loss did not improve from 0.16380
# Epoch 110/800
# 31/31 - 4s - loss: 0.1452 - accuracy: 0.9395 - val_loss: 0.2147 - val_accuracy: 0.9276
#
# Epoch 00110: val_loss did not improve from 0.16380
# Epoch 111/800
# 31/31 - 4s - loss: 0.1325 - accuracy: 0.9491 - val_loss: 0.1787 - val_accuracy: 0.9276
#
# Epoch 00111: val_loss did not improve from 0.16380
# Epoch 112/800
# 31/31 - 4s - loss: 0.1262 - accuracy: 0.9541 - val_loss: 0.1655 - val_accuracy: 0.9356
#
# Epoch 00112: val_loss did not improve from 0.16380
# Epoch 113/800
# 31/31 - 4s - loss: 0.1362 - accuracy: 0.9481 - val_loss: 0.1679 - val_accuracy: 0.9316
#
# Epoch 00113: val_loss did not improve from 0.16380
# Epoch 114/800
# 31/31 - 4s - loss: 0.1306 - accuracy: 0.9451 - val_loss: 0.3325 - val_accuracy: 0.8712
#
# Epoch 00114: val_loss did not improve from 0.16380
# Epoch 115/800
# 31/31 - 4s - loss: 0.1402 - accuracy: 0.9476 - val_loss: 0.1681 - val_accuracy: 0.9376
#
# Epoch 00115: val_loss did not improve from 0.16380
# Epoch 116/800
# 31/31 - 4s - loss: 0.1175 - accuracy: 0.9531 - val_loss: 0.1744 - val_accuracy: 0.9256
#
# Epoch 00116: val_loss did not improve from 0.16380
# Epoch 117/800
# 31/31 - 4s - loss: 0.1279 - accuracy: 0.9456 - val_loss: 0.2256 - val_accuracy: 0.9074
#
# Epoch 00117: val_loss did not improve from 0.16380
# Epoch 118/800
# 31/31 - 4s - loss: 0.1353 - accuracy: 0.9526 - val_loss: 0.3813 - val_accuracy: 0.8531
#
# Epoch 00118: val_loss did not improve from 0.16380
# Epoch 119/800
# 31/31 - 4s - loss: 0.1308 - accuracy: 0.9546 - val_loss: 0.1730 - val_accuracy: 0.9195
#
# Epoch 00119: val_loss did not improve from 0.16380
# Epoch 120/800
# 31/31 - 4s - loss: 0.1118 - accuracy: 0.9607 - val_loss: 0.1602 - val_accuracy: 0.9356
#
# Epoch 00120: val_loss improved from 0.16380 to 0.16019, saving model to model.h5
# Epoch 121/800
# 31/31 - 4s - loss: 0.1176 - accuracy: 0.9531 - val_loss: 0.8127 - val_accuracy: 0.7767
#
# Epoch 00121: val_loss did not improve from 0.16019
# Epoch 122/800
# 31/31 - 4s - loss: 0.1369 - accuracy: 0.9451 - val_loss: 0.4093 - val_accuracy: 0.8612
#
# Epoch 00122: val_loss did not improve from 0.16019
# Epoch 123/800
# 31/31 - 4s - loss: 0.1097 - accuracy: 0.9561 - val_loss: 0.1590 - val_accuracy: 0.9316
#
# Epoch 00123: val_loss improved from 0.16019 to 0.15898, saving model to model.h5
# Epoch 124/800
# 31/31 - 4s - loss: 0.1156 - accuracy: 0.9536 - val_loss: 0.5588 - val_accuracy: 0.8149
#
# Epoch 00124: val_loss did not improve from 0.15898
# Epoch 125/800
# 31/31 - 4s - loss: 0.1512 - accuracy: 0.9340 - val_loss: 0.1619 - val_accuracy: 0.9316
#
# Epoch 00125: val_loss did not improve from 0.15898
# Epoch 126/800
# 31/31 - 4s - loss: 0.1174 - accuracy: 0.9506 - val_loss: 0.2965 - val_accuracy: 0.8954
#
# Epoch 00126: val_loss did not improve from 0.15898
# Epoch 127/800
# 31/31 - 4s - loss: 0.1293 - accuracy: 0.9481 - val_loss: 0.3415 - val_accuracy: 0.8531
#
# Epoch 00127: val_loss did not improve from 0.15898
# Epoch 128/800
# 31/31 - 4s - loss: 0.1288 - accuracy: 0.9511 - val_loss: 0.4754 - val_accuracy: 0.8350
#
# Epoch 00128: val_loss did not improve from 0.15898
# Epoch 129/800
# 31/31 - 4s - loss: 0.1152 - accuracy: 0.9521 - val_loss: 0.1428 - val_accuracy: 0.9437
#
# Epoch 00129: val_loss improved from 0.15898 to 0.14285, saving model to model.h5
# Epoch 130/800
# 31/31 - 4s - loss: 0.1206 - accuracy: 0.9501 - val_loss: 0.1896 - val_accuracy: 0.9256
#
# Epoch 00130: val_loss did not improve from 0.14285
# Epoch 131/800
# 31/31 - 4s - loss: 0.1140 - accuracy: 0.9556 - val_loss: 0.3352 - val_accuracy: 0.8732
#
# Epoch 00131: val_loss did not improve from 0.14285
# Epoch 132/800
# 31/31 - 4s - loss: 0.1202 - accuracy: 0.9531 - val_loss: 0.2356 - val_accuracy: 0.9034
#
# Epoch 00132: val_loss did not improve from 0.14285
# Epoch 133/800
# 31/31 - 4s - loss: 0.0928 - accuracy: 0.9622 - val_loss: 0.1362 - val_accuracy: 0.9336
#
# Epoch 00133: val_loss improved from 0.14285 to 0.13616, saving model to model.h5
# Epoch 134/800
# 31/31 - 4s - loss: 0.1259 - accuracy: 0.9526 - val_loss: 0.1173 - val_accuracy: 0.9477
#
# Epoch 00134: val_loss improved from 0.13616 to 0.11733, saving model to model.h5
# Epoch 135/800
# 31/31 - 4s - loss: 0.1244 - accuracy: 0.9506 - val_loss: 0.1417 - val_accuracy: 0.9396
#
# Epoch 00135: val_loss did not improve from 0.11733
# Epoch 136/800
# 31/31 - 4s - loss: 0.1142 - accuracy: 0.9536 - val_loss: 0.2176 - val_accuracy: 0.9115
#
# Epoch 00136: val_loss did not improve from 0.11733
# Epoch 137/800
# 31/31 - 4s - loss: 0.1086 - accuracy: 0.9587 - val_loss: 0.3047 - val_accuracy: 0.8873
#
# Epoch 00137: val_loss did not improve from 0.11733
# Epoch 138/800
# 31/31 - 4s - loss: 0.1150 - accuracy: 0.9506 - val_loss: 0.4513 - val_accuracy: 0.8451
#
# Epoch 00138: val_loss did not improve from 0.11733
# Epoch 139/800
# 31/31 - 4s - loss: 0.1000 - accuracy: 0.9607 - val_loss: 0.3890 - val_accuracy: 0.8531
#
# Epoch 00139: val_loss did not improve from 0.11733
# Epoch 140/800
# 31/31 - 4s - loss: 0.1185 - accuracy: 0.9531 - val_loss: 0.7523 - val_accuracy: 0.7726
#
# Epoch 00140: val_loss did not improve from 0.11733
# Epoch 141/800
# 31/31 - 4s - loss: 0.1046 - accuracy: 0.9551 - val_loss: 1.3229 - val_accuracy: 0.6901
#
# Epoch 00141: val_loss did not improve from 0.11733
# Epoch 142/800
# 31/31 - 4s - loss: 0.1099 - accuracy: 0.9556 - val_loss: 0.1889 - val_accuracy: 0.9235
#
# Epoch 00142: val_loss did not improve from 0.11733
# Epoch 143/800
# 31/31 - 4s - loss: 0.1113 - accuracy: 0.9592 - val_loss: 0.3854 - val_accuracy: 0.8511
#
# Epoch 00143: val_loss did not improve from 0.11733
# Epoch 144/800
# 31/31 - 4s - loss: 0.1095 - accuracy: 0.9546 - val_loss: 0.2385 - val_accuracy: 0.9034
#
# Epoch 00144: val_loss did not improve from 0.11733
# Epoch 145/800
# 31/31 - 4s - loss: 0.0983 - accuracy: 0.9607 - val_loss: 0.1761 - val_accuracy: 0.9336
#
# Epoch 00145: val_loss did not improve from 0.11733
# Epoch 146/800
# 31/31 - 4s - loss: 0.0972 - accuracy: 0.9617 - val_loss: 0.3014 - val_accuracy: 0.8893
#
# Epoch 00146: val_loss did not improve from 0.11733
# Epoch 147/800
# 31/31 - 4s - loss: 0.0755 - accuracy: 0.9773 - val_loss: 0.1384 - val_accuracy: 0.9336
#
# Epoch 00147: val_loss did not improve from 0.11733
# Epoch 148/800
# 31/31 - 4s - loss: 0.0924 - accuracy: 0.9652 - val_loss: 0.4364 - val_accuracy: 0.8511
#
# Epoch 00148: val_loss did not improve from 0.11733
# Epoch 149/800
# 31/31 - 4s - loss: 0.1035 - accuracy: 0.9627 - val_loss: 0.2603 - val_accuracy: 0.9014
#
# Epoch 00149: val_loss did not improve from 0.11733
# Epoch 150/800
# 31/31 - 4s - loss: 0.1089 - accuracy: 0.9556 - val_loss: 0.2006 - val_accuracy: 0.9235
#
# Epoch 00150: val_loss did not improve from 0.11733
# Epoch 151/800
# 31/31 - 4s - loss: 0.1017 - accuracy: 0.9587 - val_loss: 0.4807 - val_accuracy: 0.8531
#
# Epoch 00151: val_loss did not improve from 0.11733
# Epoch 152/800
# 31/31 - 4s - loss: 0.1030 - accuracy: 0.9597 - val_loss: 0.2234 - val_accuracy: 0.9175
#
# Epoch 00152: val_loss did not improve from 0.11733
# Epoch 153/800
# 31/31 - 4s - loss: 0.0948 - accuracy: 0.9688 - val_loss: 0.4410 - val_accuracy: 0.8571
#
# Epoch 00153: val_loss did not improve from 0.11733
# Epoch 154/800
# 31/31 - 4s - loss: 0.0696 - accuracy: 0.9728 - val_loss: 0.1978 - val_accuracy: 0.9115
#
# Epoch 00154: val_loss did not improve from 0.11733
# Epoch 155/800
# 31/31 - 4s - loss: 0.1082 - accuracy: 0.9592 - val_loss: 0.1900 - val_accuracy: 0.9235
#
# Epoch 00155: val_loss did not improve from 0.11733
# Epoch 156/800
# 31/31 - 4s - loss: 0.0961 - accuracy: 0.9627 - val_loss: 0.1455 - val_accuracy: 0.9517
#
# Epoch 00156: val_loss did not improve from 0.11733
# Epoch 157/800
# 31/31 - 4s - loss: 0.0837 - accuracy: 0.9698 - val_loss: 0.2577 - val_accuracy: 0.8954
#
# Epoch 00157: val_loss did not improve from 0.11733
# Epoch 158/800
# 31/31 - 4s - loss: 0.0802 - accuracy: 0.9708 - val_loss: 0.2465 - val_accuracy: 0.9095
#
# Epoch 00158: val_loss did not improve from 0.11733
# Epoch 159/800
# 31/31 - 4s - loss: 0.0969 - accuracy: 0.9617 - val_loss: 0.1388 - val_accuracy: 0.9437
#
# Epoch 00159: val_loss did not improve from 0.11733
# Epoch 160/800
# 31/31 - 4s - loss: 0.0909 - accuracy: 0.9627 - val_loss: 0.1332 - val_accuracy: 0.9457
#
# Epoch 00160: val_loss did not improve from 0.11733
# Epoch 161/800
# 31/31 - 4s - loss: 0.1009 - accuracy: 0.9592 - val_loss: 0.1742 - val_accuracy: 0.9376
#
# Epoch 00161: val_loss did not improve from 0.11733
# Epoch 162/800
# 31/31 - 4s - loss: 0.0786 - accuracy: 0.9662 - val_loss: 0.2255 - val_accuracy: 0.9095
#
# Epoch 00162: val_loss did not improve from 0.11733
# Epoch 163/800
# 31/31 - 4s - loss: 0.0972 - accuracy: 0.9561 - val_loss: 0.1349 - val_accuracy: 0.9437
#
# Epoch 00163: val_loss did not improve from 0.11733
# Epoch 164/800
# 31/31 - 4s - loss: 0.0826 - accuracy: 0.9713 - val_loss: 0.2437 - val_accuracy: 0.8994
#
# Epoch 00164: val_loss did not improve from 0.11733
# Epoch 165/800
# 31/31 - 4s - loss: 0.0946 - accuracy: 0.9637 - val_loss: 0.2974 - val_accuracy: 0.8753
#
# Epoch 00165: val_loss did not improve from 0.11733
# Epoch 166/800
# 31/31 - 4s - loss: 0.0914 - accuracy: 0.9652 - val_loss: 0.4738 - val_accuracy: 0.8310
#
# Epoch 00166: val_loss did not improve from 0.11733
# Epoch 167/800
# 31/31 - 4s - loss: 0.0653 - accuracy: 0.9743 - val_loss: 0.4179 - val_accuracy: 0.8511
#
# Epoch 00167: val_loss did not improve from 0.11733
# Epoch 168/800
# 31/31 - 4s - loss: 0.0856 - accuracy: 0.9677 - val_loss: 0.1920 - val_accuracy: 0.9175
#
# Epoch 00168: val_loss did not improve from 0.11733
# Epoch 169/800
# 31/31 - 4s - loss: 0.0802 - accuracy: 0.9728 - val_loss: 0.4962 - val_accuracy: 0.8189
#
# Epoch 00169: val_loss did not improve from 0.11733
# Epoch 170/800
# 31/31 - 4s - loss: 0.0867 - accuracy: 0.9677 - val_loss: 0.2747 - val_accuracy: 0.8974
#
# Epoch 00170: val_loss did not improve from 0.11733
# Epoch 171/800
# 31/31 - 4s - loss: 0.0816 - accuracy: 0.9667 - val_loss: 0.7814 - val_accuracy: 0.7606
#
# Epoch 00171: val_loss did not improve from 0.11733
# Epoch 172/800
# 31/31 - 4s - loss: 0.0789 - accuracy: 0.9698 - val_loss: 0.5562 - val_accuracy: 0.8169
#
# Epoch 00172: val_loss did not improve from 0.11733
# Epoch 173/800
# 31/31 - 4s - loss: 0.0796 - accuracy: 0.9677 - val_loss: 0.5213 - val_accuracy: 0.8270
#
# Epoch 00173: val_loss did not improve from 0.11733
# Epoch 174/800
# 31/31 - 4s - loss: 0.0774 - accuracy: 0.9718 - val_loss: 0.2011 - val_accuracy: 0.9256
#
# Epoch 00174: val_loss did not improve from 0.11733
# Epoch 175/800
# 31/31 - 4s - loss: 0.0776 - accuracy: 0.9667 - val_loss: 0.1278 - val_accuracy: 0.9477
#
# Epoch 00175: val_loss did not improve from 0.11733
# Epoch 176/800
# 31/31 - 4s - loss: 0.0812 - accuracy: 0.9688 - val_loss: 0.1226 - val_accuracy: 0.9497
#
# Epoch 00176: val_loss did not improve from 0.11733
# Epoch 177/800
# 31/31 - 4s - loss: 0.0705 - accuracy: 0.9728 - val_loss: 0.1241 - val_accuracy: 0.9416
#
# Epoch 00177: val_loss did not improve from 0.11733
# Epoch 178/800
# 31/31 - 4s - loss: 0.0578 - accuracy: 0.9768 - val_loss: 0.2352 - val_accuracy: 0.9215
#
# Epoch 00178: val_loss did not improve from 0.11733
# Epoch 179/800
# 31/31 - 4s - loss: 0.0793 - accuracy: 0.9708 - val_loss: 0.1334 - val_accuracy: 0.9517
#
# Epoch 00179: val_loss did not improve from 0.11733
# Epoch 180/800
# 31/31 - 4s - loss: 0.0679 - accuracy: 0.9738 - val_loss: 0.3491 - val_accuracy: 0.8813
#
# Epoch 00180: val_loss did not improve from 0.11733
# Epoch 181/800
# 31/31 - 4s - loss: 0.0849 - accuracy: 0.9698 - val_loss: 0.4298 - val_accuracy: 0.8551
#
# Epoch 00181: val_loss did not improve from 0.11733
# Epoch 182/800
# 31/31 - 4s - loss: 0.0807 - accuracy: 0.9708 - val_loss: 0.3171 - val_accuracy: 0.8934
#
# Epoch 00182: val_loss did not improve from 0.11733
# Epoch 183/800
# 31/31 - 4s - loss: 0.0763 - accuracy: 0.9713 - val_loss: 0.1616 - val_accuracy: 0.9497
#
# Epoch 00183: val_loss did not improve from 0.11733
# Epoch 184/800
# 31/31 - 4s - loss: 0.0611 - accuracy: 0.9763 - val_loss: 0.2055 - val_accuracy: 0.9235
#
# Epoch 00184: val_loss did not improve from 0.11733
# Epoch 185/800
# 31/31 - 4s - loss: 0.0829 - accuracy: 0.9688 - val_loss: 0.1868 - val_accuracy: 0.9316
#
# Epoch 00185: val_loss did not improve from 0.11733
# Epoch 186/800
# 31/31 - 4s - loss: 0.0620 - accuracy: 0.9783 - val_loss: 0.2919 - val_accuracy: 0.8994
#
# Epoch 00186: val_loss did not improve from 0.11733
# Epoch 187/800
# 31/31 - 4s - loss: 0.0737 - accuracy: 0.9728 - val_loss: 0.1065 - val_accuracy: 0.9537
#
# Epoch 00187: val_loss improved from 0.11733 to 0.10654, saving model to model.h5
# Epoch 188/800
# 31/31 - 4s - loss: 0.0876 - accuracy: 0.9693 - val_loss: 1.7465 - val_accuracy: 0.6720
#
# Epoch 00188: val_loss did not improve from 0.10654
# Epoch 189/800
# 31/31 - 4s - loss: 0.0558 - accuracy: 0.9768 - val_loss: 0.1424 - val_accuracy: 0.9457
#
# Epoch 00189: val_loss did not improve from 0.10654
# Epoch 190/800
# 31/31 - 4s - loss: 0.0842 - accuracy: 0.9672 - val_loss: 0.2046 - val_accuracy: 0.9256
#
# Epoch 00190: val_loss did not improve from 0.10654
# Epoch 191/800
# 31/31 - 4s - loss: 0.0574 - accuracy: 0.9808 - val_loss: 0.1958 - val_accuracy: 0.9296
#
# Epoch 00191: val_loss did not improve from 0.10654
# Epoch 192/800
# 31/31 - 4s - loss: 0.0944 - accuracy: 0.9652 - val_loss: 0.2199 - val_accuracy: 0.9195
#
# Epoch 00192: val_loss did not improve from 0.10654
# Epoch 193/800
# 31/31 - 4s - loss: 0.0743 - accuracy: 0.9708 - val_loss: 1.1930 - val_accuracy: 0.7082
#
# Epoch 00193: val_loss did not improve from 0.10654
# Epoch 194/800
# 31/31 - 4s - loss: 0.0763 - accuracy: 0.9733 - val_loss: 0.6915 - val_accuracy: 0.7787
#
# Epoch 00194: val_loss did not improve from 0.10654
# Epoch 195/800
# 31/31 - 4s - loss: 0.0724 - accuracy: 0.9718 - val_loss: 0.1865 - val_accuracy: 0.9256
#
# Epoch 00195: val_loss did not improve from 0.10654
# Epoch 196/800
# 31/31 - 4s - loss: 0.0695 - accuracy: 0.9723 - val_loss: 0.1749 - val_accuracy: 0.9316
#
# Epoch 00196: val_loss did not improve from 0.10654
# Epoch 197/800
# 31/31 - 4s - loss: 0.0738 - accuracy: 0.9698 - val_loss: 0.1017 - val_accuracy: 0.9537
#
# Epoch 00197: val_loss improved from 0.10654 to 0.10170, saving model to model.h5
# Epoch 198/800
# 31/31 - 4s - loss: 0.0736 - accuracy: 0.9693 - val_loss: 0.7145 - val_accuracy: 0.7726
#
# Epoch 00198: val_loss did not improve from 0.10170
# Epoch 199/800
# 31/31 - 4s - loss: 0.0657 - accuracy: 0.9748 - val_loss: 0.2540 - val_accuracy: 0.9014
#
# Epoch 00199: val_loss did not improve from 0.10170
# Epoch 200/800
# 31/31 - 4s - loss: 0.0670 - accuracy: 0.9778 - val_loss: 0.1121 - val_accuracy: 0.9497
#
# Epoch 00200: val_loss did not improve from 0.10170
# Epoch 201/800
# 31/31 - 4s - loss: 0.0661 - accuracy: 0.9728 - val_loss: 0.1292 - val_accuracy: 0.9497
#
# Epoch 00201: val_loss did not improve from 0.10170
# Epoch 202/800
# 31/31 - 4s - loss: 0.0699 - accuracy: 0.9718 - val_loss: 0.1392 - val_accuracy: 0.9497
#
# Epoch 00202: val_loss did not improve from 0.10170
# Epoch 203/800
# 31/31 - 4s - loss: 0.0754 - accuracy: 0.9693 - val_loss: 0.0946 - val_accuracy: 0.9638
#
# Epoch 00203: val_loss improved from 0.10170 to 0.09460, saving model to model.h5
# Epoch 204/800
# 31/31 - 4s - loss: 0.0645 - accuracy: 0.9793 - val_loss: 0.0941 - val_accuracy: 0.9658
#
# Epoch 00204: val_loss improved from 0.09460 to 0.09411, saving model to model.h5
# Epoch 205/800
# 31/31 - 4s - loss: 0.0659 - accuracy: 0.9788 - val_loss: 0.2428 - val_accuracy: 0.9135
#
# Epoch 00205: val_loss did not improve from 0.09411
# Epoch 206/800
# 31/31 - 4s - loss: 0.0583 - accuracy: 0.9783 - val_loss: 0.5125 - val_accuracy: 0.8310
#
# Epoch 00206: val_loss did not improve from 0.09411
# Epoch 207/800
# 31/31 - 4s - loss: 0.0636 - accuracy: 0.9758 - val_loss: 0.3660 - val_accuracy: 0.8753
#
# Epoch 00207: val_loss did not improve from 0.09411
# Epoch 208/800
# 31/31 - 4s - loss: 0.0680 - accuracy: 0.9738 - val_loss: 0.3999 - val_accuracy: 0.8571
#
# Epoch 00208: val_loss did not improve from 0.09411
# Epoch 209/800
# 31/31 - 4s - loss: 0.0600 - accuracy: 0.9743 - val_loss: 0.6965 - val_accuracy: 0.8169
#
# Epoch 00209: val_loss did not improve from 0.09411
# Epoch 210/800
# 31/31 - 4s - loss: 0.0665 - accuracy: 0.9738 - val_loss: 0.3506 - val_accuracy: 0.8753
#
# Epoch 00210: val_loss did not improve from 0.09411
# Epoch 211/800
# 31/31 - 4s - loss: 0.0559 - accuracy: 0.9793 - val_loss: 0.1169 - val_accuracy: 0.9537
#
# Epoch 00211: val_loss did not improve from 0.09411
# Epoch 212/800
# 31/31 - 4s - loss: 0.0756 - accuracy: 0.9758 - val_loss: 0.1116 - val_accuracy: 0.9598
#
# Epoch 00212: val_loss did not improve from 0.09411
# Epoch 213/800
# 31/31 - 4s - loss: 0.0615 - accuracy: 0.9723 - val_loss: 0.2546 - val_accuracy: 0.9155
#
# Epoch 00213: val_loss did not improve from 0.09411
# Epoch 214/800
# 31/31 - 4s - loss: 0.0521 - accuracy: 0.9819 - val_loss: 0.2916 - val_accuracy: 0.9014
#
# Epoch 00214: val_loss did not improve from 0.09411
# Epoch 215/800
# 31/31 - 4s - loss: 0.0736 - accuracy: 0.9738 - val_loss: 0.2557 - val_accuracy: 0.9155
#
# Epoch 00215: val_loss did not improve from 0.09411
# Epoch 216/800
# 31/31 - 4s - loss: 0.0761 - accuracy: 0.9713 - val_loss: 0.3204 - val_accuracy: 0.8753
#
# Epoch 00216: val_loss did not improve from 0.09411
# Epoch 217/800
# 31/31 - 4s - loss: 0.0543 - accuracy: 0.9834 - val_loss: 0.7389 - val_accuracy: 0.7968
#
# Epoch 00217: val_loss did not improve from 0.09411
# Epoch 218/800
# 31/31 - 4s - loss: 0.0576 - accuracy: 0.9803 - val_loss: 0.1027 - val_accuracy: 0.9638
#
# Epoch 00218: val_loss did not improve from 0.09411
# Epoch 219/800
# 31/31 - 4s - loss: 0.0449 - accuracy: 0.9819 - val_loss: 0.2371 - val_accuracy: 0.9195
#
# Epoch 00219: val_loss did not improve from 0.09411
# Epoch 220/800
# 31/31 - 4s - loss: 0.0547 - accuracy: 0.9788 - val_loss: 0.3031 - val_accuracy: 0.9115
#
# Epoch 00220: val_loss did not improve from 0.09411
# Epoch 221/800
# 31/31 - 4s - loss: 0.0528 - accuracy: 0.9793 - val_loss: 0.1025 - val_accuracy: 0.9618
#
# Epoch 00221: val_loss did not improve from 0.09411
# Epoch 222/800
# 31/31 - 4s - loss: 0.0672 - accuracy: 0.9738 - val_loss: 0.1186 - val_accuracy: 0.9517
#
# Epoch 00222: val_loss did not improve from 0.09411
# Epoch 223/800
# 31/31 - 4s - loss: 0.0456 - accuracy: 0.9854 - val_loss: 0.1931 - val_accuracy: 0.9336
#
# Epoch 00223: val_loss did not improve from 0.09411
# Epoch 224/800
# 31/31 - 4s - loss: 0.0533 - accuracy: 0.9798 - val_loss: 0.1713 - val_accuracy: 0.9356
#
# Epoch 00224: val_loss did not improve from 0.09411
# Epoch 225/800
# 31/31 - 4s - loss: 0.0679 - accuracy: 0.9738 - val_loss: 0.1916 - val_accuracy: 0.9356
#
# Epoch 00225: val_loss did not improve from 0.09411
# Epoch 226/800
# 31/31 - 4s - loss: 0.0589 - accuracy: 0.9768 - val_loss: 0.3422 - val_accuracy: 0.8853
#
# Epoch 00226: val_loss did not improve from 0.09411
# Epoch 227/800
# 31/31 - 4s - loss: 0.0610 - accuracy: 0.9718 - val_loss: 0.8272 - val_accuracy: 0.7847
#
# Epoch 00227: val_loss did not improve from 0.09411
# Epoch 228/800
# 31/31 - 4s - loss: 0.0620 - accuracy: 0.9758 - val_loss: 1.3393 - val_accuracy: 0.7022
#
# Epoch 00228: val_loss did not improve from 0.09411
# Epoch 229/800
# 31/31 - 4s - loss: 0.0674 - accuracy: 0.9778 - val_loss: 0.4336 - val_accuracy: 0.8612
#
# Epoch 00229: val_loss did not improve from 0.09411
# Epoch 230/800
# 31/31 - 4s - loss: 0.0447 - accuracy: 0.9834 - val_loss: 0.2613 - val_accuracy: 0.9135
#
# Epoch 00230: val_loss did not improve from 0.09411
# Epoch 231/800
# 31/31 - 4s - loss: 0.0588 - accuracy: 0.9773 - val_loss: 1.1767 - val_accuracy: 0.7525
#
# Epoch 00231: val_loss did not improve from 0.09411
# Epoch 232/800
# 31/31 - 4s - loss: 0.0537 - accuracy: 0.9783 - val_loss: 0.3071 - val_accuracy: 0.8913
#
# Epoch 00232: val_loss did not improve from 0.09411
# Epoch 233/800
# 31/31 - 4s - loss: 0.0528 - accuracy: 0.9793 - val_loss: 0.2576 - val_accuracy: 0.9115
#
# Epoch 00233: val_loss did not improve from 0.09411
# Epoch 234/800
# 31/31 - 4s - loss: 0.0568 - accuracy: 0.9814 - val_loss: 0.2357 - val_accuracy: 0.9195
#
# Epoch 00234: val_loss did not improve from 0.09411
# Epoch 235/800
# 31/31 - 4s - loss: 0.0499 - accuracy: 0.9778 - val_loss: 0.4150 - val_accuracy: 0.8652
#
# Epoch 00235: val_loss did not improve from 0.09411
# Epoch 236/800
# 31/31 - 4s - loss: 0.0602 - accuracy: 0.9793 - val_loss: 1.5804 - val_accuracy: 0.7002
#
# Epoch 00236: val_loss did not improve from 0.09411
# Epoch 237/800
# 31/31 - 4s - loss: 0.0605 - accuracy: 0.9788 - val_loss: 1.9813 - val_accuracy: 0.6680
#
# Epoch 00237: val_loss did not improve from 0.09411
# Epoch 238/800
# 31/31 - 4s - loss: 0.0663 - accuracy: 0.9763 - val_loss: 0.1030 - val_accuracy: 0.9658
#
# Epoch 00238: val_loss did not improve from 0.09411
# Epoch 239/800
# 31/31 - 4s - loss: 0.0597 - accuracy: 0.9758 - val_loss: 0.3579 - val_accuracy: 0.8652
#
# Epoch 00239: val_loss did not improve from 0.09411
# Epoch 240/800
# 31/31 - 4s - loss: 0.0526 - accuracy: 0.9788 - val_loss: 0.6013 - val_accuracy: 0.8149
#
# Epoch 00240: val_loss did not improve from 0.09411
# Epoch 241/800
# 31/31 - 4s - loss: 0.0504 - accuracy: 0.9834 - val_loss: 0.2490 - val_accuracy: 0.9034
#
# Epoch 00241: val_loss did not improve from 0.09411
# Epoch 242/800
# 31/31 - 4s - loss: 0.0450 - accuracy: 0.9839 - val_loss: 0.0995 - val_accuracy: 0.9598
#
# Epoch 00242: val_loss did not improve from 0.09411
# Epoch 243/800
# 31/31 - 4s - loss: 0.0447 - accuracy: 0.9834 - val_loss: 0.1036 - val_accuracy: 0.9658
#
# Epoch 00243: val_loss did not improve from 0.09411
# Epoch 244/800
# 31/31 - 4s - loss: 0.0460 - accuracy: 0.9814 - val_loss: 0.1746 - val_accuracy: 0.9336
#
# Epoch 00244: val_loss did not improve from 0.09411
# Epoch 245/800
# 31/31 - 4s - loss: 0.0559 - accuracy: 0.9849 - val_loss: 0.1292 - val_accuracy: 0.9437
#
# Epoch 00245: val_loss did not improve from 0.09411
# Epoch 246/800
# 31/31 - 4s - loss: 0.0740 - accuracy: 0.9713 - val_loss: 1.7885 - val_accuracy: 0.7002
#
# Epoch 00246: val_loss did not improve from 0.09411
# Epoch 247/800
# 31/31 - 4s - loss: 0.0435 - accuracy: 0.9839 - val_loss: 1.8039 - val_accuracy: 0.6861
#
# Epoch 00247: val_loss did not improve from 0.09411
# Epoch 248/800
# 31/31 - 4s - loss: 0.0490 - accuracy: 0.9824 - val_loss: 1.2258 - val_accuracy: 0.7203
#
# Epoch 00248: val_loss did not improve from 0.09411
# Epoch 249/800
# 31/31 - 4s - loss: 0.0507 - accuracy: 0.9824 - val_loss: 0.1009 - val_accuracy: 0.9557
#
# Epoch 00249: val_loss did not improve from 0.09411
# Epoch 250/800
# 31/31 - 4s - loss: 0.0415 - accuracy: 0.9849 - val_loss: 0.1158 - val_accuracy: 0.9477
#
# Epoch 00250: val_loss did not improve from 0.09411
# Epoch 251/800
# 31/31 - 4s - loss: 0.0492 - accuracy: 0.9844 - val_loss: 0.0812 - val_accuracy: 0.9759
#
# Epoch 00251: val_loss improved from 0.09411 to 0.08120, saving model to model.h5
# Epoch 252/800
# 31/31 - 4s - loss: 0.0530 - accuracy: 0.9814 - val_loss: 0.1587 - val_accuracy: 0.9356
#
# Epoch 00252: val_loss did not improve from 0.08120
# Epoch 253/800
# 31/31 - 4s - loss: 0.0435 - accuracy: 0.9849 - val_loss: 0.2066 - val_accuracy: 0.9336
#
# Epoch 00253: val_loss did not improve from 0.08120
# Epoch 254/800
# 31/31 - 4s - loss: 0.0561 - accuracy: 0.9803 - val_loss: 0.1476 - val_accuracy: 0.9416
#
# Epoch 00254: val_loss did not improve from 0.08120
# Epoch 255/800
# 31/31 - 4s - loss: 0.0485 - accuracy: 0.9814 - val_loss: 0.1003 - val_accuracy: 0.9638
#
# Epoch 00255: val_loss did not improve from 0.08120
# Epoch 256/800
# 31/31 - 4s - loss: 0.0449 - accuracy: 0.9829 - val_loss: 0.0890 - val_accuracy: 0.9618
#
# Epoch 00256: val_loss did not improve from 0.08120
# Epoch 257/800
# 31/31 - 4s - loss: 0.0442 - accuracy: 0.9839 - val_loss: 0.0787 - val_accuracy: 0.9779
#
# Epoch 00257: val_loss improved from 0.08120 to 0.07867, saving model to model.h5
# Epoch 258/800
# 31/31 - 4s - loss: 0.0440 - accuracy: 0.9824 - val_loss: 0.1832 - val_accuracy: 0.9356
#
# Epoch 00258: val_loss did not improve from 0.07867
# Epoch 259/800
# 31/31 - 4s - loss: 0.0451 - accuracy: 0.9834 - val_loss: 0.3340 - val_accuracy: 0.8813
#
# Epoch 00259: val_loss did not improve from 0.07867
# Epoch 260/800
# 31/31 - 4s - loss: 0.0604 - accuracy: 0.9753 - val_loss: 0.2307 - val_accuracy: 0.9235
#
# Epoch 00260: val_loss did not improve from 0.07867
# Epoch 261/800
# 31/31 - 4s - loss: 0.0494 - accuracy: 0.9839 - val_loss: 0.2114 - val_accuracy: 0.9396
#
# Epoch 00261: val_loss did not improve from 0.07867
# Epoch 262/800
# 31/31 - 4s - loss: 0.0514 - accuracy: 0.9788 - val_loss: 0.4065 - val_accuracy: 0.8773
#
# Epoch 00262: val_loss did not improve from 0.07867
# Epoch 263/800
# 31/31 - 4s - loss: 0.0483 - accuracy: 0.9839 - val_loss: 0.3006 - val_accuracy: 0.9195
#
# Epoch 00263: val_loss did not improve from 0.07867
# Epoch 264/800
# 31/31 - 4s - loss: 0.0472 - accuracy: 0.9808 - val_loss: 0.1575 - val_accuracy: 0.9437
#
# Epoch 00264: val_loss did not improve from 0.07867
# Epoch 265/800
# 31/31 - 4s - loss: 0.0474 - accuracy: 0.9829 - val_loss: 0.1142 - val_accuracy: 0.9577
#
# Epoch 00265: val_loss did not improve from 0.07867
# Epoch 266/800
# 31/31 - 4s - loss: 0.0531 - accuracy: 0.9788 - val_loss: 0.1085 - val_accuracy: 0.9557
#
# Epoch 00266: val_loss did not improve from 0.07867
# Epoch 267/800
# 31/31 - 4s - loss: 0.0564 - accuracy: 0.9768 - val_loss: 0.3574 - val_accuracy: 0.8813
#
# Epoch 00267: val_loss did not improve from 0.07867
# Epoch 268/800
# 31/31 - 4s - loss: 0.0416 - accuracy: 0.9834 - val_loss: 0.2831 - val_accuracy: 0.9014
#
# Epoch 00268: val_loss did not improve from 0.07867
# Epoch 269/800
# 31/31 - 4s - loss: 0.0369 - accuracy: 0.9864 - val_loss: 0.0714 - val_accuracy: 0.9738
#
# Epoch 00269: val_loss improved from 0.07867 to 0.07138, saving model to model.h5
# Epoch 270/800
# 31/31 - 4s - loss: 0.0482 - accuracy: 0.9819 - val_loss: 0.0907 - val_accuracy: 0.9678
#
# Epoch 00270: val_loss did not improve from 0.07138
# Epoch 271/800
# 31/31 - 4s - loss: 0.0371 - accuracy: 0.9874 - val_loss: 0.1889 - val_accuracy: 0.9396
#
# Epoch 00271: val_loss did not improve from 0.07138
# Epoch 272/800
# 31/31 - 4s - loss: 0.0454 - accuracy: 0.9814 - val_loss: 0.1607 - val_accuracy: 0.9477
#
# Epoch 00272: val_loss did not improve from 0.07138
# Epoch 273/800
# 31/31 - 4s - loss: 0.0464 - accuracy: 0.9839 - val_loss: 0.3778 - val_accuracy: 0.8551
#
# Epoch 00273: val_loss did not improve from 0.07138
# Epoch 274/800
# 31/31 - 4s - loss: 0.0403 - accuracy: 0.9879 - val_loss: 1.7053 - val_accuracy: 0.6761
#
# Epoch 00274: val_loss did not improve from 0.07138
# Epoch 275/800
# 31/31 - 4s - loss: 0.0356 - accuracy: 0.9879 - val_loss: 0.2071 - val_accuracy: 0.9175
#
# Epoch 00275: val_loss did not improve from 0.07138
# Epoch 276/800
# 31/31 - 4s - loss: 0.0472 - accuracy: 0.9829 - val_loss: 0.2527 - val_accuracy: 0.9115
#
# Epoch 00276: val_loss did not improve from 0.07138
# Epoch 277/800
# 31/31 - 4s - loss: 0.0543 - accuracy: 0.9819 - val_loss: 0.1397 - val_accuracy: 0.9497
#
# Epoch 00277: val_loss did not improve from 0.07138
# Epoch 278/800
# 31/31 - 4s - loss: 0.0384 - accuracy: 0.9879 - val_loss: 0.7618 - val_accuracy: 0.7807
#
# Epoch 00278: val_loss did not improve from 0.07138
# Epoch 279/800
# 31/31 - 4s - loss: 0.0350 - accuracy: 0.9874 - val_loss: 1.7181 - val_accuracy: 0.6881
#
# Epoch 00279: val_loss did not improve from 0.07138
# Epoch 280/800
# 31/31 - 4s - loss: 0.0369 - accuracy: 0.9869 - val_loss: 0.0846 - val_accuracy: 0.9678
#
# Epoch 00280: val_loss did not improve from 0.07138
# Epoch 281/800
# 31/31 - 4s - loss: 0.0375 - accuracy: 0.9834 - val_loss: 0.1782 - val_accuracy: 0.9376
#
# Epoch 00281: val_loss did not improve from 0.07138
# Epoch 282/800
# 31/31 - 4s - loss: 0.0599 - accuracy: 0.9803 - val_loss: 0.5725 - val_accuracy: 0.8310
#
# Epoch 00282: val_loss did not improve from 0.07138
# Epoch 283/800
# 31/31 - 4s - loss: 0.0426 - accuracy: 0.9869 - val_loss: 1.0169 - val_accuracy: 0.7565
#
# Epoch 00283: val_loss did not improve from 0.07138
# Epoch 284/800
# 31/31 - 4s - loss: 0.0422 - accuracy: 0.9829 - val_loss: 0.0792 - val_accuracy: 0.9738
#
# Epoch 00284: val_loss did not improve from 0.07138
# Epoch 285/800
# 31/31 - 4s - loss: 0.0398 - accuracy: 0.9849 - val_loss: 0.1657 - val_accuracy: 0.9457
#
# Epoch 00285: val_loss did not improve from 0.07138
# Epoch 286/800
# 31/31 - 4s - loss: 0.0388 - accuracy: 0.9844 - val_loss: 0.3304 - val_accuracy: 0.8793
#
# Epoch 00286: val_loss did not improve from 0.07138
# Epoch 287/800
# 31/31 - 4s - loss: 0.0371 - accuracy: 0.9869 - val_loss: 0.2431 - val_accuracy: 0.9276
#
# Epoch 00287: val_loss did not improve from 0.07138
# Epoch 288/800
# 31/31 - 4s - loss: 0.0455 - accuracy: 0.9839 - val_loss: 0.2705 - val_accuracy: 0.9276
#
# Epoch 00288: val_loss did not improve from 0.07138
# Epoch 289/800
# 31/31 - 4s - loss: 0.0533 - accuracy: 0.9834 - val_loss: 0.0845 - val_accuracy: 0.9718
#
# Epoch 00289: val_loss did not improve from 0.07138
# Epoch 290/800
# 31/31 - 4s - loss: 0.0453 - accuracy: 0.9824 - val_loss: 0.1197 - val_accuracy: 0.9577
#
# Epoch 00290: val_loss did not improve from 0.07138
# Epoch 291/800
# 31/31 - 4s - loss: 0.0328 - accuracy: 0.9884 - val_loss: 0.1187 - val_accuracy: 0.9577
#
# Epoch 00291: val_loss did not improve from 0.07138
# Epoch 292/800
# 31/31 - 4s - loss: 0.0379 - accuracy: 0.9884 - val_loss: 0.0898 - val_accuracy: 0.9698
#
# Epoch 00292: val_loss did not improve from 0.07138
# Epoch 293/800
# ...
#
# Epoch 00696: val_loss did not improve from 0.02677
# Epoch 697/800
# 31/31 - 4s - loss: 0.0151 - accuracy: 0.9934 - val_loss: 0.0959 - val_accuracy: 0.9779
#
# Epoch 00697: val_loss did not improve from 0.02677
# Epoch 698/800
# 31/31 - 4s - loss: 0.0082 - accuracy: 0.9960 - val_loss: 0.2129 - val_accuracy: 0.9457
#
# Epoch 00698: val_loss did not improve from 0.02677
# Epoch 699/800
# 31/31 - 4s - loss: 0.0156 - accuracy: 0.9934 - val_loss: 0.4689 - val_accuracy: 0.8793
#
# Epoch 00699: val_loss did not improve from 0.02677
# Epoch 700/800
# 31/31 - 4s - loss: 0.0194 - accuracy: 0.9940 - val_loss: 0.1659 - val_accuracy: 0.9537
#
# Epoch 00700: val_loss did not improve from 0.02677
# Epoch 701/800
# 31/31 - 4s - loss: 0.0123 - accuracy: 0.9960 - val_loss: 0.1480 - val_accuracy: 0.9557
#
# Epoch 00701: val_loss did not improve from 0.02677
# Epoch 702/800
# 31/31 - 4s - loss: 0.0163 - accuracy: 0.9950 - val_loss: 0.1601 - val_accuracy: 0.9557
#
# Epoch 00702: val_loss did not improve from 0.02677
# Epoch 703/800
# 31/31 - 4s - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.1993 - val_accuracy: 0.9416
#
# Epoch 00703: val_loss did not improve from 0.02677
# Epoch 704/800
# 31/31 - 4s - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.4436 - val_accuracy: 0.8893
#
# Epoch 00704: val_loss did not improve from 0.02677
# Epoch 705/800
# 31/31 - 4s - loss: 0.0056 - accuracy: 0.9985 - val_loss: 0.4283 - val_accuracy: 0.8793
#
# Epoch 00705: val_loss did not improve from 0.02677
# Epoch 706/800
# 31/31 - 4s - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.2402 - val_accuracy: 0.9376
#
# Epoch 00706: val_loss did not improve from 0.02677
# Epoch 707/800
# 31/31 - 4s - loss: 0.0067 - accuracy: 0.9985 - val_loss: 0.4138 - val_accuracy: 0.8853
#
# Epoch 00707: val_loss did not improve from 0.02677
# Epoch 708/800
# 31/31 - 4s - loss: 0.0102 - accuracy: 0.9975 - val_loss: 0.6893 - val_accuracy: 0.8330
#
# Epoch 00708: val_loss did not improve from 0.02677
# Epoch 709/800
# 31/31 - 4s - loss: 0.0154 - accuracy: 0.9950 - val_loss: 0.0672 - val_accuracy: 0.9759
#
# Epoch 00709: val_loss did not improve from 0.02677
# Epoch 710/800
# 31/31 - 4s - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.0234 - val_accuracy: 0.9920
#
# Epoch 00710: val_loss improved from 0.02677 to 0.02344, saving model to model.h5
# Epoch 711/800
# 31/31 - 4s - loss: 0.0122 - accuracy: 0.9960 - val_loss: 0.1043 - val_accuracy: 0.9738
#
# Epoch 00711: val_loss did not improve from 0.02344
# Epoch 712/800
# 31/31 - 4s - loss: 0.0109 - accuracy: 0.9965 - val_loss: 0.1145 - val_accuracy: 0.9618
#
# Epoch 00712: val_loss did not improve from 0.02344
# Epoch 713/800
# 31/31 - 4s - loss: 0.0078 - accuracy: 0.9965 - val_loss: 2.1145 - val_accuracy: 0.7103
#
# Epoch 00713: val_loss did not improve from 0.02344
# Epoch 714/800
# 31/31 - 4s - loss: 0.0141 - accuracy: 0.9950 - val_loss: 0.2019 - val_accuracy: 0.9618
#
# Epoch 00714: val_loss did not improve from 0.02344
# Epoch 715/800
# 31/31 - 4s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.3160 - val_accuracy: 0.9296
#
# Epoch 00715: val_loss did not improve from 0.02344
# Epoch 716/800
# 31/31 - 4s - loss: 0.0126 - accuracy: 0.9945 - val_loss: 0.2617 - val_accuracy: 0.9316
#
# Epoch 00716: val_loss did not improve from 0.02344
# Epoch 717/800
# 31/31 - 4s - loss: 0.0132 - accuracy: 0.9940 - val_loss: 0.0952 - val_accuracy: 0.9698
#
# Epoch 00717: val_loss did not improve from 0.02344
# Epoch 718/800
# 31/31 - 4s - loss: 0.0158 - accuracy: 0.9955 - val_loss: 0.1668 - val_accuracy: 0.9537
#
# Epoch 00718: val_loss did not improve from 0.02344
# Epoch 719/800
# 31/31 - 4s - loss: 0.0106 - accuracy: 0.9980 - val_loss: 0.4641 - val_accuracy: 0.8934
#
# Epoch 00719: val_loss did not improve from 0.02344
# Epoch 720/800
# 31/31 - 4s - loss: 0.0080 - accuracy: 0.9970 - val_loss: 0.1609 - val_accuracy: 0.9537
#
# Epoch 00720: val_loss did not improve from 0.02344
# Epoch 721/800
# 31/31 - 4s - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.1363 - val_accuracy: 0.9678
#
# Epoch 00721: val_loss did not improve from 0.02344
# Epoch 722/800
# 31/31 - 4s - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.3882 - val_accuracy: 0.8954
#
# Epoch 00722: val_loss did not improve from 0.02344
# Epoch 723/800
# 31/31 - 4s - loss: 0.0080 - accuracy: 0.9970 - val_loss: 0.4337 - val_accuracy: 0.8873
#
# Epoch 00723: val_loss did not improve from 0.02344
# Epoch 724/800
# 31/31 - 4s - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.4336 - val_accuracy: 0.8994
#
# Epoch 00724: val_loss did not improve from 0.02344
# Epoch 725/800
# 31/31 - 4s - loss: 0.0055 - accuracy: 0.9965 - val_loss: 1.2627 - val_accuracy: 0.7666
#
# Epoch 00725: val_loss did not improve from 0.02344
# Epoch 726/800
# 31/31 - 4s - loss: 0.0138 - accuracy: 0.9934 - val_loss: 0.0693 - val_accuracy: 0.9819
#
# Epoch 00726: val_loss did not improve from 0.02344
# Epoch 727/800
# 31/31 - 4s - loss: 0.0119 - accuracy: 0.9955 - val_loss: 0.1032 - val_accuracy: 0.9738
#
# Epoch 00727: val_loss did not improve from 0.02344
# Epoch 728/800
# 31/31 - 4s - loss: 0.0103 - accuracy: 0.9975 - val_loss: 0.3338 - val_accuracy: 0.9215
#
# Epoch 00728: val_loss did not improve from 0.02344
# Epoch 729/800
# 31/31 - 4s - loss: 0.0082 - accuracy: 0.9965 - val_loss: 0.1476 - val_accuracy: 0.9557
#
# Epoch 00729: val_loss did not improve from 0.02344
# Epoch 730/800
# 31/31 - 4s - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.0742 - val_accuracy: 0.9799
#
# Epoch 00730: val_loss did not improve from 0.02344
# Epoch 731/800
# 31/31 - 4s - loss: 0.0094 - accuracy: 0.9975 - val_loss: 0.1374 - val_accuracy: 0.9678
#
# Epoch 00731: val_loss did not improve from 0.02344
# Epoch 732/800
# 31/31 - 4s - loss: 0.0075 - accuracy: 0.9975 - val_loss: 0.2004 - val_accuracy: 0.9537
#
# Epoch 00732: val_loss did not improve from 0.02344
# Epoch 733/800
# 31/31 - 4s - loss: 0.0130 - accuracy: 0.9975 - val_loss: 0.1595 - val_accuracy: 0.9638
#
# Epoch 00733: val_loss did not improve from 0.02344
# Epoch 734/800
# 31/31 - 4s - loss: 0.0110 - accuracy: 0.9960 - val_loss: 0.1837 - val_accuracy: 0.9537
#
# Epoch 00734: val_loss did not improve from 0.02344
# Epoch 735/800
# 31/31 - 4s - loss: 0.0123 - accuracy: 0.9965 - val_loss: 0.4067 - val_accuracy: 0.8913
#
# Epoch 00735: val_loss did not improve from 0.02344
# Epoch 736/800
# 31/31 - 4s - loss: 0.0189 - accuracy: 0.9960 - val_loss: 0.1010 - val_accuracy: 0.9698
#
# Epoch 00736: val_loss did not improve from 0.02344
# Epoch 737/800
# 31/31 - 4s - loss: 0.0102 - accuracy: 0.9960 - val_loss: 0.1387 - val_accuracy: 0.9577
#
# Epoch 00737: val_loss did not improve from 0.02344
# Epoch 738/800
# 31/31 - 4s - loss: 0.0060 - accuracy: 0.9975 - val_loss: 0.0827 - val_accuracy: 0.9738
#
# Epoch 00738: val_loss did not improve from 0.02344
# Epoch 739/800
# 31/31 - 4s - loss: 0.0086 - accuracy: 0.9965 - val_loss: 0.0742 - val_accuracy: 0.9839
#
# Epoch 00739: val_loss did not improve from 0.02344
# Epoch 740/800
# 31/31 - 4s - loss: 0.0118 - accuracy: 0.9975 - val_loss: 0.1796 - val_accuracy: 0.9477
#
# Epoch 00740: val_loss did not improve from 0.02344
# Epoch 741/800
# 31/31 - 4s - loss: 0.0128 - accuracy: 0.9955 - val_loss: 0.0932 - val_accuracy: 0.9698
#
# Epoch 00741: val_loss did not improve from 0.02344
# Epoch 742/800
# 31/31 - 4s - loss: 0.0152 - accuracy: 0.9965 - val_loss: 0.2879 - val_accuracy: 0.9316
#
# Epoch 00742: val_loss did not improve from 0.02344
# Epoch 743/800
# 31/31 - 4s - loss: 0.0117 - accuracy: 0.9955 - val_loss: 0.0406 - val_accuracy: 0.9899
#
# Epoch 00743: val_loss did not improve from 0.02344
# Epoch 744/800
# 31/31 - 4s - loss: 0.0122 - accuracy: 0.9945 - val_loss: 0.1257 - val_accuracy: 0.9658
#
# Epoch 00744: val_loss did not improve from 0.02344
# Epoch 745/800
# 31/31 - 4s - loss: 0.0088 - accuracy: 0.9970 - val_loss: 0.2588 - val_accuracy: 0.9276
#
# Epoch 00745: val_loss did not improve from 0.02344
# Epoch 746/800
# 31/31 - 4s - loss: 0.0062 - accuracy: 0.9970 - val_loss: 0.7061 - val_accuracy: 0.8571
#
# Epoch 00746: val_loss did not improve from 0.02344
# Epoch 747/800
# 31/31 - 4s - loss: 0.0039 - accuracy: 0.9985 - val_loss: 0.1768 - val_accuracy: 0.9396
#
# Epoch 00747: val_loss did not improve from 0.02344
# Epoch 748/800
# 31/31 - 4s - loss: 0.0112 - accuracy: 0.9965 - val_loss: 0.0387 - val_accuracy: 0.9879
#
# Epoch 00748: val_loss did not improve from 0.02344
# Epoch 749/800
# 31/31 - 4s - loss: 0.0099 - accuracy: 0.9955 - val_loss: 0.0466 - val_accuracy: 0.9859
#
# Epoch 00749: val_loss did not improve from 0.02344
# Epoch 750/800
# 31/31 - 4s - loss: 0.0117 - accuracy: 0.9965 - val_loss: 0.4724 - val_accuracy: 0.8913
#
# Epoch 00750: val_loss did not improve from 0.02344
# Epoch 751/800
# 31/31 - 4s - loss: 0.0155 - accuracy: 0.9929 - val_loss: 1.8400 - val_accuracy: 0.7163
#
# Epoch 00751: val_loss did not improve from 0.02344
# Epoch 752/800
# 31/31 - 4s - loss: 0.0173 - accuracy: 0.9970 - val_loss: 0.3306 - val_accuracy: 0.9356
#
# Epoch 00752: val_loss did not improve from 0.02344
# Epoch 753/800
# 31/31 - 4s - loss: 0.0086 - accuracy: 0.9965 - val_loss: 0.0898 - val_accuracy: 0.9638
#
# Epoch 00753: val_loss did not improve from 0.02344
# Epoch 754/800
# 31/31 - 4s - loss: 0.0053 - accuracy: 0.9990 - val_loss: 0.1636 - val_accuracy: 0.9497
#
# Epoch 00754: val_loss did not improve from 0.02344
# Epoch 755/800
# 31/31 - 4s - loss: 0.0083 - accuracy: 0.9965 - val_loss: 0.9714 - val_accuracy: 0.7968
#
# Epoch 00755: val_loss did not improve from 0.02344
# Epoch 756/800
# 31/31 - 4s - loss: 0.0081 - accuracy: 0.9965 - val_loss: 0.3759 - val_accuracy: 0.9034
#
# Epoch 00756: val_loss did not improve from 0.02344
# Epoch 757/800
# 31/31 - 4s - loss: 0.0135 - accuracy: 0.9970 - val_loss: 0.4051 - val_accuracy: 0.8974
#
# Epoch 00757: val_loss did not improve from 0.02344
# Epoch 758/800
# 31/31 - 4s - loss: 0.0120 - accuracy: 0.9950 - val_loss: 0.2299 - val_accuracy: 0.9497
#
# Epoch 00758: val_loss did not improve from 0.02344
# Epoch 759/800
# 31/31 - 4s - loss: 0.0037 - accuracy: 0.9995 - val_loss: 0.1135 - val_accuracy: 0.9698
#
# Epoch 00759: val_loss did not improve from 0.02344
# Epoch 760/800
# 31/31 - 4s - loss: 0.0114 - accuracy: 0.9955 - val_loss: 0.1681 - val_accuracy: 0.9598
#
# Epoch 00760: val_loss did not improve from 0.02344
# Epoch 761/800
# 31/31 - 4s - loss: 0.0084 - accuracy: 0.9970 - val_loss: 0.0835 - val_accuracy: 0.9698
#
# Epoch 00761: val_loss did not improve from 0.02344
# Epoch 762/800
# 31/31 - 4s - loss: 0.0089 - accuracy: 0.9955 - val_loss: 0.2079 - val_accuracy: 0.9437
#
# Epoch 00762: val_loss did not improve from 0.02344
# Epoch 763/800
# 31/31 - 4s - loss: 0.0123 - accuracy: 0.9950 - val_loss: 0.2918 - val_accuracy: 0.9135
#
# Epoch 00763: val_loss did not improve from 0.02344
# Epoch 764/800
# 31/31 - 4s - loss: 0.0086 - accuracy: 0.9970 - val_loss: 0.1669 - val_accuracy: 0.9577
#
# Epoch 00764: val_loss did not improve from 0.02344
# Epoch 765/800
# 31/31 - 4s - loss: 0.0090 - accuracy: 0.9945 - val_loss: 0.1513 - val_accuracy: 0.9698
#
# Epoch 00765: val_loss did not improve from 0.02344
# Epoch 766/800
# 31/31 - 4s - loss: 0.0139 - accuracy: 0.9950 - val_loss: 0.1499 - val_accuracy: 0.9638
#
# Epoch 00766: val_loss did not improve from 0.02344
# Epoch 767/800
# 31/31 - 4s - loss: 0.0151 - accuracy: 0.9950 - val_loss: 0.5745 - val_accuracy: 0.8753
#
# Epoch 00767: val_loss did not improve from 0.02344
# Epoch 768/800
# 31/31 - 4s - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.2785 - val_accuracy: 0.9316
#
# Epoch 00768: val_loss did not improve from 0.02344
# Epoch 769/800
# 31/31 - 4s - loss: 0.0142 - accuracy: 0.9950 - val_loss: 0.1740 - val_accuracy: 0.9537
#
# Epoch 00769: val_loss did not improve from 0.02344
# Epoch 770/800
# 31/31 - 4s - loss: 0.0140 - accuracy: 0.9975 - val_loss: 0.3390 - val_accuracy: 0.9276
#
# Epoch 00770: val_loss did not improve from 0.02344
# Epoch 771/800
# 31/31 - 4s - loss: 0.0174 - accuracy: 0.9955 - val_loss: 2.8450 - val_accuracy: 0.6781
#
# Epoch 00771: val_loss did not improve from 0.02344
# Epoch 772/800
# 31/31 - 4s - loss: 0.0153 - accuracy: 0.9945 - val_loss: 0.0656 - val_accuracy: 0.9819
#
# Epoch 00772: val_loss did not improve from 0.02344
# Epoch 773/800
# 31/31 - 4s - loss: 0.0100 - accuracy: 0.9975 - val_loss: 0.2412 - val_accuracy: 0.9276
#
# Epoch 00773: val_loss did not improve from 0.02344
# Epoch 774/800
# 31/31 - 4s - loss: 0.0093 - accuracy: 0.9975 - val_loss: 0.0575 - val_accuracy: 0.9839
#
# Epoch 00774: val_loss did not improve from 0.02344
# Epoch 775/800
# 31/31 - 4s - loss: 0.0084 - accuracy: 0.9975 - val_loss: 0.0865 - val_accuracy: 0.9779
#
# Epoch 00775: val_loss did not improve from 0.02344
# Epoch 776/800
# 31/31 - 4s - loss: 0.0201 - accuracy: 0.9940 - val_loss: 0.2145 - val_accuracy: 0.9537
#
# Epoch 00776: val_loss did not improve from 0.02344
# Epoch 777/800
# 31/31 - 4s - loss: 0.0152 - accuracy: 0.9934 - val_loss: 0.2221 - val_accuracy: 0.9416
#
# Epoch 00777: val_loss did not improve from 0.02344
# Epoch 778/800
# 31/31 - 4s - loss: 0.0081 - accuracy: 0.9970 - val_loss: 0.0839 - val_accuracy: 0.9658
#
# Epoch 00778: val_loss did not improve from 0.02344
# Epoch 779/800
# 31/31 - 4s - loss: 0.0099 - accuracy: 0.9960 - val_loss: 0.0711 - val_accuracy: 0.9718
#
# Epoch 00779: val_loss did not improve from 0.02344
# Epoch 780/800
# 31/31 - 4s - loss: 0.0065 - accuracy: 0.9985 - val_loss: 0.0813 - val_accuracy: 0.9658
#
# Epoch 00780: val_loss did not improve from 0.02344
# Epoch 781/800
# 31/31 - 4s - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.1269 - val_accuracy: 0.9577
#
# Epoch 00781: val_loss did not improve from 0.02344
# Epoch 782/800
# 31/31 - 4s - loss: 0.0051 - accuracy: 0.9975 - val_loss: 0.7620 - val_accuracy: 0.8270
#
# Epoch 00782: val_loss did not improve from 0.02344
# Epoch 783/800
# 31/31 - 4s - loss: 0.0083 - accuracy: 0.9975 - val_loss: 0.9613 - val_accuracy: 0.7988
#
# Epoch 00783: val_loss did not improve from 0.02344
# Epoch 784/800
# 31/31 - 4s - loss: 0.0104 - accuracy: 0.9960 - val_loss: 0.1802 - val_accuracy: 0.9517
#
# Epoch 00784: val_loss did not improve from 0.02344
# Epoch 785/800
# 31/31 - 4s - loss: 0.0069 - accuracy: 0.9970 - val_loss: 0.2609 - val_accuracy: 0.9457
#
# Epoch 00785: val_loss did not improve from 0.02344
# Epoch 786/800
# 31/31 - 4s - loss: 0.0051 - accuracy: 0.9975 - val_loss: 0.0960 - val_accuracy: 0.9738
#
# Epoch 00786: val_loss did not improve from 0.02344
# Epoch 787/800
# 31/31 - 4s - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.1211 - val_accuracy: 0.9698
#
# Epoch 00787: val_loss did not improve from 0.02344
# Epoch 788/800
# 31/31 - 4s - loss: 0.0155 - accuracy: 0.9934 - val_loss: 0.2238 - val_accuracy: 0.9457
#
# Epoch 00788: val_loss did not improve from 0.02344
# Epoch 789/800
# 31/31 - 4s - loss: 0.0129 - accuracy: 0.9960 - val_loss: 0.2004 - val_accuracy: 0.9557
#
# Epoch 00789: val_loss did not improve from 0.02344
# Epoch 790/800
# 31/31 - 4s - loss: 0.0069 - accuracy: 0.9965 - val_loss: 0.0743 - val_accuracy: 0.9839
#
# Epoch 00790: val_loss did not improve from 0.02344
# Epoch 791/800
# 31/31 - 4s - loss: 0.0071 - accuracy: 0.9990 - val_loss: 0.1003 - val_accuracy: 0.9759
#
# Epoch 00791: val_loss did not improve from 0.02344
# Epoch 792/800
# 31/31 - 4s - loss: 0.0080 - accuracy: 0.9975 - val_loss: 0.7523 - val_accuracy: 0.8370
#
# Epoch 00792: val_loss did not improve from 0.02344
# Epoch 793/800
# 31/31 - 4s - loss: 0.0060 - accuracy: 0.9985 - val_loss: 0.0554 - val_accuracy: 0.9839
#
# Epoch 00793: val_loss did not improve from 0.02344
# Epoch 794/800
# 31/31 - 4s - loss: 0.0153 - accuracy: 0.9955 - val_loss: 0.0376 - val_accuracy: 0.9899
#
# Epoch 00794: val_loss did not improve from 0.02344
# Epoch 795/800
# 31/31 - 4s - loss: 0.0117 - accuracy: 0.9955 - val_loss: 0.0755 - val_accuracy: 0.9718
#
# Epoch 00795: val_loss did not improve from 0.02344
# Epoch 796/800
# 31/31 - 4s - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.1044 - val_accuracy: 0.9738
#
# Epoch 00796: val_loss did not improve from 0.02344
# Epoch 797/800
# 31/31 - 4s - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.1163 - val_accuracy: 0.9759
#
# Epoch 00797: val_loss did not improve from 0.02344
# Epoch 798/800
# 31/31 - 4s - loss: 0.0101 - accuracy: 0.9980 - val_loss: 0.0840 - val_accuracy: 0.9839
#
# Epoch 00798: val_loss did not improve from 0.02344
# Epoch 799/800
# 31/31 - 4s - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.0799 - val_accuracy: 0.9819
#
# Epoch 00799: val_loss did not improve from 0.02344
# Epoch 800/800
# 31/31 - 4s - loss: 0.0063 - accuracy: 0.9975 - val_loss: 0.0567 - val_accuracy: 0.9839
#
# Epoch 00800: val_loss did not improve from 0.02344

# %%
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0567 - accuracy: 0.9839
# Final Loss: 0.05674150958657265, Final Accuracy: 0.9839034080505371

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 145.31999999999996, 'Predicted')

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from skimage import io
from keras.preprocessing import image
#path='imbalanced/Scratch/Scratch_400.jpg'
img = image.load_img('/content/COVID/Covid (1010).png', grayscale=False, target_size=(64, 64))
show_img=image.load_img('/content/COVID/Covid (1010).png', grayscale=False, target_size=(200, 200))
disease_class=['Covid-19','Non Covid-19']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255

custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [9.9999905e-01 9.7145585e-07]
# Prediction: Covid-19

# %%
from skimage import io
from keras.preprocessing import image
#path='imbalanced/Scratch/Scratch_400.jpg'
img = image.load_img('/content/non-COVID/Non-Covid (1007).png', grayscale=False, target_size=(64, 64))
show_img=image.load_img('/content/non-COVID/Non-Covid (1007).png', grayscale=False, target_size=(200, 200))
disease_class=['Covid-19','Non Covid-19']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255

custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [0.00295021 0.9970498 ]
# Prediction: Non Covid-19
