# %% [markdown]
# <a href="https://colab.research.google.com/github/AnimeshMondol/CSE498R/blob/main/epo700.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Jun 11 14:48:33 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2020.12.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-de846053-f4d1-4064-a302-e881e89db580" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-de846053-f4d1-4064-a302-e881e89db580">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"animeshmondol","key":"c4507c33debf7afb770d35a343bfcbcc"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle

#Change permission
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d plameneduardo/sarscov2-ctscan-dataset
# Out:
# Downloading sarscov2-ctscan-dataset.zip to /content
#  98% 227M/230M [00:02<00:00, 75.8MB/s]
# 100% 230M/230M [00:02<00:00, 81.3MB/s]

# %%
from zipfile import ZipFile
file_name = "sarscov2-ctscan-dataset.zip"

with ZipFile(file_name,"r") as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
        #print(os.path.join(dirname, filename))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.densenet import DenseNet121

# %%
disease_types=['COVID', 'non-COVID']
data_dir = '/content'
train_dir = os.path.join(data_dir)

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.head()
# Out:
#                     File  DiseaseID Disease Type
# 0   COVID/Covid (63).png          0        COVID
# 1  COVID/Covid (386).png          0        COVID
# 2  COVID/Covid (816).png          0        COVID
# 3  COVID/Covid (896).png          0        COVID
# 4  COVID/Covid (782).png          0        COVID

# %%
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#                             File  DiseaseID Disease Type
# 0          COVID/Covid (178).png          0        COVID
# 1          COVID/Covid (494).png          0        COVID
# 2  non-COVID/Non-Covid (585).png          1    non-COVID
# 3  non-COVID/Non-Covid (952).png          1    non-COVID
# 4          COVID/Covid (710).png          0        COVID

# %%
plt.hist(train['DiseaseID'])
plt.title('Frequency Histogram of Species')
plt.figure(figsize=(12, 12))
plt.show()

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('COVID', 5, 5)

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('non-COVID', 5, 5)

# %%
IMAGE_SIZE = 64
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 2481it [00:07, 325.69it/s]
# Train Shape: (2481, 64, 64, 3)

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=2)

# %%
BATCH_SIZE = 64

# Split the train and validation sets 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 15))
for i in range(3):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(disease_types[np.argmax(Y_train[i])])

# %%
EPOCHS = 700
SIZE=64
N_ch=3

# %%
def build_densenet():
    densenet = DenseNet121(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = densenet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    optimizer = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
model = build_densenet()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        zoom_range=0.2, # Range for random zoom
                        horizontal_flip=True, # Randomly flip inputs horizontally
                        vertical_flip=True) # Randomly flip inputs vertically

datagen.fit(X_train)
# Fits the model on batches with real-time data augmentation
hist = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 3)         84
# _________________________________________________________________
# densenet121 (Functional)     (None, None, None, 1024)  7037504
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               262400
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# root (Dense)                 (None, 2)                 514
# =================================================================
# Total params: 7,305,622
# Trainable params: 7,219,414
# Non-trainable params: 86,208
# _________________________________________________________________
# Epoch 1/700
# 31/31 - 35s - loss: 1.2359 - accuracy: 0.5464 - val_loss: 0.8851 - val_accuracy: 0.5352
#
# Epoch 00001: val_loss improved from inf to 0.88513, saving model to model.h5
# Epoch 2/700
# 31/31 - 4s - loss: 0.9890 - accuracy: 0.6058 - val_loss: 0.7857 - val_accuracy: 0.5755
#
# Epoch 00002: val_loss improved from 0.88513 to 0.78565, saving model to model.h5
# Epoch 3/700
# 31/31 - 4s - loss: 0.8481 - accuracy: 0.6598 - val_loss: 0.9264 - val_accuracy: 0.5312
#
# Epoch 00003: val_loss did not improve from 0.78565
# Epoch 4/700
# 31/31 - 4s - loss: 0.8487 - accuracy: 0.6613 - val_loss: 0.8762 - val_accuracy: 0.5714
#
# Epoch 00004: val_loss did not improve from 0.78565
# Epoch 5/700
# 31/31 - 4s - loss: 0.7357 - accuracy: 0.6845 - val_loss: 0.8967 - val_accuracy: 0.6056
#
# Epoch 00005: val_loss did not improve from 0.78565
# Epoch 6/700
# 31/31 - 4s - loss: 0.6863 - accuracy: 0.7072 - val_loss: 0.7686 - val_accuracy: 0.6318
#
# Epoch 00006: val_loss improved from 0.78565 to 0.76863, saving model to model.h5
# Epoch 7/700
# 31/31 - 4s - loss: 0.6575 - accuracy: 0.7243 - val_loss: 0.9509 - val_accuracy: 0.5734
#
# Epoch 00007: val_loss did not improve from 0.76863
# Epoch 8/700
# 31/31 - 4s - loss: 0.5986 - accuracy: 0.7389 - val_loss: 1.0066 - val_accuracy: 0.6137
#
# Epoch 00008: val_loss did not improve from 0.76863
# Epoch 9/700
# 31/31 - 4s - loss: 0.5683 - accuracy: 0.7621 - val_loss: 0.8474 - val_accuracy: 0.6378
#
# Epoch 00009: val_loss did not improve from 0.76863
# Epoch 10/700
# 31/31 - 4s - loss: 0.4910 - accuracy: 0.7974 - val_loss: 0.6127 - val_accuracy: 0.7002
#
# Epoch 00010: val_loss improved from 0.76863 to 0.61271, saving model to model.h5
# Epoch 11/700
# 31/31 - 4s - loss: 0.4804 - accuracy: 0.7964 - val_loss: 0.5561 - val_accuracy: 0.7203
#
# Epoch 00011: val_loss improved from 0.61271 to 0.55606, saving model to model.h5
# Epoch 12/700
# 31/31 - 4s - loss: 0.4451 - accuracy: 0.8135 - val_loss: 0.6399 - val_accuracy: 0.7183
#
# Epoch 00012: val_loss did not improve from 0.55606
# Epoch 13/700
# 31/31 - 4s - loss: 0.4651 - accuracy: 0.8080 - val_loss: 0.8332 - val_accuracy: 0.6620
#
# Epoch 00013: val_loss did not improve from 0.55606
# Epoch 14/700
# 31/31 - 4s - loss: 0.3917 - accuracy: 0.8301 - val_loss: 0.3309 - val_accuracy: 0.8571
#
# Epoch 00014: val_loss improved from 0.55606 to 0.33089, saving model to model.h5
# Epoch 15/700
# 31/31 - 4s - loss: 0.4090 - accuracy: 0.8206 - val_loss: 0.3222 - val_accuracy: 0.8632
#
# Epoch 00015: val_loss improved from 0.33089 to 0.32215, saving model to model.h5
# Epoch 16/700
# 31/31 - 4s - loss: 0.3860 - accuracy: 0.8377 - val_loss: 0.3666 - val_accuracy: 0.8390
#
# Epoch 00016: val_loss did not improve from 0.32215
# Epoch 17/700
# 31/31 - 4s - loss: 0.3767 - accuracy: 0.8493 - val_loss: 0.4608 - val_accuracy: 0.7907
#
# Epoch 00017: val_loss did not improve from 0.32215
# Epoch 18/700
# 31/31 - 4s - loss: 0.3531 - accuracy: 0.8523 - val_loss: 0.4207 - val_accuracy: 0.8209
#
# Epoch 00018: val_loss did not improve from 0.32215
# Epoch 19/700
# 31/31 - 4s - loss: 0.3580 - accuracy: 0.8538 - val_loss: 0.5371 - val_accuracy: 0.7746
#
# Epoch 00019: val_loss did not improve from 0.32215
# Epoch 20/700
# 31/31 - 4s - loss: 0.3328 - accuracy: 0.8654 - val_loss: 0.2602 - val_accuracy: 0.8873
#
# Epoch 00020: val_loss improved from 0.32215 to 0.26025, saving model to model.h5
# Epoch 21/700
# 31/31 - 4s - loss: 0.3365 - accuracy: 0.8614 - val_loss: 0.3427 - val_accuracy: 0.8571
#
# Epoch 00021: val_loss did not improve from 0.26025
# Epoch 22/700
# 31/31 - 4s - loss: 0.3345 - accuracy: 0.8579 - val_loss: 0.4191 - val_accuracy: 0.8109
#
# Epoch 00022: val_loss did not improve from 0.26025
# Epoch 23/700
# 31/31 - 4s - loss: 0.3229 - accuracy: 0.8745 - val_loss: 0.3132 - val_accuracy: 0.8491
#
# Epoch 00023: val_loss did not improve from 0.26025
# Epoch 24/700
# 31/31 - 4s - loss: 0.3301 - accuracy: 0.8684 - val_loss: 0.3417 - val_accuracy: 0.8270
#
# Epoch 00024: val_loss did not improve from 0.26025
# Epoch 25/700
# 31/31 - 4s - loss: 0.3170 - accuracy: 0.8629 - val_loss: 0.3722 - val_accuracy: 0.8370
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 00025: val_loss did not improve from 0.26025
# Epoch 26/700
# 31/31 - 4s - loss: 0.3153 - accuracy: 0.8639 - val_loss: 0.2870 - val_accuracy: 0.8652
#
# Epoch 00026: val_loss did not improve from 0.26025
# Epoch 27/700
# 31/31 - 4s - loss: 0.3075 - accuracy: 0.8740 - val_loss: 0.3711 - val_accuracy: 0.8310
#
# Epoch 00027: val_loss did not improve from 0.26025
# Epoch 28/700
# 31/31 - 4s - loss: 0.2851 - accuracy: 0.8810 - val_loss: 0.2256 - val_accuracy: 0.9034
#
# Epoch 00028: val_loss improved from 0.26025 to 0.22557, saving model to model.h5
# Epoch 29/700
# 31/31 - 4s - loss: 0.2991 - accuracy: 0.8790 - val_loss: 0.2268 - val_accuracy: 0.9034
#
# Epoch 00029: val_loss did not improve from 0.22557
# Epoch 30/700
# 31/31 - 4s - loss: 0.2922 - accuracy: 0.8790 - val_loss: 0.2410 - val_accuracy: 0.8833
#
# Epoch 00030: val_loss did not improve from 0.22557
# Epoch 31/700
# 31/31 - 4s - loss: 0.2750 - accuracy: 0.8851 - val_loss: 0.3147 - val_accuracy: 0.8753
#
# Epoch 00031: val_loss did not improve from 0.22557
# Epoch 32/700
# 31/31 - 4s - loss: 0.2900 - accuracy: 0.8790 - val_loss: 0.2990 - val_accuracy: 0.8873
#
# Epoch 00032: val_loss did not improve from 0.22557
# Epoch 33/700
# 31/31 - 4s - loss: 0.2817 - accuracy: 0.8780 - val_loss: 0.2278 - val_accuracy: 0.9074
#
# Epoch 00033: val_loss did not improve from 0.22557
# Epoch 34/700
# 31/31 - 4s - loss: 0.2830 - accuracy: 0.8851 - val_loss: 0.2184 - val_accuracy: 0.9054
#
# Epoch 00034: val_loss improved from 0.22557 to 0.21836, saving model to model.h5
# Epoch 35/700
# 31/31 - 4s - loss: 0.2678 - accuracy: 0.8866 - val_loss: 0.2201 - val_accuracy: 0.9095
#
# Epoch 00035: val_loss did not improve from 0.21836
# Epoch 36/700
# 31/31 - 4s - loss: 0.2752 - accuracy: 0.8846 - val_loss: 0.2903 - val_accuracy: 0.8652
#
# Epoch 00036: val_loss did not improve from 0.21836
# Epoch 37/700
# 31/31 - 4s - loss: 0.2776 - accuracy: 0.8841 - val_loss: 0.2866 - val_accuracy: 0.8712
#
# Epoch 00037: val_loss did not improve from 0.21836
# Epoch 38/700
# 31/31 - 4s - loss: 0.2712 - accuracy: 0.8866 - val_loss: 0.4137 - val_accuracy: 0.8068
#
# Epoch 00038: val_loss did not improve from 0.21836
# Epoch 39/700
# 31/31 - 4s - loss: 0.2532 - accuracy: 0.8992 - val_loss: 0.4609 - val_accuracy: 0.7646
#
# Epoch 00039: val_loss did not improve from 0.21836
# Epoch 40/700
# 31/31 - 4s - loss: 0.2693 - accuracy: 0.8916 - val_loss: 0.2327 - val_accuracy: 0.8954
#
# Epoch 00040: val_loss did not improve from 0.21836
# Epoch 41/700
# 31/31 - 4s - loss: 0.2694 - accuracy: 0.8936 - val_loss: 0.2514 - val_accuracy: 0.9074
#
# Epoch 00041: val_loss did not improve from 0.21836
# Epoch 42/700
# 31/31 - 4s - loss: 0.2716 - accuracy: 0.8881 - val_loss: 0.2236 - val_accuracy: 0.9135
#
# Epoch 00042: val_loss did not improve from 0.21836
# Epoch 43/700
# 31/31 - 4s - loss: 0.2640 - accuracy: 0.8911 - val_loss: 0.2406 - val_accuracy: 0.8913
#
# Epoch 00043: val_loss did not improve from 0.21836
# Epoch 44/700
# 31/31 - 4s - loss: 0.2442 - accuracy: 0.9027 - val_loss: 0.3858 - val_accuracy: 0.8229
#
# Epoch 00044: val_loss did not improve from 0.21836
# Epoch 45/700
# 31/31 - 4s - loss: 0.2609 - accuracy: 0.9007 - val_loss: 0.5060 - val_accuracy: 0.7646
#
# Epoch 00045: val_loss did not improve from 0.21836
# Epoch 46/700
# 31/31 - 4s - loss: 0.2530 - accuracy: 0.8982 - val_loss: 0.2491 - val_accuracy: 0.8833
#
# Epoch 00046: val_loss did not improve from 0.21836
# Epoch 47/700
# 31/31 - 4s - loss: 0.2417 - accuracy: 0.8967 - val_loss: 0.2441 - val_accuracy: 0.9014
#
# Epoch 00047: val_loss did not improve from 0.21836
# Epoch 48/700
# 31/31 - 4s - loss: 0.2373 - accuracy: 0.9022 - val_loss: 0.2408 - val_accuracy: 0.9014
#
# Epoch 00048: val_loss did not improve from 0.21836
# Epoch 49/700
# 31/31 - 4s - loss: 0.2634 - accuracy: 0.8926 - val_loss: 0.2970 - val_accuracy: 0.8672
#
# Epoch 00049: val_loss did not improve from 0.21836
# Epoch 50/700
# 31/31 - 4s - loss: 0.2429 - accuracy: 0.9037 - val_loss: 0.3212 - val_accuracy: 0.8551
#
# Epoch 00050: val_loss did not improve from 0.21836
# Epoch 51/700
# 31/31 - 4s - loss: 0.2268 - accuracy: 0.9118 - val_loss: 0.3421 - val_accuracy: 0.8410
#
# Epoch 00051: val_loss did not improve from 0.21836
# Epoch 52/700
# 31/31 - 4s - loss: 0.2388 - accuracy: 0.9022 - val_loss: 0.2514 - val_accuracy: 0.8793
#
# Epoch 00052: val_loss did not improve from 0.21836
# Epoch 53/700
# 31/31 - 4s - loss: 0.2289 - accuracy: 0.9057 - val_loss: 0.2121 - val_accuracy: 0.9195
#
# Epoch 00053: val_loss improved from 0.21836 to 0.21206, saving model to model.h5
# Epoch 54/700
# 31/31 - 4s - loss: 0.2436 - accuracy: 0.9037 - val_loss: 0.3034 - val_accuracy: 0.8672
#
# Epoch 00054: val_loss did not improve from 0.21206
# Epoch 55/700
# 31/31 - 4s - loss: 0.2420 - accuracy: 0.8987 - val_loss: 0.2313 - val_accuracy: 0.8934
#
# Epoch 00055: val_loss did not improve from 0.21206
# Epoch 56/700
# 31/31 - 4s - loss: 0.2410 - accuracy: 0.9022 - val_loss: 0.2296 - val_accuracy: 0.9074
#
# Epoch 00056: val_loss did not improve from 0.21206
# Epoch 57/700
# 31/31 - 4s - loss: 0.2422 - accuracy: 0.8952 - val_loss: 0.3080 - val_accuracy: 0.8632
#
# Epoch 00057: val_loss did not improve from 0.21206
# Epoch 58/700
# 31/31 - 4s - loss: 0.2236 - accuracy: 0.9108 - val_loss: 0.2057 - val_accuracy: 0.9155
#
# Epoch 00058: val_loss improved from 0.21206 to 0.20571, saving model to model.h5
# Epoch 59/700
# 31/31 - 4s - loss: 0.2337 - accuracy: 0.9083 - val_loss: 0.2644 - val_accuracy: 0.8954
#
# Epoch 00059: val_loss did not improve from 0.20571
# Epoch 60/700
# 31/31 - 4s - loss: 0.2231 - accuracy: 0.9062 - val_loss: 0.2069 - val_accuracy: 0.9256
#
# Epoch 00060: val_loss did not improve from 0.20571
# Epoch 61/700
# 31/31 - 4s - loss: 0.2244 - accuracy: 0.9073 - val_loss: 0.3153 - val_accuracy: 0.8632
#
# Epoch 00061: val_loss did not improve from 0.20571
# Epoch 62/700
# 31/31 - 4s - loss: 0.2093 - accuracy: 0.9168 - val_loss: 0.2134 - val_accuracy: 0.9014
#
# Epoch 00062: val_loss did not improve from 0.20571
# Epoch 63/700
# 31/31 - 4s - loss: 0.2313 - accuracy: 0.9052 - val_loss: 0.4155 - val_accuracy: 0.7988
#
# Epoch 00063: val_loss did not improve from 0.20571
# Epoch 64/700
# 31/31 - 4s - loss: 0.2205 - accuracy: 0.9108 - val_loss: 0.1895 - val_accuracy: 0.9155
#
# Epoch 00064: val_loss improved from 0.20571 to 0.18949, saving model to model.h5
# Epoch 65/700
# 31/31 - 4s - loss: 0.2233 - accuracy: 0.9022 - val_loss: 0.2663 - val_accuracy: 0.9014
#
# Epoch 00065: val_loss did not improve from 0.18949
# Epoch 66/700
# 31/31 - 4s - loss: 0.2107 - accuracy: 0.9148 - val_loss: 0.2055 - val_accuracy: 0.9155
#
# Epoch 00066: val_loss did not improve from 0.18949
# Epoch 67/700
# 31/31 - 4s - loss: 0.2164 - accuracy: 0.9168 - val_loss: 0.2676 - val_accuracy: 0.8954
#
# Epoch 00067: val_loss did not improve from 0.18949
# Epoch 68/700
# 31/31 - 4s - loss: 0.2076 - accuracy: 0.9103 - val_loss: 0.3258 - val_accuracy: 0.8612
#
# Epoch 00068: val_loss did not improve from 0.18949
# Epoch 69/700
# 31/31 - 4s - loss: 0.1893 - accuracy: 0.9163 - val_loss: 0.2022 - val_accuracy: 0.9014
#
# Epoch 00069: val_loss did not improve from 0.18949
# Epoch 70/700
# 31/31 - 4s - loss: 0.2084 - accuracy: 0.9173 - val_loss: 0.2131 - val_accuracy: 0.8954
#
# Epoch 00070: val_loss did not improve from 0.18949
# Epoch 71/700
# 31/31 - 4s - loss: 0.1922 - accuracy: 0.9189 - val_loss: 0.2010 - val_accuracy: 0.9115
#
# Epoch 00071: val_loss did not improve from 0.18949
# Epoch 72/700
# 31/31 - 4s - loss: 0.2012 - accuracy: 0.9138 - val_loss: 0.2563 - val_accuracy: 0.9014
#
# Epoch 00072: val_loss did not improve from 0.18949
# Epoch 73/700
# 31/31 - 4s - loss: 0.2088 - accuracy: 0.9173 - val_loss: 0.1958 - val_accuracy: 0.9135
#
# Epoch 00073: val_loss did not improve from 0.18949
# Epoch 74/700
# 31/31 - 4s - loss: 0.2097 - accuracy: 0.9143 - val_loss: 0.2004 - val_accuracy: 0.9155
#
# Epoch 00074: val_loss did not improve from 0.18949
# Epoch 75/700
# 31/31 - 4s - loss: 0.2016 - accuracy: 0.9113 - val_loss: 0.2392 - val_accuracy: 0.8974
#
# Epoch 00075: val_loss did not improve from 0.18949
# Epoch 76/700
# 31/31 - 4s - loss: 0.1883 - accuracy: 0.9234 - val_loss: 0.2370 - val_accuracy: 0.8994
#
# Epoch 00076: val_loss did not improve from 0.18949
# Epoch 77/700
# 31/31 - 4s - loss: 0.1833 - accuracy: 0.9279 - val_loss: 0.2138 - val_accuracy: 0.9074
#
# Epoch 00077: val_loss did not improve from 0.18949
# Epoch 78/700
# 31/31 - 4s - loss: 0.1849 - accuracy: 0.9244 - val_loss: 0.3520 - val_accuracy: 0.8813
#
# Epoch 00078: val_loss did not improve from 0.18949
# Epoch 79/700
# 31/31 - 4s - loss: 0.2048 - accuracy: 0.9153 - val_loss: 0.1881 - val_accuracy: 0.9115
#
# Epoch 00079: val_loss improved from 0.18949 to 0.18805, saving model to model.h5
# Epoch 80/700
# 31/31 - 4s - loss: 0.2028 - accuracy: 0.9143 - val_loss: 0.2198 - val_accuracy: 0.9175
#
# Epoch 00080: val_loss did not improve from 0.18805
# Epoch 81/700
# 31/31 - 4s - loss: 0.1968 - accuracy: 0.9254 - val_loss: 0.2464 - val_accuracy: 0.8934
#
# Epoch 00081: val_loss did not improve from 0.18805
# Epoch 82/700
# 31/31 - 4s - loss: 0.1940 - accuracy: 0.9239 - val_loss: 0.3105 - val_accuracy: 0.8692
#
# Epoch 00082: val_loss did not improve from 0.18805
# Epoch 83/700
# 31/31 - 4s - loss: 0.1858 - accuracy: 0.9274 - val_loss: 0.1830 - val_accuracy: 0.9135
#
# Epoch 00083: val_loss improved from 0.18805 to 0.18303, saving model to model.h5
# Epoch 84/700
# 31/31 - 4s - loss: 0.1765 - accuracy: 0.9320 - val_loss: 0.2440 - val_accuracy: 0.9074
#
# Epoch 00084: val_loss did not improve from 0.18303
# Epoch 85/700
# 31/31 - 4s - loss: 0.1682 - accuracy: 0.9284 - val_loss: 0.3083 - val_accuracy: 0.8793
#
# Epoch 00085: val_loss did not improve from 0.18303
# Epoch 86/700
# 31/31 - 4s - loss: 0.1799 - accuracy: 0.9284 - val_loss: 0.3129 - val_accuracy: 0.8793
#
# Epoch 00086: val_loss did not improve from 0.18303
# Epoch 87/700
# 31/31 - 4s - loss: 0.1735 - accuracy: 0.9340 - val_loss: 0.2407 - val_accuracy: 0.8974
#
# Epoch 00087: val_loss did not improve from 0.18303
# Epoch 88/700
# 31/31 - 4s - loss: 0.1943 - accuracy: 0.9199 - val_loss: 0.3504 - val_accuracy: 0.8451
#
# Epoch 00088: val_loss did not improve from 0.18303
# Epoch 89/700
# 31/31 - 4s - loss: 0.1710 - accuracy: 0.9315 - val_loss: 0.2714 - val_accuracy: 0.9014
#
# Epoch 00089: val_loss did not improve from 0.18303
# Epoch 90/700
# 31/31 - 4s - loss: 0.1836 - accuracy: 0.9214 - val_loss: 0.2402 - val_accuracy: 0.9014
#
# Epoch 00090: val_loss did not improve from 0.18303
# Epoch 91/700
# 31/31 - 4s - loss: 0.1841 - accuracy: 0.9219 - val_loss: 0.1913 - val_accuracy: 0.9135
#
# Epoch 00091: val_loss did not improve from 0.18303
# Epoch 92/700
# 31/31 - 4s - loss: 0.1714 - accuracy: 0.9249 - val_loss: 0.1989 - val_accuracy: 0.9256
#
# Epoch 00092: val_loss did not improve from 0.18303
# Epoch 93/700
# 31/31 - 4s - loss: 0.1687 - accuracy: 0.9279 - val_loss: 0.1966 - val_accuracy: 0.9276
#
# Epoch 00093: val_loss did not improve from 0.18303
# Epoch 94/700
# 31/31 - 4s - loss: 0.1696 - accuracy: 0.9299 - val_loss: 0.2668 - val_accuracy: 0.9034
#
# Epoch 00094: val_loss did not improve from 0.18303
# Epoch 95/700
# 31/31 - 4s - loss: 0.1815 - accuracy: 0.9269 - val_loss: 0.3599 - val_accuracy: 0.8773
#
# Epoch 00095: val_loss did not improve from 0.18303
# Epoch 96/700
# 31/31 - 4s - loss: 0.1662 - accuracy: 0.9320 - val_loss: 0.2219 - val_accuracy: 0.9195
#
# Epoch 00096: val_loss did not improve from 0.18303
# Epoch 97/700
# 31/31 - 4s - loss: 0.1625 - accuracy: 0.9299 - val_loss: 0.6099 - val_accuracy: 0.7626
#
# Epoch 00097: val_loss did not improve from 0.18303
# Epoch 98/700
# 31/31 - 4s - loss: 0.1824 - accuracy: 0.9209 - val_loss: 0.4139 - val_accuracy: 0.8350
#
# Epoch 00098: val_loss did not improve from 0.18303
# Epoch 99/700
# 31/31 - 4s - loss: 0.1599 - accuracy: 0.9390 - val_loss: 0.4119 - val_accuracy: 0.8390
#
# Epoch 00099: val_loss did not improve from 0.18303
# Epoch 100/700
# 31/31 - 4s - loss: 0.1585 - accuracy: 0.9320 - val_loss: 0.4862 - val_accuracy: 0.8048
#
# Epoch 00100: val_loss did not improve from 0.18303
# Epoch 101/700
# 31/31 - 4s - loss: 0.1484 - accuracy: 0.9425 - val_loss: 0.1715 - val_accuracy: 0.9296
#
# Epoch 00101: val_loss improved from 0.18303 to 0.17146, saving model to model.h5
# Epoch 102/700
# 31/31 - 4s - loss: 0.1642 - accuracy: 0.9345 - val_loss: 0.2573 - val_accuracy: 0.9135
#
# Epoch 00102: val_loss did not improve from 0.17146
# Epoch 103/700
# 31/31 - 4s - loss: 0.1620 - accuracy: 0.9390 - val_loss: 0.1833 - val_accuracy: 0.9155
#
# Epoch 00103: val_loss did not improve from 0.17146
# Epoch 104/700
# 31/31 - 4s - loss: 0.1663 - accuracy: 0.9375 - val_loss: 0.3424 - val_accuracy: 0.8692
#
# Epoch 00104: val_loss did not improve from 0.17146
# Epoch 105/700
# 31/31 - 4s - loss: 0.1622 - accuracy: 0.9380 - val_loss: 0.4928 - val_accuracy: 0.8028
#
# Epoch 00105: val_loss did not improve from 0.17146
# Epoch 106/700
# 31/31 - 4s - loss: 0.1676 - accuracy: 0.9320 - val_loss: 0.1841 - val_accuracy: 0.9235
#
# Epoch 00106: val_loss did not improve from 0.17146
# Epoch 107/700
# 31/31 - 4s - loss: 0.1422 - accuracy: 0.9410 - val_loss: 0.2618 - val_accuracy: 0.8893
#
# Epoch 00107: val_loss did not improve from 0.17146
# Epoch 108/700
# 31/31 - 4s - loss: 0.1544 - accuracy: 0.9299 - val_loss: 0.4635 - val_accuracy: 0.8189
#
# Epoch 00108: val_loss did not improve from 0.17146
# Epoch 109/700
# 31/31 - 4s - loss: 0.1475 - accuracy: 0.9360 - val_loss: 0.4850 - val_accuracy: 0.8048
#
# Epoch 00109: val_loss did not improve from 0.17146
# Epoch 110/700
# 31/31 - 4s - loss: 0.1514 - accuracy: 0.9461 - val_loss: 0.1911 - val_accuracy: 0.9296
#
# Epoch 00110: val_loss did not improve from 0.17146
# Epoch 111/700
# 31/31 - 4s - loss: 0.1388 - accuracy: 0.9476 - val_loss: 0.1807 - val_accuracy: 0.9215
#
# Epoch 00111: val_loss did not improve from 0.17146
# Epoch 112/700
# 31/31 - 4s - loss: 0.1321 - accuracy: 0.9441 - val_loss: 0.1769 - val_accuracy: 0.9276
#
# Epoch 00112: val_loss did not improve from 0.17146
# Epoch 113/700
# 31/31 - 4s - loss: 0.1580 - accuracy: 0.9330 - val_loss: 0.1727 - val_accuracy: 0.9316
#
# Epoch 00113: val_loss did not improve from 0.17146
# Epoch 114/700
# 31/31 - 4s - loss: 0.1272 - accuracy: 0.9481 - val_loss: 0.2507 - val_accuracy: 0.9054
#
# Epoch 00114: val_loss did not improve from 0.17146
# Epoch 115/700
# 31/31 - 4s - loss: 0.1336 - accuracy: 0.9481 - val_loss: 0.2825 - val_accuracy: 0.9115
#
# Epoch 00115: val_loss did not improve from 0.17146
# Epoch 116/700
# 31/31 - 4s - loss: 0.1404 - accuracy: 0.9385 - val_loss: 0.2328 - val_accuracy: 0.9175
#
# Epoch 00116: val_loss did not improve from 0.17146
# Epoch 117/700
# 31/31 - 4s - loss: 0.1399 - accuracy: 0.9400 - val_loss: 0.2436 - val_accuracy: 0.9135
#
# Epoch 00117: val_loss did not improve from 0.17146
# Epoch 118/700
# 31/31 - 4s - loss: 0.1329 - accuracy: 0.9451 - val_loss: 0.3069 - val_accuracy: 0.8853
#
# Epoch 00118: val_loss did not improve from 0.17146
# Epoch 119/700
# 31/31 - 4s - loss: 0.1356 - accuracy: 0.9441 - val_loss: 0.3948 - val_accuracy: 0.8592
#
# Epoch 00119: val_loss did not improve from 0.17146
# Epoch 120/700
# 31/31 - 4s - loss: 0.1477 - accuracy: 0.9350 - val_loss: 0.3138 - val_accuracy: 0.9074
#
# Epoch 00120: val_loss did not improve from 0.17146
# Epoch 121/700
# 31/31 - 4s - loss: 0.1415 - accuracy: 0.9456 - val_loss: 0.5667 - val_accuracy: 0.8089
#
# Epoch 00121: val_loss did not improve from 0.17146
# Epoch 122/700
# 31/31 - 4s - loss: 0.1410 - accuracy: 0.9425 - val_loss: 0.1760 - val_accuracy: 0.9256
#
# Epoch 00122: val_loss did not improve from 0.17146
# Epoch 123/700
# 31/31 - 4s - loss: 0.1308 - accuracy: 0.9511 - val_loss: 0.1898 - val_accuracy: 0.9195
#
# Epoch 00123: val_loss did not improve from 0.17146
# Epoch 124/700
# 31/31 - 4s - loss: 0.1205 - accuracy: 0.9496 - val_loss: 0.2342 - val_accuracy: 0.8994
#
# Epoch 00124: val_loss did not improve from 0.17146
# Epoch 125/700
# 31/31 - 4s - loss: 0.1182 - accuracy: 0.9511 - val_loss: 1.1292 - val_accuracy: 0.6600
#
# Epoch 00125: val_loss did not improve from 0.17146
# Epoch 126/700
# 31/31 - 4s - loss: 0.1267 - accuracy: 0.9501 - val_loss: 0.3332 - val_accuracy: 0.8672
#
# Epoch 00126: val_loss did not improve from 0.17146
# Epoch 127/700
# 31/31 - 4s - loss: 0.1127 - accuracy: 0.9572 - val_loss: 0.3689 - val_accuracy: 0.8732
#
# Epoch 00127: val_loss did not improve from 0.17146
# Epoch 128/700
# 31/31 - 4s - loss: 0.1375 - accuracy: 0.9430 - val_loss: 0.1571 - val_accuracy: 0.9256
#
# Epoch 00128: val_loss improved from 0.17146 to 0.15709, saving model to model.h5
# Epoch 129/700
# 31/31 - 4s - loss: 0.1198 - accuracy: 0.9561 - val_loss: 0.9749 - val_accuracy: 0.7123
#
# Epoch 00129: val_loss did not improve from 0.15709
# Epoch 130/700
# 31/31 - 4s - loss: 0.1145 - accuracy: 0.9561 - val_loss: 0.2097 - val_accuracy: 0.9376
#
# Epoch 00130: val_loss did not improve from 0.15709
# Epoch 131/700
# 31/31 - 4s - loss: 0.1221 - accuracy: 0.9486 - val_loss: 0.1993 - val_accuracy: 0.9416
#
# Epoch 00131: val_loss did not improve from 0.15709
# Epoch 132/700
# 31/31 - 4s - loss: 0.1281 - accuracy: 0.9491 - val_loss: 0.4524 - val_accuracy: 0.8451
#
# Epoch 00132: val_loss did not improve from 0.15709
# Epoch 133/700
# 31/31 - 4s - loss: 0.1255 - accuracy: 0.9430 - val_loss: 0.4501 - val_accuracy: 0.8410
#
# Epoch 00133: val_loss did not improve from 0.15709
# Epoch 134/700
# 31/31 - 4s - loss: 0.1009 - accuracy: 0.9612 - val_loss: 0.3549 - val_accuracy: 0.8813
#
# Epoch 00134: val_loss did not improve from 0.15709
# Epoch 135/700
# 31/31 - 4s - loss: 0.1156 - accuracy: 0.9577 - val_loss: 0.1930 - val_accuracy: 0.9135
#
# Epoch 00135: val_loss did not improve from 0.15709
# Epoch 136/700
# 31/31 - 4s - loss: 0.1358 - accuracy: 0.9456 - val_loss: 0.3583 - val_accuracy: 0.8732
#
# Epoch 00136: val_loss did not improve from 0.15709
# Epoch 137/700
# 31/31 - 4s - loss: 0.1143 - accuracy: 0.9612 - val_loss: 0.1501 - val_accuracy: 0.9376
#
# Epoch 00137: val_loss improved from 0.15709 to 0.15010, saving model to model.h5
# Epoch 138/700
# 31/31 - 4s - loss: 0.1191 - accuracy: 0.9516 - val_loss: 0.3733 - val_accuracy: 0.8753
#
# Epoch 00138: val_loss did not improve from 0.15010
# Epoch 139/700
# 31/31 - 4s - loss: 0.1006 - accuracy: 0.9672 - val_loss: 0.2382 - val_accuracy: 0.9235
#
# Epoch 00139: val_loss did not improve from 0.15010
# Epoch 140/700
# 31/31 - 4s - loss: 0.1247 - accuracy: 0.9506 - val_loss: 0.1630 - val_accuracy: 0.9356
#
# Epoch 00140: val_loss did not improve from 0.15010
# Epoch 141/700
# 31/31 - 4s - loss: 0.1115 - accuracy: 0.9567 - val_loss: 0.1414 - val_accuracy: 0.9336
#
# Epoch 00141: val_loss improved from 0.15010 to 0.14144, saving model to model.h5
# Epoch 142/700
# 31/31 - 4s - loss: 0.1325 - accuracy: 0.9481 - val_loss: 0.2048 - val_accuracy: 0.9175
#
# Epoch 00142: val_loss did not improve from 0.14144
# Epoch 143/700
# 31/31 - 4s - loss: 0.1153 - accuracy: 0.9531 - val_loss: 0.3262 - val_accuracy: 0.8773
#
# Epoch 00143: val_loss did not improve from 0.14144
# Epoch 144/700
# 31/31 - 4s - loss: 0.1139 - accuracy: 0.9541 - val_loss: 0.3938 - val_accuracy: 0.8833
#
# Epoch 00144: val_loss did not improve from 0.14144
# Epoch 145/700
# 31/31 - 4s - loss: 0.1218 - accuracy: 0.9516 - val_loss: 0.3493 - val_accuracy: 0.8994
#
# Epoch 00145: val_loss did not improve from 0.14144
# Epoch 146/700
# 31/31 - 4s - loss: 0.1076 - accuracy: 0.9561 - val_loss: 0.2080 - val_accuracy: 0.9074
#
# Epoch 00146: val_loss did not improve from 0.14144
# Epoch 147/700
# 31/31 - 4s - loss: 0.1136 - accuracy: 0.9587 - val_loss: 0.2681 - val_accuracy: 0.9235
#
# Epoch 00147: val_loss did not improve from 0.14144
# Epoch 148/700
# 31/31 - 4s - loss: 0.1081 - accuracy: 0.9546 - val_loss: 0.1286 - val_accuracy: 0.9477
#
# Epoch 00148: val_loss improved from 0.14144 to 0.12859, saving model to model.h5
# Epoch 149/700
# 31/31 - 4s - loss: 0.0845 - accuracy: 0.9667 - val_loss: 0.2330 - val_accuracy: 0.9095
#
# Epoch 00149: val_loss did not improve from 0.12859
# Epoch 150/700
# 31/31 - 4s - loss: 0.1136 - accuracy: 0.9531 - val_loss: 0.4265 - val_accuracy: 0.8451
#
# Epoch 00150: val_loss did not improve from 0.12859
# Epoch 151/700
# 31/31 - 4s - loss: 0.0914 - accuracy: 0.9637 - val_loss: 0.1757 - val_accuracy: 0.9316
#
# Epoch 00151: val_loss did not improve from 0.12859
# Epoch 152/700
# 31/31 - 4s - loss: 0.1176 - accuracy: 0.9511 - val_loss: 0.1356 - val_accuracy: 0.9477
#
# Epoch 00152: val_loss did not improve from 0.12859
# Epoch 153/700
# 31/31 - 4s - loss: 0.1127 - accuracy: 0.9546 - val_loss: 0.2508 - val_accuracy: 0.9095
#
# Epoch 00153: val_loss did not improve from 0.12859
# Epoch 154/700
# 31/31 - 4s - loss: 0.1060 - accuracy: 0.9627 - val_loss: 0.3882 - val_accuracy: 0.8732
#
# Epoch 00154: val_loss did not improve from 0.12859
# Epoch 155/700
# 31/31 - 4s - loss: 0.1153 - accuracy: 0.9546 - val_loss: 0.2934 - val_accuracy: 0.8913
#
# Epoch 00155: val_loss did not improve from 0.12859
# Epoch 156/700
# 31/31 - 4s - loss: 0.0998 - accuracy: 0.9642 - val_loss: 0.2303 - val_accuracy: 0.9095
#
# Epoch 00156: val_loss did not improve from 0.12859
# Epoch 157/700
# 31/31 - 4s - loss: 0.1117 - accuracy: 0.9541 - val_loss: 0.5533 - val_accuracy: 0.8390
#
# Epoch 00157: val_loss did not improve from 0.12859
# Epoch 158/700
# 31/31 - 4s - loss: 0.1123 - accuracy: 0.9567 - val_loss: 0.1861 - val_accuracy: 0.9316
#
# Epoch 00158: val_loss did not improve from 0.12859
# Epoch 159/700
# 31/31 - 4s - loss: 0.1001 - accuracy: 0.9582 - val_loss: 0.2273 - val_accuracy: 0.9316
#
# Epoch 00159: val_loss did not improve from 0.12859
# Epoch 160/700
# 31/31 - 4s - loss: 0.1124 - accuracy: 0.9597 - val_loss: 0.1788 - val_accuracy: 0.9296
#
# Epoch 00160: val_loss did not improve from 0.12859
# Epoch 161/700
# 31/31 - 4s - loss: 0.1029 - accuracy: 0.9602 - val_loss: 0.3526 - val_accuracy: 0.8793
#
# Epoch 00161: val_loss did not improve from 0.12859
# Epoch 162/700
# 31/31 - 4s - loss: 0.0999 - accuracy: 0.9617 - val_loss: 0.1638 - val_accuracy: 0.9416
#
# Epoch 00162: val_loss did not improve from 0.12859
# Epoch 163/700
# 31/31 - 4s - loss: 0.1058 - accuracy: 0.9551 - val_loss: 0.1583 - val_accuracy: 0.9437
#
# Epoch 00163: val_loss did not improve from 0.12859
# Epoch 164/700
# 31/31 - 4s - loss: 0.1021 - accuracy: 0.9597 - val_loss: 0.2039 - val_accuracy: 0.9276
#
# Epoch 00164: val_loss did not improve from 0.12859
# Epoch 165/700
# 31/31 - 4s - loss: 0.0920 - accuracy: 0.9647 - val_loss: 0.3250 - val_accuracy: 0.8773
#
# Epoch 00165: val_loss did not improve from 0.12859
# Epoch 166/700
# 31/31 - 4s - loss: 0.0915 - accuracy: 0.9612 - val_loss: 0.2975 - val_accuracy: 0.9074
#
# Epoch 00166: val_loss did not improve from 0.12859
# Epoch 167/700
# 31/31 - 4s - loss: 0.1028 - accuracy: 0.9587 - val_loss: 0.5153 - val_accuracy: 0.8209
#
# Epoch 00167: val_loss did not improve from 0.12859
# Epoch 168/700
# 31/31 - 4s - loss: 0.0731 - accuracy: 0.9733 - val_loss: 0.3580 - val_accuracy: 0.8692
#
# Epoch 00168: val_loss did not improve from 0.12859
# Epoch 169/700
# 31/31 - 4s - loss: 0.0863 - accuracy: 0.9657 - val_loss: 0.1841 - val_accuracy: 0.9155
#
# Epoch 00169: val_loss did not improve from 0.12859
# Epoch 170/700
# 31/31 - 4s - loss: 0.0907 - accuracy: 0.9637 - val_loss: 0.2869 - val_accuracy: 0.9014
#
# Epoch 00170: val_loss did not improve from 0.12859
# Epoch 171/700
# 31/31 - 4s - loss: 0.0870 - accuracy: 0.9662 - val_loss: 0.2973 - val_accuracy: 0.8853
#
# Epoch 00171: val_loss did not improve from 0.12859
# Epoch 172/700
# 31/31 - 4s - loss: 0.0757 - accuracy: 0.9708 - val_loss: 0.3832 - val_accuracy: 0.8692
#
# Epoch 00172: val_loss did not improve from 0.12859
# Epoch 173/700
# 31/31 - 4s - loss: 0.0873 - accuracy: 0.9657 - val_loss: 0.3220 - val_accuracy: 0.8913
#
# Epoch 00173: val_loss did not improve from 0.12859
# Epoch 174/700
# 31/31 - 4s - loss: 0.0968 - accuracy: 0.9647 - val_loss: 0.3264 - val_accuracy: 0.8934
#
# Epoch 00174: val_loss did not improve from 0.12859
# Epoch 175/700
# 31/31 - 4s - loss: 0.0894 - accuracy: 0.9632 - val_loss: 0.4831 - val_accuracy: 0.8571
#
# Epoch 00175: val_loss did not improve from 0.12859
# Epoch 176/700
# 31/31 - 4s - loss: 0.0946 - accuracy: 0.9622 - val_loss: 0.2180 - val_accuracy: 0.9155
#
# Epoch 00176: val_loss did not improve from 0.12859
# Epoch 177/700
# 31/31 - 4s - loss: 0.0941 - accuracy: 0.9632 - val_loss: 0.2299 - val_accuracy: 0.9135
#
# Epoch 00177: val_loss did not improve from 0.12859
# Epoch 178/700
# 31/31 - 4s - loss: 0.0800 - accuracy: 0.9733 - val_loss: 0.1336 - val_accuracy: 0.9457
#
# Epoch 00178: val_loss did not improve from 0.12859
# Epoch 179/700
# 31/31 - 4s - loss: 0.0890 - accuracy: 0.9642 - val_loss: 0.1736 - val_accuracy: 0.9316
#
# Epoch 00179: val_loss did not improve from 0.12859
# Epoch 180/700
# 31/31 - 4s - loss: 0.0872 - accuracy: 0.9688 - val_loss: 0.1358 - val_accuracy: 0.9376
#
# Epoch 00180: val_loss did not improve from 0.12859
# Epoch 181/700
# 31/31 - 4s - loss: 0.0732 - accuracy: 0.9718 - val_loss: 0.1531 - val_accuracy: 0.9376
#
# Epoch 00181: val_loss did not improve from 0.12859
# Epoch 182/700
# 31/31 - 4s - loss: 0.0824 - accuracy: 0.9703 - val_loss: 0.2321 - val_accuracy: 0.9155
#
# Epoch 00182: val_loss did not improve from 0.12859
# Epoch 183/700
# 31/31 - 4s - loss: 0.0873 - accuracy: 0.9652 - val_loss: 0.1385 - val_accuracy: 0.9396
#
# Epoch 00183: val_loss did not improve from 0.12859
# Epoch 184/700
# 31/31 - 4s - loss: 0.0972 - accuracy: 0.9647 - val_loss: 0.3977 - val_accuracy: 0.8672
#
# Epoch 00184: val_loss did not improve from 0.12859
# Epoch 185/700
# 31/31 - 4s - loss: 0.0838 - accuracy: 0.9682 - val_loss: 0.1793 - val_accuracy: 0.9396
#
# Epoch 00185: val_loss did not improve from 0.12859
# Epoch 186/700
# 31/31 - 4s - loss: 0.0871 - accuracy: 0.9662 - val_loss: 0.2773 - val_accuracy: 0.8994
#
# Epoch 00186: val_loss did not improve from 0.12859
# Epoch 187/700
# 31/31 - 4s - loss: 0.0791 - accuracy: 0.9667 - val_loss: 0.2939 - val_accuracy: 0.9155
#
# Epoch 00187: val_loss did not improve from 0.12859
# Epoch 188/700
# 31/31 - 4s - loss: 0.0806 - accuracy: 0.9682 - val_loss: 0.3870 - val_accuracy: 0.8612
#
# Epoch 00188: val_loss did not improve from 0.12859
# Epoch 189/700
# 31/31 - 4s - loss: 0.0864 - accuracy: 0.9693 - val_loss: 0.2004 - val_accuracy: 0.9376
#
# Epoch 00189: val_loss did not improve from 0.12859
# Epoch 190/700
# 31/31 - 4s - loss: 0.0972 - accuracy: 0.9632 - val_loss: 0.1856 - val_accuracy: 0.9296
#
# Epoch 00190: val_loss did not improve from 0.12859
# Epoch 191/700
# 31/31 - 4s - loss: 0.0747 - accuracy: 0.9743 - val_loss: 0.3173 - val_accuracy: 0.8934
#
# Epoch 00191: val_loss did not improve from 0.12859
# Epoch 192/700
# 31/31 - 4s - loss: 0.0651 - accuracy: 0.9753 - val_loss: 0.5314 - val_accuracy: 0.8189
#
# Epoch 00192: val_loss did not improve from 0.12859
# Epoch 193/700
# 31/31 - 4s - loss: 0.0756 - accuracy: 0.9743 - val_loss: 0.3195 - val_accuracy: 0.8934
#
# Epoch 00193: val_loss did not improve from 0.12859
# Epoch 194/700
# 31/31 - 4s - loss: 0.0779 - accuracy: 0.9677 - val_loss: 1.0569 - val_accuracy: 0.7404
#
# Epoch 00194: val_loss did not improve from 0.12859
# Epoch 195/700
# 31/31 - 4s - loss: 0.0697 - accuracy: 0.9728 - val_loss: 0.3447 - val_accuracy: 0.8954
#
# Epoch 00195: val_loss did not improve from 0.12859
# Epoch 196/700
# 31/31 - 4s - loss: 0.0732 - accuracy: 0.9703 - val_loss: 1.7499 - val_accuracy: 0.6660
#
# Epoch 00196: val_loss did not improve from 0.12859
# Epoch 197/700
# 31/31 - 4s - loss: 0.0845 - accuracy: 0.9647 - val_loss: 0.2939 - val_accuracy: 0.8974
#
# Epoch 00197: val_loss did not improve from 0.12859
# Epoch 198/700
# 31/31 - 4s - loss: 0.0742 - accuracy: 0.9723 - val_loss: 0.2885 - val_accuracy: 0.8974
#
# Epoch 00198: val_loss did not improve from 0.12859
# Epoch 199/700
# 31/31 - 4s - loss: 0.0741 - accuracy: 0.9693 - val_loss: 0.2427 - val_accuracy: 0.9175
#
# Epoch 00199: val_loss did not improve from 0.12859
# Epoch 200/700
# 31/31 - 4s - loss: 0.0699 - accuracy: 0.9703 - val_loss: 0.2643 - val_accuracy: 0.8974
#
# Epoch 00200: val_loss did not improve from 0.12859
# Epoch 201/700
# 31/31 - 4s - loss: 0.0636 - accuracy: 0.9743 - val_loss: 0.1506 - val_accuracy: 0.9457
#
# Epoch 00201: val_loss did not improve from 0.12859
# Epoch 202/700
# 31/31 - 4s - loss: 0.0807 - accuracy: 0.9738 - val_loss: 0.1739 - val_accuracy: 0.9396
#
# Epoch 00202: val_loss did not improve from 0.12859
# Epoch 203/700
# 31/31 - 4s - loss: 0.0889 - accuracy: 0.9642 - val_loss: 0.2270 - val_accuracy: 0.9175
#
# Epoch 00203: val_loss did not improve from 0.12859
# Epoch 204/700
# 31/31 - 4s - loss: 0.0723 - accuracy: 0.9733 - val_loss: 0.2113 - val_accuracy: 0.9276
#
# Epoch 00204: val_loss did not improve from 0.12859
# Epoch 205/700
# 31/31 - 4s - loss: 0.0796 - accuracy: 0.9662 - val_loss: 0.1966 - val_accuracy: 0.9316
#
# Epoch 00205: val_loss did not improve from 0.12859
# Epoch 206/700
# 31/31 - 4s - loss: 0.0805 - accuracy: 0.9667 - val_loss: 0.2488 - val_accuracy: 0.9135
#
# Epoch 00206: val_loss did not improve from 0.12859
# Epoch 207/700
# 31/31 - 4s - loss: 0.0905 - accuracy: 0.9627 - val_loss: 0.2856 - val_accuracy: 0.8873
#
# Epoch 00207: val_loss did not improve from 0.12859
# Epoch 208/700
# 31/31 - 4s - loss: 0.0665 - accuracy: 0.9723 - val_loss: 0.1566 - val_accuracy: 0.9336
#
# Epoch 00208: val_loss did not improve from 0.12859
# Epoch 209/700
# 31/31 - 4s - loss: 0.0741 - accuracy: 0.9708 - val_loss: 0.1330 - val_accuracy: 0.9497
#
# Epoch 00209: val_loss did not improve from 0.12859
# Epoch 210/700
# 31/31 - 4s - loss: 0.0877 - accuracy: 0.9677 - val_loss: 0.1722 - val_accuracy: 0.9356
#
# Epoch 00210: val_loss did not improve from 0.12859
# Epoch 211/700
# 31/31 - 4s - loss: 0.0667 - accuracy: 0.9778 - val_loss: 0.1624 - val_accuracy: 0.9396
#
# Epoch 00211: val_loss did not improve from 0.12859
# Epoch 212/700
# 31/31 - 4s - loss: 0.0687 - accuracy: 0.9783 - val_loss: 0.1187 - val_accuracy: 0.9598
#
# Epoch 00212: val_loss improved from 0.12859 to 0.11871, saving model to model.h5
# Epoch 213/700
# 31/31 - 4s - loss: 0.0672 - accuracy: 0.9748 - val_loss: 0.4230 - val_accuracy: 0.8672
#
# Epoch 00213: val_loss did not improve from 0.11871
# Epoch 214/700
# 31/31 - 4s - loss: 0.0709 - accuracy: 0.9778 - val_loss: 0.8627 - val_accuracy: 0.7565
#
# Epoch 00214: val_loss did not improve from 0.11871
# Epoch 215/700
# 31/31 - 4s - loss: 0.0590 - accuracy: 0.9748 - val_loss: 0.0989 - val_accuracy: 0.9638
#
# Epoch 00215: val_loss improved from 0.11871 to 0.09886, saving model to model.h5
# Epoch 216/700
# 31/31 - 4s - loss: 0.0592 - accuracy: 0.9793 - val_loss: 0.1725 - val_accuracy: 0.9376
#
# Epoch 00216: val_loss did not improve from 0.09886
# Epoch 217/700
# 31/31 - 4s - loss: 0.0700 - accuracy: 0.9743 - val_loss: 0.1556 - val_accuracy: 0.9457
#
# Epoch 00217: val_loss did not improve from 0.09886
# Epoch 218/700
# 31/31 - 4s - loss: 0.0818 - accuracy: 0.9738 - val_loss: 0.1576 - val_accuracy: 0.9416
#
# Epoch 00218: val_loss did not improve from 0.09886
# Epoch 219/700
# 31/31 - 4s - loss: 0.0576 - accuracy: 0.9798 - val_loss: 0.3500 - val_accuracy: 0.8893
#
# Epoch 00219: val_loss did not improve from 0.09886
# Epoch 220/700
# 31/31 - 4s - loss: 0.0770 - accuracy: 0.9738 - val_loss: 0.1757 - val_accuracy: 0.9396
#
# Epoch 00220: val_loss did not improve from 0.09886
# Epoch 221/700
# 31/31 - 4s - loss: 0.0774 - accuracy: 0.9708 - val_loss: 0.1753 - val_accuracy: 0.9276
#
# Epoch 00221: val_loss did not improve from 0.09886
# Epoch 222/700
# 31/31 - 4s - loss: 0.0620 - accuracy: 0.9763 - val_loss: 0.1491 - val_accuracy: 0.9356
#
# Epoch 00222: val_loss did not improve from 0.09886
# Epoch 223/700
# 31/31 - 4s - loss: 0.0698 - accuracy: 0.9743 - val_loss: 0.2280 - val_accuracy: 0.9256
#
# Epoch 00223: val_loss did not improve from 0.09886
# Epoch 224/700
# 31/31 - 4s - loss: 0.0673 - accuracy: 0.9768 - val_loss: 0.3198 - val_accuracy: 0.9054
#
# Epoch 00224: val_loss did not improve from 0.09886
# Epoch 225/700
# 31/31 - 4s - loss: 0.0596 - accuracy: 0.9768 - val_loss: 0.8642 - val_accuracy: 0.7706
#
# Epoch 00225: val_loss did not improve from 0.09886
# Epoch 226/700
# 31/31 - 4s - loss: 0.0792 - accuracy: 0.9693 - val_loss: 0.3629 - val_accuracy: 0.8773
#
# Epoch 00226: val_loss did not improve from 0.09886
# Epoch 227/700
# 31/31 - 4s - loss: 0.0740 - accuracy: 0.9753 - val_loss: 0.2490 - val_accuracy: 0.9155
#
# Epoch 00227: val_loss did not improve from 0.09886
# Epoch 228/700
# 31/31 - 4s - loss: 0.0710 - accuracy: 0.9763 - val_loss: 0.2350 - val_accuracy: 0.9296
#
# Epoch 00228: val_loss did not improve from 0.09886
# Epoch 229/700
# 31/31 - 4s - loss: 0.0533 - accuracy: 0.9773 - val_loss: 0.1163 - val_accuracy: 0.9517
#
# Epoch 00229: val_loss did not improve from 0.09886
# Epoch 230/700
# 31/31 - 4s - loss: 0.0608 - accuracy: 0.9763 - val_loss: 0.1927 - val_accuracy: 0.9356
#
# Epoch 00230: val_loss did not improve from 0.09886
# Epoch 231/700
# 31/31 - 4s - loss: 0.0700 - accuracy: 0.9738 - val_loss: 0.1524 - val_accuracy: 0.9416
#
# Epoch 00231: val_loss did not improve from 0.09886
# Epoch 232/700
# 31/31 - 4s - loss: 0.0620 - accuracy: 0.9748 - val_loss: 0.1449 - val_accuracy: 0.9356
#
# Epoch 00232: val_loss did not improve from 0.09886
# Epoch 233/700
# 31/31 - 4s - loss: 0.0704 - accuracy: 0.9708 - val_loss: 0.3914 - val_accuracy: 0.8712
#
# Epoch 00233: val_loss did not improve from 0.09886
# Epoch 234/700
# 31/31 - 4s - loss: 0.0599 - accuracy: 0.9783 - val_loss: 0.1377 - val_accuracy: 0.9517
#
# Epoch 00234: val_loss did not improve from 0.09886
# Epoch 235/700
# 31/31 - 4s - loss: 0.0652 - accuracy: 0.9723 - val_loss: 0.1949 - val_accuracy: 0.9437
#
# Epoch 00235: val_loss did not improve from 0.09886
# Epoch 236/700
# 31/31 - 4s - loss: 0.0684 - accuracy: 0.9723 - val_loss: 0.2182 - val_accuracy: 0.9155
#
# Epoch 00236: val_loss did not improve from 0.09886
# Epoch 237/700
# 31/31 - 4s - loss: 0.0607 - accuracy: 0.9798 - val_loss: 0.1586 - val_accuracy: 0.9517
#
# Epoch 00237: val_loss did not improve from 0.09886
# Epoch 238/700
# 31/31 - 4s - loss: 0.0430 - accuracy: 0.9839 - val_loss: 0.2990 - val_accuracy: 0.8954
#
# Epoch 00238: val_loss did not improve from 0.09886
# Epoch 239/700
# 31/31 - 4s - loss: 0.0577 - accuracy: 0.9798 - val_loss: 0.4224 - val_accuracy: 0.8712
#
# Epoch 00239: val_loss did not improve from 0.09886
# Epoch 240/700
# 31/31 - 4s - loss: 0.0570 - accuracy: 0.9748 - val_loss: 0.3311 - val_accuracy: 0.8934
#
# Epoch 00240: val_loss did not improve from 0.09886
# Epoch 241/700
# 31/31 - 4s - loss: 0.0579 - accuracy: 0.9778 - val_loss: 0.1676 - val_accuracy: 0.9416
#
# Epoch 00241: val_loss did not improve from 0.09886
# Epoch 242/700
# 31/31 - 4s - loss: 0.0736 - accuracy: 0.9718 - val_loss: 0.3441 - val_accuracy: 0.9074
#
# Epoch 00242: val_loss did not improve from 0.09886
# Epoch 243/700
# 31/31 - 4s - loss: 0.0632 - accuracy: 0.9748 - val_loss: 0.1518 - val_accuracy: 0.9497
#
# Epoch 00243: val_loss did not improve from 0.09886
# Epoch 244/700
# 31/31 - 4s - loss: 0.0511 - accuracy: 0.9803 - val_loss: 0.2679 - val_accuracy: 0.9195
#
# Epoch 00244: val_loss did not improve from 0.09886
# Epoch 245/700
# 31/31 - 4s - loss: 0.0558 - accuracy: 0.9788 - val_loss: 0.1268 - val_accuracy: 0.9497
#
# Epoch 00245: val_loss did not improve from 0.09886
# Epoch 246/700
# 31/31 - 4s - loss: 0.0644 - accuracy: 0.9743 - val_loss: 0.2569 - val_accuracy: 0.9095
#
# Epoch 00246: val_loss did not improve from 0.09886
# Epoch 247/700
# 31/31 - 4s - loss: 0.0574 - accuracy: 0.9808 - val_loss: 0.1406 - val_accuracy: 0.9416
#
# Epoch 00247: val_loss did not improve from 0.09886
# Epoch 248/700
# 31/31 - 4s - loss: 0.0656 - accuracy: 0.9738 - val_loss: 0.3901 - val_accuracy: 0.8793
#
# Epoch 00248: val_loss did not improve from 0.09886
# Epoch 249/700
# 31/31 - 4s - loss: 0.0549 - accuracy: 0.9793 - val_loss: 0.3610 - val_accuracy: 0.8994
#
# Epoch 00249: val_loss did not improve from 0.09886
# Epoch 250/700
# 31/31 - 4s - loss: 0.0474 - accuracy: 0.9839 - val_loss: 0.2643 - val_accuracy: 0.9195
#
# Epoch 00250: val_loss did not improve from 0.09886
# Epoch 251/700
# 31/31 - 4s - loss: 0.0425 - accuracy: 0.9844 - val_loss: 0.1931 - val_accuracy: 0.9296
#
# Epoch 00251: val_loss did not improve from 0.09886
# Epoch 252/700
# 31/31 - 4s - loss: 0.0498 - accuracy: 0.9814 - val_loss: 0.1782 - val_accuracy: 0.9477
#
# Epoch 00252: val_loss did not improve from 0.09886
# Epoch 253/700
# 31/31 - 4s - loss: 0.0558 - accuracy: 0.9793 - val_loss: 0.1240 - val_accuracy: 0.9618
#
# Epoch 00253: val_loss did not improve from 0.09886
# Epoch 254/700
# 31/31 - 4s - loss: 0.0532 - accuracy: 0.9798 - val_loss: 0.2864 - val_accuracy: 0.9215
#
# Epoch 00254: val_loss did not improve from 0.09886
# Epoch 255/700
# 31/31 - 4s - loss: 0.0537 - accuracy: 0.9803 - val_loss: 0.1422 - val_accuracy: 0.9537
#
# Epoch 00255: val_loss did not improve from 0.09886
# Epoch 256/700
# 31/31 - 4s - loss: 0.0519 - accuracy: 0.9814 - val_loss: 0.4721 - val_accuracy: 0.8632
#
# Epoch 00256: val_loss did not improve from 0.09886
# Epoch 257/700
# 31/31 - 4s - loss: 0.0475 - accuracy: 0.9834 - val_loss: 0.2134 - val_accuracy: 0.9256
#
# Epoch 00257: val_loss did not improve from 0.09886
# Epoch 258/700
# 31/31 - 4s - loss: 0.0735 - accuracy: 0.9748 - val_loss: 0.1874 - val_accuracy: 0.9296
#
# Epoch 00258: val_loss did not improve from 0.09886
# Epoch 259/700
# 31/31 - 4s - loss: 0.0635 - accuracy: 0.9718 - val_loss: 0.7366 - val_accuracy: 0.8068
#
# Epoch 00259: val_loss did not improve from 0.09886
# Epoch 260/700
# 31/31 - 4s - loss: 0.0581 - accuracy: 0.9803 - val_loss: 0.4019 - val_accuracy: 0.8692
#
# Epoch 00260: val_loss did not improve from 0.09886
# Epoch 261/700
# 31/31 - 4s - loss: 0.0579 - accuracy: 0.9783 - val_loss: 1.8406 - val_accuracy: 0.6499
#
# Epoch 00261: val_loss did not improve from 0.09886
# Epoch 262/700
# 31/31 - 4s - loss: 0.0633 - accuracy: 0.9793 - val_loss: 0.2673 - val_accuracy: 0.9175
#
# Epoch 00262: val_loss did not improve from 0.09886
# Epoch 263/700
# 31/31 - 4s - loss: 0.0630 - accuracy: 0.9763 - val_loss: 0.2362 - val_accuracy: 0.9215
#
# Epoch 00263: val_loss did not improve from 0.09886
# Epoch 264/700
# 31/31 - 4s - loss: 0.0457 - accuracy: 0.9829 - val_loss: 0.1116 - val_accuracy: 0.9598
#
# Epoch 00264: val_loss did not improve from 0.09886
# Epoch 265/700
# 31/31 - 4s - loss: 0.0491 - accuracy: 0.9814 - val_loss: 0.2103 - val_accuracy: 0.9256
#
# Epoch 00265: val_loss did not improve from 0.09886
# Epoch 266/700
# 31/31 - 4s - loss: 0.0546 - accuracy: 0.9808 - val_loss: 0.2249 - val_accuracy: 0.9316
#
# Epoch 00266: val_loss did not improve from 0.09886
# Epoch 267/700
# 31/31 - 4s - loss: 0.0568 - accuracy: 0.9783 - val_loss: 0.1985 - val_accuracy: 0.9376
#
# Epoch 00267: val_loss did not improve from 0.09886
# Epoch 268/700
# 31/31 - 4s - loss: 0.0500 - accuracy: 0.9798 - val_loss: 0.1088 - val_accuracy: 0.9598
#
# Epoch 00268: val_loss did not improve from 0.09886
# Epoch 269/700
# 31/31 - 4s - loss: 0.0477 - accuracy: 0.9844 - val_loss: 0.2766 - val_accuracy: 0.9115
#
# Epoch 00269: val_loss did not improve from 0.09886
# Epoch 270/700
# 31/31 - 4s - loss: 0.0401 - accuracy: 0.9834 - val_loss: 0.3061 - val_accuracy: 0.9034
#
# Epoch 00270: val_loss did not improve from 0.09886
# Epoch 271/700
# 31/31 - 4s - loss: 0.0366 - accuracy: 0.9834 - val_loss: 0.2446 - val_accuracy: 0.9276
#
# Epoch 00271: val_loss did not improve from 0.09886
# Epoch 272/700
# 31/31 - 4s - loss: 0.0489 - accuracy: 0.9814 - val_loss: 0.2644 - val_accuracy: 0.9155
#
# Epoch 00272: val_loss did not improve from 0.09886
# Epoch 273/700
# 31/31 - 4s - loss: 0.0394 - accuracy: 0.9859 - val_loss: 0.2683 - val_accuracy: 0.9135
#
# Epoch 00273: val_loss did not improve from 0.09886
# Epoch 274/700
# 31/31 - 4s - loss: 0.0442 - accuracy: 0.9854 - val_loss: 0.5320 - val_accuracy: 0.8471
#
# Epoch 00274: val_loss did not improve from 0.09886
# Epoch 275/700
# 31/31 - 4s - loss: 0.0527 - accuracy: 0.9783 - val_loss: 0.2558 - val_accuracy: 0.9115
#
# Epoch 00275: val_loss did not improve from 0.09886
# Epoch 276/700
# 31/31 - 4s - loss: 0.0481 - accuracy: 0.9803 - val_loss: 0.3088 - val_accuracy: 0.9074
#
# Epoch 00276: val_loss did not improve from 0.09886
# Epoch 277/700
# 31/31 - 4s - loss: 0.0511 - accuracy: 0.9798 - val_loss: 0.1700 - val_accuracy: 0.9416
#
# Epoch 00277: val_loss did not improve from 0.09886
# Epoch 278/700
# 31/31 - 4s - loss: 0.0519 - accuracy: 0.9819 - val_loss: 0.2738 - val_accuracy: 0.9215
#
# Epoch 00278: val_loss did not improve from 0.09886
# Epoch 279/700
# 31/31 - 4s - loss: 0.0583 - accuracy: 0.9783 - val_loss: 0.2400 - val_accuracy: 0.9215
#
# Epoch 00279: val_loss did not improve from 0.09886
# Epoch 280/700
# 31/31 - 4s - loss: 0.0563 - accuracy: 0.9798 - val_loss: 0.1515 - val_accuracy: 0.9437
#
# Epoch 00280: val_loss did not improve from 0.09886
# Epoch 281/700
# 31/31 - 4s - loss: 0.0494 - accuracy: 0.9829 - val_loss: 0.0940 - val_accuracy: 0.9678
#
# Epoch 00281: val_loss improved from 0.09886 to 0.09400, saving model to model.h5
# Epoch 282/700
# 31/31 - 4s - loss: 0.0545 - accuracy: 0.9758 - val_loss: 0.1197 - val_accuracy: 0.9577
#
# Epoch 00282: val_loss did not improve from 0.09400
# Epoch 283/700
# 31/31 - 4s - loss: 0.0583 - accuracy: 0.9733 - val_loss: 0.1336 - val_accuracy: 0.9557
#
# Epoch 00283: val_loss did not improve from 0.09400
# Epoch 284/700
# 31/31 - 4s - loss: 0.0398 - accuracy: 0.9859 - val_loss: 0.1191 - val_accuracy: 0.9577
#
# Epoch 00284: val_loss did not improve from 0.09400
# Epoch 285/700
# 31/31 - 4s - loss: 0.0446 - accuracy: 0.9854 - val_loss: 0.2224 - val_accuracy: 0.9256
#
# Epoch 00285: val_loss did not improve from 0.09400
# Epoch 286/700
# 31/31 - 4s - loss: 0.0368 - accuracy: 0.9864 - val_loss: 0.6909 - val_accuracy: 0.8129
#
# Epoch 00286: val_loss did not improve from 0.09400
# Epoch 287/700
# 31/31 - 4s - loss: 0.0482 - accuracy: 0.9834 - val_loss: 0.0916 - val_accuracy: 0.9638
#
# Epoch 00287: val_loss improved from 0.09400 to 0.09160, saving model to model.h5
# Epoch 288/700
# 31/31 - 4s - loss: 0.0465 - accuracy: 0.9814 - val_loss: 0.1314 - val_accuracy: 0.9537
#
# Epoch 00288: val_loss did not improve from 0.09160
# Epoch 289/700
# 31/31 - 4s - loss: 0.0521 - accuracy: 0.9773 - val_loss: 0.1206 - val_accuracy: 0.9537
#
# Epoch 00289: val_loss did not improve from 0.09160
# Epoch 290/700
# 31/31 - 4s - loss: 0.0534 - accuracy: 0.9808 - val_loss: 0.1856 - val_accuracy: 0.9457
#
# Epoch 00290: val_loss did not improve from 0.09160
# Epoch 291/700
# 31/31 - 4s - loss: 0.0486 - accuracy: 0.9844 - val_loss: 0.1128 - val_accuracy: 0.9577
#
# Epoch 00291: val_loss did not improve from 0.09160
# Epoch 292/700
# 31/31 - 4s - loss: 0.0416 - accuracy: 0.9798 - val_loss: 0.2757 - val_accuracy: 0.9336
#
# Epoch 00292: val_loss did not improve from 0.09160
# Epoch 293/700
# 31/31 - 4s - loss: 0.0348 - accuracy: 0.9869 - val_loss: 0.1404 - val_accuracy: 0.9537
#
# Epoch 00293: val_loss did not improve from 0.09160
# Epoch 294/700
# 31/31 - 4s - loss: 0.0415 - accuracy: 0.9874 - val_loss: 0.1150 - val_accuracy: 0.9577
#
# Epoch 00294: val_loss did not improve from 0.09160
# Epoch 295/700
# 31/31 - 4s - loss: 0.0404 - accuracy: 0.9839 - val_loss: 1.3778 - val_accuracy: 0.7103
#
# ...
#
# Epoch 00596: val_loss did not improve from 0.03821
# Epoch 597/700
# 31/31 - 4s - loss: 0.0135 - accuracy: 0.9950 - val_loss: 0.0551 - val_accuracy: 0.9819
#
# Epoch 00597: val_loss did not improve from 0.03821
# Epoch 598/700
# 31/31 - 4s - loss: 0.0064 - accuracy: 0.9985 - val_loss: 0.1195 - val_accuracy: 0.9678
#
# Epoch 00598: val_loss did not improve from 0.03821
# Epoch 599/700
# 31/31 - 4s - loss: 0.0120 - accuracy: 0.9960 - val_loss: 0.0757 - val_accuracy: 0.9779
#
# Epoch 00599: val_loss did not improve from 0.03821
# Epoch 600/700
# 31/31 - 4s - loss: 0.0081 - accuracy: 0.9980 - val_loss: 0.4201 - val_accuracy: 0.8974
#
# Epoch 00600: val_loss did not improve from 0.03821
# Epoch 601/700
# 31/31 - 4s - loss: 0.0134 - accuracy: 0.9950 - val_loss: 0.0812 - val_accuracy: 0.9738
#
# Epoch 00601: val_loss did not improve from 0.03821
# Epoch 602/700
# 31/31 - 4s - loss: 0.0133 - accuracy: 0.9950 - val_loss: 0.1609 - val_accuracy: 0.9658
#
# Epoch 00602: val_loss did not improve from 0.03821
# Epoch 603/700
# 31/31 - 4s - loss: 0.0193 - accuracy: 0.9929 - val_loss: 0.1066 - val_accuracy: 0.9698
#
# Epoch 00603: val_loss did not improve from 0.03821
# Epoch 604/700
# 31/31 - 4s - loss: 0.0130 - accuracy: 0.9965 - val_loss: 0.1585 - val_accuracy: 0.9658
#
# Epoch 00604: val_loss did not improve from 0.03821
# Epoch 605/700
# 31/31 - 4s - loss: 0.0195 - accuracy: 0.9934 - val_loss: 0.0842 - val_accuracy: 0.9718
#
# Epoch 00605: val_loss did not improve from 0.03821
# Epoch 606/700
# 31/31 - 4s - loss: 0.0109 - accuracy: 0.9970 - val_loss: 0.1827 - val_accuracy: 0.9537
#
# Epoch 00606: val_loss did not improve from 0.03821
# Epoch 607/700
# 31/31 - 4s - loss: 0.0139 - accuracy: 0.9960 - val_loss: 0.2821 - val_accuracy: 0.9316
#
# Epoch 00607: val_loss did not improve from 0.03821
# Epoch 608/700
# 31/31 - 4s - loss: 0.0149 - accuracy: 0.9955 - val_loss: 0.3116 - val_accuracy: 0.9356
#
# Epoch 00608: val_loss did not improve from 0.03821
# Epoch 609/700
# 31/31 - 4s - loss: 0.0138 - accuracy: 0.9929 - val_loss: 0.2664 - val_accuracy: 0.9497
#
# Epoch 00609: val_loss did not improve from 0.03821
# Epoch 610/700
# 31/31 - 4s - loss: 0.0111 - accuracy: 0.9970 - val_loss: 0.2666 - val_accuracy: 0.9457
#
# Epoch 00610: val_loss did not improve from 0.03821
# Epoch 611/700
# 31/31 - 4s - loss: 0.0086 - accuracy: 0.9960 - val_loss: 0.1681 - val_accuracy: 0.9658
#
# Epoch 00611: val_loss did not improve from 0.03821
# Epoch 612/700
# 31/31 - 4s - loss: 0.0109 - accuracy: 0.9960 - val_loss: 0.0926 - val_accuracy: 0.9678
#
# Epoch 00612: val_loss did not improve from 0.03821
# Epoch 613/700
# 31/31 - 4s - loss: 0.0097 - accuracy: 0.9970 - val_loss: 0.4716 - val_accuracy: 0.8994
#
# Epoch 00613: val_loss did not improve from 0.03821
# Epoch 614/700
# 31/31 - 4s - loss: 0.0191 - accuracy: 0.9934 - val_loss: 0.0936 - val_accuracy: 0.9658
#
# Epoch 00614: val_loss did not improve from 0.03821
# Epoch 615/700
# 31/31 - 4s - loss: 0.0079 - accuracy: 0.9960 - val_loss: 0.1277 - val_accuracy: 0.9718
#
# Epoch 00615: val_loss did not improve from 0.03821
# Epoch 616/700
# 31/31 - 4s - loss: 0.0163 - accuracy: 0.9950 - val_loss: 0.0764 - val_accuracy: 0.9779
#
# Epoch 00616: val_loss did not improve from 0.03821
# Epoch 617/700
# 31/31 - 4s - loss: 0.0137 - accuracy: 0.9960 - val_loss: 0.1233 - val_accuracy: 0.9678
#
# Epoch 00617: val_loss did not improve from 0.03821
# Epoch 618/700
# 31/31 - 4s - loss: 0.0055 - accuracy: 0.9985 - val_loss: 0.3756 - val_accuracy: 0.9215
#
# Epoch 00618: val_loss did not improve from 0.03821
# Epoch 619/700
# 31/31 - 4s - loss: 0.0125 - accuracy: 0.9965 - val_loss: 0.1354 - val_accuracy: 0.9638
#
# Epoch 00619: val_loss did not improve from 0.03821
# Epoch 620/700
# 31/31 - 4s - loss: 0.0163 - accuracy: 0.9960 - val_loss: 0.1274 - val_accuracy: 0.9618
#
# Epoch 00620: val_loss did not improve from 0.03821
# Epoch 621/700
# 31/31 - 4s - loss: 0.0074 - accuracy: 0.9965 - val_loss: 0.1573 - val_accuracy: 0.9517
#
# Epoch 00621: val_loss did not improve from 0.03821
# Epoch 622/700
# 31/31 - 4s - loss: 0.0108 - accuracy: 0.9950 - val_loss: 0.7515 - val_accuracy: 0.8390
#
# Epoch 00622: val_loss did not improve from 0.03821
# Epoch 623/700
# 31/31 - 4s - loss: 0.0233 - accuracy: 0.9929 - val_loss: 0.2360 - val_accuracy: 0.9457
#
# Epoch 00623: val_loss did not improve from 0.03821
# Epoch 624/700
# 31/31 - 4s - loss: 0.0100 - accuracy: 0.9965 - val_loss: 1.2866 - val_accuracy: 0.7726
#
# Epoch 00624: val_loss did not improve from 0.03821
# Epoch 625/700
# 31/31 - 4s - loss: 0.0134 - accuracy: 0.9934 - val_loss: 1.5719 - val_accuracy: 0.7465
#
# Epoch 00625: val_loss did not improve from 0.03821
# Epoch 626/700
# 31/31 - 4s - loss: 0.0066 - accuracy: 0.9970 - val_loss: 0.4291 - val_accuracy: 0.9135
#
# Epoch 00626: val_loss did not improve from 0.03821
# Epoch 627/700
# 31/31 - 4s - loss: 0.0156 - accuracy: 0.9929 - val_loss: 0.2014 - val_accuracy: 0.9497
#
# Epoch 00627: val_loss did not improve from 0.03821
# Epoch 628/700
# 31/31 - 4s - loss: 0.0130 - accuracy: 0.9934 - val_loss: 0.1348 - val_accuracy: 0.9658
#
# Epoch 00628: val_loss did not improve from 0.03821
# Epoch 629/700
# 31/31 - 4s - loss: 0.0106 - accuracy: 0.9970 - val_loss: 0.1614 - val_accuracy: 0.9557
#
# Epoch 00629: val_loss did not improve from 0.03821
# Epoch 630/700
# 31/31 - 4s - loss: 0.0148 - accuracy: 0.9950 - val_loss: 0.1920 - val_accuracy: 0.9437
#
# Epoch 00630: val_loss did not improve from 0.03821
# Epoch 631/700
# 31/31 - 4s - loss: 0.0117 - accuracy: 0.9965 - val_loss: 0.7793 - val_accuracy: 0.8471
#
# Epoch 00631: val_loss did not improve from 0.03821
# Epoch 632/700
# 31/31 - 4s - loss: 0.0080 - accuracy: 0.9965 - val_loss: 0.6202 - val_accuracy: 0.8732
#
# Epoch 00632: val_loss did not improve from 0.03821
# Epoch 633/700
# 31/31 - 4s - loss: 0.0131 - accuracy: 0.9965 - val_loss: 0.1699 - val_accuracy: 0.9497
#
# Epoch 00633: val_loss did not improve from 0.03821
# Epoch 634/700
# 31/31 - 4s - loss: 0.0208 - accuracy: 0.9940 - val_loss: 0.1698 - val_accuracy: 0.9537
#
# Epoch 00634: val_loss did not improve from 0.03821
# Epoch 635/700
# 31/31 - 4s - loss: 0.0105 - accuracy: 0.9975 - val_loss: 0.1339 - val_accuracy: 0.9638
#
# Epoch 00635: val_loss did not improve from 0.03821
# Epoch 636/700
# 31/31 - 4s - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.3050 - val_accuracy: 0.9256
#
# Epoch 00636: val_loss did not improve from 0.03821
# Epoch 637/700
# 31/31 - 4s - loss: 0.0098 - accuracy: 0.9970 - val_loss: 0.0815 - val_accuracy: 0.9759
#
# Epoch 00637: val_loss did not improve from 0.03821
# Epoch 638/700
# 31/31 - 4s - loss: 0.0191 - accuracy: 0.9929 - val_loss: 0.3050 - val_accuracy: 0.9235
#
# Epoch 00638: val_loss did not improve from 0.03821
# Epoch 639/700
# 31/31 - 4s - loss: 0.0231 - accuracy: 0.9934 - val_loss: 0.0843 - val_accuracy: 0.9698
#
# Epoch 00639: val_loss did not improve from 0.03821
# Epoch 640/700
# 31/31 - 4s - loss: 0.0149 - accuracy: 0.9950 - val_loss: 0.0818 - val_accuracy: 0.9698
#
# Epoch 00640: val_loss did not improve from 0.03821
# Epoch 641/700
# 31/31 - 4s - loss: 0.0169 - accuracy: 0.9950 - val_loss: 0.1062 - val_accuracy: 0.9698
#
# Epoch 00641: val_loss did not improve from 0.03821
# Epoch 642/700
# 31/31 - 4s - loss: 0.0135 - accuracy: 0.9950 - val_loss: 0.0982 - val_accuracy: 0.9698
#
# Epoch 00642: val_loss did not improve from 0.03821
# Epoch 643/700
# 31/31 - 4s - loss: 0.0155 - accuracy: 0.9934 - val_loss: 0.2934 - val_accuracy: 0.9296
#
# Epoch 00643: val_loss did not improve from 0.03821
# Epoch 644/700
# 31/31 - 4s - loss: 0.0101 - accuracy: 0.9965 - val_loss: 0.0665 - val_accuracy: 0.9759
#
# Epoch 00644: val_loss did not improve from 0.03821
# Epoch 645/700
# 31/31 - 4s - loss: 0.0097 - accuracy: 0.9970 - val_loss: 0.0766 - val_accuracy: 0.9759
#
# Epoch 00645: val_loss did not improve from 0.03821
# Epoch 646/700
# 31/31 - 4s - loss: 0.0143 - accuracy: 0.9945 - val_loss: 0.1047 - val_accuracy: 0.9658
#
# Epoch 00646: val_loss did not improve from 0.03821
# Epoch 647/700
# 31/31 - 4s - loss: 0.0126 - accuracy: 0.9965 - val_loss: 0.1074 - val_accuracy: 0.9698
#
# Epoch 00647: val_loss did not improve from 0.03821
# Epoch 648/700
# 31/31 - 4s - loss: 0.0142 - accuracy: 0.9945 - val_loss: 0.0994 - val_accuracy: 0.9738
#
# Epoch 00648: val_loss did not improve from 0.03821
# Epoch 649/700
# 31/31 - 4s - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.0679 - val_accuracy: 0.9759
#
# Epoch 00649: val_loss did not improve from 0.03821
# Epoch 650/700
# 31/31 - 4s - loss: 0.0081 - accuracy: 0.9980 - val_loss: 0.0954 - val_accuracy: 0.9738
#
# Epoch 00650: val_loss did not improve from 0.03821
# Epoch 651/700
# 31/31 - 4s - loss: 0.0110 - accuracy: 0.9975 - val_loss: 0.1425 - val_accuracy: 0.9577
#
# Epoch 00651: val_loss did not improve from 0.03821
# Epoch 652/700
# 31/31 - 4s - loss: 0.0099 - accuracy: 0.9965 - val_loss: 0.1579 - val_accuracy: 0.9598
#
# Epoch 00652: val_loss did not improve from 0.03821
# Epoch 653/700
# 31/31 - 4s - loss: 0.0101 - accuracy: 0.9965 - val_loss: 0.1659 - val_accuracy: 0.9497
#
# Epoch 00653: val_loss did not improve from 0.03821
# Epoch 654/700
# 31/31 - 4s - loss: 0.0148 - accuracy: 0.9950 - val_loss: 0.1744 - val_accuracy: 0.9577
#
# Epoch 00654: val_loss did not improve from 0.03821
# Epoch 655/700
# 31/31 - 4s - loss: 0.0078 - accuracy: 0.9960 - val_loss: 0.2337 - val_accuracy: 0.9457
#
# Epoch 00655: val_loss did not improve from 0.03821
# Epoch 656/700
# 31/31 - 4s - loss: 0.0087 - accuracy: 0.9970 - val_loss: 1.0560 - val_accuracy: 0.8089
#
# Epoch 00656: val_loss did not improve from 0.03821
# Epoch 657/700
# 31/31 - 4s - loss: 0.0064 - accuracy: 0.9975 - val_loss: 1.1320 - val_accuracy: 0.8068
#
# Epoch 00657: val_loss did not improve from 0.03821
# Epoch 658/700
# 31/31 - 4s - loss: 0.0153 - accuracy: 0.9955 - val_loss: 0.1398 - val_accuracy: 0.9577
#
# Epoch 00658: val_loss did not improve from 0.03821
# Epoch 659/700
# 31/31 - 4s - loss: 0.0138 - accuracy: 0.9955 - val_loss: 0.0443 - val_accuracy: 0.9819
#
# Epoch 00659: val_loss did not improve from 0.03821
# Epoch 660/700
# 31/31 - 4s - loss: 0.0230 - accuracy: 0.9934 - val_loss: 0.0576 - val_accuracy: 0.9799
#
# Epoch 00660: val_loss did not improve from 0.03821
# Epoch 661/700
# 31/31 - 3s - loss: 0.0108 - accuracy: 0.9975 - val_loss: 0.0656 - val_accuracy: 0.9738
#
# Epoch 00661: val_loss did not improve from 0.03821
# Epoch 662/700
# 31/31 - 4s - loss: 0.0170 - accuracy: 0.9934 - val_loss: 0.2125 - val_accuracy: 0.9497
#
# Epoch 00662: val_loss did not improve from 0.03821
# Epoch 663/700
# 31/31 - 4s - loss: 0.0160 - accuracy: 0.9950 - val_loss: 0.2714 - val_accuracy: 0.9396
#
# Epoch 00663: val_loss did not improve from 0.03821
# Epoch 664/700
# 31/31 - 4s - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.4707 - val_accuracy: 0.9054
#
# Epoch 00664: val_loss did not improve from 0.03821
# Epoch 665/700
# 31/31 - 4s - loss: 0.0097 - accuracy: 0.9975 - val_loss: 0.3941 - val_accuracy: 0.9155
#
# Epoch 00665: val_loss did not improve from 0.03821
# Epoch 666/700
# 31/31 - 4s - loss: 0.0201 - accuracy: 0.9934 - val_loss: 0.2552 - val_accuracy: 0.9296
#
# Epoch 00666: val_loss did not improve from 0.03821
# Epoch 667/700
# 31/31 - 4s - loss: 0.0197 - accuracy: 0.9919 - val_loss: 0.0982 - val_accuracy: 0.9678
#
# Epoch 00667: val_loss did not improve from 0.03821
# Epoch 668/700
# 31/31 - 4s - loss: 0.0123 - accuracy: 0.9940 - val_loss: 0.0783 - val_accuracy: 0.9698
#
# Epoch 00668: val_loss did not improve from 0.03821
# Epoch 669/700
# 31/31 - 4s - loss: 0.0138 - accuracy: 0.9975 - val_loss: 0.2417 - val_accuracy: 0.9396
#
# Epoch 00669: val_loss did not improve from 0.03821
# Epoch 670/700
# 31/31 - 4s - loss: 0.0094 - accuracy: 0.9980 - val_loss: 0.3088 - val_accuracy: 0.9276
#
# Epoch 00670: val_loss did not improve from 0.03821
# Epoch 671/700
# 31/31 - 4s - loss: 0.0176 - accuracy: 0.9945 - val_loss: 0.8039 - val_accuracy: 0.8330
#
# Epoch 00671: val_loss did not improve from 0.03821
# Epoch 672/700
# 31/31 - 4s - loss: 0.0130 - accuracy: 0.9955 - val_loss: 0.5162 - val_accuracy: 0.8773
#
# Epoch 00672: val_loss did not improve from 0.03821
# Epoch 673/700
# 31/31 - 4s - loss: 0.0097 - accuracy: 0.9975 - val_loss: 0.0829 - val_accuracy: 0.9738
#
# Epoch 00673: val_loss did not improve from 0.03821
# Epoch 674/700
# 31/31 - 4s - loss: 0.0080 - accuracy: 0.9980 - val_loss: 0.1034 - val_accuracy: 0.9638
#
# Epoch 00674: val_loss did not improve from 0.03821
# Epoch 675/700
# 31/31 - 4s - loss: 0.0104 - accuracy: 0.9965 - val_loss: 0.0891 - val_accuracy: 0.9718
#
# Epoch 00675: val_loss did not improve from 0.03821
# Epoch 676/700
# 31/31 - 4s - loss: 0.0099 - accuracy: 0.9960 - val_loss: 0.1531 - val_accuracy: 0.9457
#
# Epoch 00676: val_loss did not improve from 0.03821
# Epoch 677/700
# 31/31 - 4s - loss: 0.0079 - accuracy: 0.9970 - val_loss: 0.1861 - val_accuracy: 0.9437
#
# Epoch 00677: val_loss did not improve from 0.03821
# Epoch 678/700
# 31/31 - 4s - loss: 0.0065 - accuracy: 0.9985 - val_loss: 0.0555 - val_accuracy: 0.9819
#
# Epoch 00678: val_loss did not improve from 0.03821
# Epoch 679/700
# 31/31 - 4s - loss: 0.0128 - accuracy: 0.9960 - val_loss: 0.0808 - val_accuracy: 0.9759
#
# Epoch 00679: val_loss did not improve from 0.03821
# Epoch 680/700
# 31/31 - 4s - loss: 0.0125 - accuracy: 0.9960 - val_loss: 0.1022 - val_accuracy: 0.9759
#
# Epoch 00680: val_loss did not improve from 0.03821
# Epoch 681/700
# 31/31 - 4s - loss: 0.0171 - accuracy: 0.9934 - val_loss: 0.4488 - val_accuracy: 0.8913
#
# Epoch 00681: val_loss did not improve from 0.03821
# Epoch 682/700
# 31/31 - 4s - loss: 0.0132 - accuracy: 0.9950 - val_loss: 0.0729 - val_accuracy: 0.9759
#
# Epoch 00682: val_loss did not improve from 0.03821
# Epoch 683/700
# 31/31 - 4s - loss: 0.0126 - accuracy: 0.9955 - val_loss: 0.0562 - val_accuracy: 0.9839
#
# Epoch 00683: val_loss did not improve from 0.03821
# Epoch 684/700
# 31/31 - 4s - loss: 0.0113 - accuracy: 0.9980 - val_loss: 0.2393 - val_accuracy: 0.9437
#
# Epoch 00684: val_loss did not improve from 0.03821
# Epoch 685/700
# 31/31 - 4s - loss: 0.0136 - accuracy: 0.9955 - val_loss: 0.1681 - val_accuracy: 0.9598
#
# Epoch 00685: val_loss did not improve from 0.03821
# Epoch 686/700
# 31/31 - 3s - loss: 0.0057 - accuracy: 0.9975 - val_loss: 0.1707 - val_accuracy: 0.9598
#
# Epoch 00686: val_loss did not improve from 0.03821
# Epoch 687/700
# 31/31 - 4s - loss: 0.0139 - accuracy: 0.9950 - val_loss: 0.2027 - val_accuracy: 0.9497
#
# Epoch 00687: val_loss did not improve from 0.03821
# Epoch 688/700
# 31/31 - 4s - loss: 0.0120 - accuracy: 0.9950 - val_loss: 0.0624 - val_accuracy: 0.9799
#
# Epoch 00688: val_loss did not improve from 0.03821
# Epoch 689/700
# 31/31 - 4s - loss: 0.0112 - accuracy: 0.9970 - val_loss: 0.1187 - val_accuracy: 0.9678
#
# Epoch 00689: val_loss did not improve from 0.03821
# Epoch 690/700
# 31/31 - 4s - loss: 0.0138 - accuracy: 0.9960 - val_loss: 0.1027 - val_accuracy: 0.9678
#
# Epoch 00690: val_loss did not improve from 0.03821
# Epoch 691/700
# 31/31 - 4s - loss: 0.0110 - accuracy: 0.9975 - val_loss: 0.1441 - val_accuracy: 0.9598
#
# Epoch 00691: val_loss did not improve from 0.03821
# Epoch 692/700
# 31/31 - 4s - loss: 0.0182 - accuracy: 0.9950 - val_loss: 0.3768 - val_accuracy: 0.9155
#
# Epoch 00692: val_loss did not improve from 0.03821
# Epoch 693/700
# 31/31 - 4s - loss: 0.0108 - accuracy: 0.9955 - val_loss: 0.1109 - val_accuracy: 0.9759
#
# Epoch 00693: val_loss did not improve from 0.03821
# Epoch 694/700
# 31/31 - 3s - loss: 0.0133 - accuracy: 0.9965 - val_loss: 0.9670 - val_accuracy: 0.8169
#
# Epoch 00694: val_loss did not improve from 0.03821
# Epoch 695/700
# 31/31 - 4s - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.1992 - val_accuracy: 0.9497
#
# Epoch 00695: val_loss did not improve from 0.03821
# Epoch 696/700
# 31/31 - 4s - loss: 0.0125 - accuracy: 0.9945 - val_loss: 0.1295 - val_accuracy: 0.9557
#
# Epoch 00696: val_loss did not improve from 0.03821
# Epoch 697/700
# 31/31 - 4s - loss: 0.0120 - accuracy: 0.9960 - val_loss: 0.4718 - val_accuracy: 0.8934
#
# Epoch 00697: val_loss did not improve from 0.03821
# Epoch 698/700
# 31/31 - 4s - loss: 0.0063 - accuracy: 0.9985 - val_loss: 0.2419 - val_accuracy: 0.9336
#
# Epoch 00698: val_loss did not improve from 0.03821
# Epoch 699/700
# 31/31 - 4s - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.0733 - val_accuracy: 0.9698
#
# Epoch 00699: val_loss did not improve from 0.03821
# Epoch 700/700
# 31/31 - 4s - loss: 0.0142 - accuracy: 0.9940 - val_loss: 0.1077 - val_accuracy: 0.9698
#
# Epoch 00700: val_loss did not improve from 0.03821

# %%
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 16/16 [==============================] - 0s 23ms/step - loss: 0.1077 - accuracy: 0.9698
# Final Loss: 0.10767676681280136, Final Accuracy: 0.9698188900947571

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 145.31999999999996, 'Predicted')

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from skimage import io
from keras.preprocessing import image
#path='imbalanced/Scratch/Scratch_400.jpg'
img = image.load_img('/content/COVID/Covid (1010).png', grayscale=False, target_size=(64, 64))
show_img=image.load_img('/content/COVID/Covid (1010).png', grayscale=False, target_size=(200, 200))
disease_class=['Covid-19','Non Covid-19']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255

custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [9.9998713e-01 1.2861699e-05]
# Prediction: Covid-19

# %%
from skimage import io
from keras.preprocessing import image
#path='imbalanced/Scratch/Scratch_400.jpg'
img = image.load_img('/content/non-COVID/Non-Covid (1007).png', grayscale=False, target_size=(64, 64))
show_img=image.load_img('/content/non-COVID/Non-Covid (1007).png', grayscale=False, target_size=(200, 200))
disease_class=['Covid-19','Non Covid-19']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255

custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [7.6790944e-05 9.9992323e-01]
# Prediction: Non Covid-19
